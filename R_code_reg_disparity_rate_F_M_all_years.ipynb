# %%
Data_Root <- "/Data/Promotion/revision/"
data_root <- "/Data/Promotion/revision/reg_results_F_M/"

# %%
library("lme4")
library("margins")
library("stargazer")
library("emmeans")
library("ggeffects")
library("broom")
library("broom.mixed")
library("dplyr")
library("MuMIn")

# %%
# https://www.rdocumentation.org/packages/ggeffects/versions/1.1.1
# https://www.rdocumentation.org/packages/ggeffects/versions/1.1.1/topics/ggeffect
packageVersion("ggeffects")
# Out:
# [1] ‘1.1.4’

# %%
# library("sjmisc")
# ?sjmisc::typical_value

# %%
options(repr.matrix.max.rows=500, repr.matrix.max.cols=200)

# %%
options(dplyr.print_max = 100)

# %%
mydata <- read.csv(paste(Data_Root, "reg_data_drop_missing.csv", sep = ''), header = TRUE, stringsAsFactors = TRUE)

# %%
# this is after dropping missing data
nrow(mydata)
# Out:
# [1] 14552304

# %%
ncol(mydata)
# Out:
# [1] 81

# %%
mydata = mydata[mydata$affiliation_cate != 'unknown', ]

# %%
mydata = mydata[mydata$gender != 'Unknown', ]

# %%
table(mydata$gender)
# Out:
#  Female    Male  Unisex Unknown
# 4025650 7371102  808320       0

# %%
nrow(mydata)
# Out:
# [1] 12205072

# %%
mydata$pub_year <- as.factor(mydata$pub_year)

# %%
mydata <- within(mydata, gender <- relevel(gender, ref = 'Male'))
mydata <- within(mydata, authorship_pos <- relevel(authorship_pos, ref = 'last_position'))
mydata <- within(mydata, affiliation_cate <- relevel(affiliation_cate, ref = 'domestic'))

# %%
keywords <- " + Social_Sciences + Materials_Science + Engineering + Chemistry + \
        Biochemistry__Genetics_and_Molecular_Biology + Medicine + Nursing + Agricultural_and_Biological_Sciences + \
        Pharmacology__Toxicology_and_Pharmaceutics + Neuroscience + Business__Management_and_Accounting + \
        Economics__Econometrics_and_Finance + Chemical_Engineering + Physics_and_Astronomy + Computer_Science + \
        Decision_Sciences + Health_Professions + Psychology + Immunology_and_Microbiology + Dentistry + \
        Earth_and_Planetary_Sciences + Environmental_Science + Mathematics + Arts_and_Humanities + Energy + \
        Veterinary + General"

# %%
mydata$author_citation_log <- log2(1 + mydata$author_citation)

# %% [markdown]
# ### SI - include unisex

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_tw_0 <- glmer(equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_all_tw_0)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.441800012
# 2  fixed    NA    genderFemale                                 -0.347689815
# 3  fixed    NA    genderUnisex                                 -0.753432056
# 4  fixed    NA    authorship_posfirst_position                  0.363608947
# 5  fixed    NA    authorship_posmiddle_position                -0.639838508
# 6  fixed    NA    authorship_possolo_author                     0.843901177
# 7  fixed    NA    author_pub_count_cate                         0.286180719
# 8  fixed    NA    I(author_pub_count_cate^2)                   -0.020567120
# 9  fixed    NA    affiliation_rank_cate                        -0.047655775
# 10 fixed    NA    affiliation_cateinternational                 0.048979383
# 11 fixed    NA    num_authors                                  -0.002261879
# 12 fixed    NA    journal_impact                                0.033514467
# 13 fixed    NA    author_citation_log                          -0.030789312
# 14 fixed    NA    pub_year2014                                  0.305232631
# 15 fixed    NA    pub_year2015                                  0.604269291
# 16 fixed    NA    pub_year2016                                  0.844787075
# 17 fixed    NA    pub_year2017                                  1.175744230
# 18 fixed    NA    pub_year2018                                  1.541702171
# 19 fixed    NA    Social_Sciences                               0.907496921
# 20 fixed    NA    Materials_Science                            -0.146740817
# 21 fixed    NA    Engineering                                  -0.468967553
# 22 fixed    NA    Chemistry                                    -0.429253763
# 23 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.170631015
# 24 fixed    NA    Medicine                                     -0.274143785
# 25 fixed    NA    Nursing                                       0.263339392
# 26 fixed    NA    Agricultural_and_Biological_Sciences          0.494482469
# 27 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.571382251
# 28 fixed    NA    Neuroscience                                 -0.104247587
# 29 fixed    NA    Business__Management_and_Accounting          -0.177664461
# 30 fixed    NA    Economics__Econometrics_and_Finance          -0.493397817
# 31 fixed    NA    Chemical_Engineering                          0.062147955
# 32 fixed    NA    Physics_and_Astronomy                        -0.722596318
# 33 fixed    NA    Computer_Science                              0.130515935
# 34 fixed    NA    Decision_Sciences                            -0.780355008
# 35 fixed    NA    Health_Professions                            0.904404026
# 36 fixed    NA    Psychology                                   -0.576600470
# 37 fixed    NA    Immunology_and_Microbiology                  -0.176953538
# 38 fixed    NA    Dentistry                                    -1.254120221
# 39 fixed    NA    Earth_and_Planetary_Sciences                 -0.074786971
# 40 fixed    NA    Environmental_Science                         0.168698122
# 41 fixed    NA    Mathematics                                  -0.237807537
# 42 fixed    NA    Arts_and_Humanities                          -0.227904756
# 43 fixed    NA    Energy                                       -0.373862005
# 44 fixed    NA    Veterinary                                   -0.857958563
# 45 fixed    NA    General                                       0.392385693
# 46 ran_pars doi   sd__(Intercept)                               1.497727383
#    std.error    statistic   p.value
# 1  1.138513e-02 -390.140571  0.000000e+00
# 2  3.803820e-03  -91.405438  0.000000e+00
# 3  9.625669e-03  -78.273218  0.000000e+00
# 4  4.899606e-03   74.211879  0.000000e+00
# 5  4.340850e-03 -147.399363  0.000000e+00
# 6  9.889549e-03   85.332626  0.000000e+00
# 7  3.121574e-03   91.678324  0.000000e+00
# 8  2.573086e-04  -79.931714  0.000000e+00
# 9  6.779367e-04  -70.295322  0.000000e+00
# 10 4.200090e-03   11.661508  2.004600e-31
# 11 7.874157e-05  -28.725355 1.840617e-181
# 12 2.857643e-04  117.280088  0.000000e+00
# 13 1.002709e-03  -30.706129 4.714384e-207
# 14 9.667720e-03   31.572350 8.849910e-219
# 15 9.105792e-03   66.360985  0.000000e+00
# 16 8.821246e-03   95.767320  0.000000e+00
# 17 8.609897e-03  136.557292  0.000000e+00
# 18 8.420862e-03  183.081285  0.000000e+00
# 19 8.991357e-03  100.929913  0.000000e+00
# 20 1.487242e-02   -9.866643  5.807592e-23
# 21 1.254029e-02  -37.396861 4.394373e-306
# 22 1.155570e-02  -37.146491 4.994847e-302
# 23 5.767724e-03  -29.583771 2.416760e-192
# 24 4.747806e-03  -57.741153  0.000000e+00
# 25 1.388573e-02   18.964753  3.335925e-80
# 26 6.603002e-03   74.887521  0.000000e+00
# 27 1.421668e-02  -40.190973  0.000000e+00
# 28 9.844332e-03  -10.589605  3.329923e-26
# 29 1.678483e-02  -10.584821  3.504493e-26
# 30 1.811485e-02  -27.237204 2.356101e-163
# 31 1.684578e-02    3.689231  2.249330e-04
# 32 1.245604e-02  -58.011723  0.000000e+00
# 33 1.301245e-02   10.030085  1.124199e-23
# 34 2.875581e-02  -27.137301 3.575736e-162
# 35 1.552523e-02   58.253811  0.000000e+00
# 36 1.321457e-02  -43.633677  0.000000e+00
# 37 1.075673e-02  -16.450501  8.317737e-61
# 38 5.217600e-02  -24.036344 1.159877e-127
# 39 1.154448e-02   -6.478156  9.285027e-11
# 40 8.704851e-03   19.379782  1.143299e-83
# 41 1.686743e-02  -14.098625  3.872386e-45
# 42 2.203536e-02  -10.342683  4.517120e-25
# 43 2.171372e-02  -17.217775  1.953568e-66
# 44 3.023371e-02  -28.377546 3.828164e-177
# 45 1.499270e-02   26.171777 5.570374e-151
# 46           NA          NA            NA

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_all_tw_0, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:34:59 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.348$^{***}$ \\
#   & p = 0.000 \\
#   genderUnisex & $-$0.753$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.364$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.640$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.844$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.286$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.021$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.048$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.049$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.002$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.034$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.031$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.305$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.604$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.845$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.176$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.542$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.907$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.147$^{***}$ \\
#   & p = 0.000 \\
#   Engineering & $-$0.469$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.429$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.171$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.274$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.263$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.494$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.571$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.104$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.178$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.493$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & 0.062$^{***}$ \\
#   & p = 0.0003 \\
#   Physics\_and\_Astronomy & $-$0.723$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.131$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.780$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.904$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.577$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.177$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.254$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.075$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.169$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.238$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.228$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.374$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.858$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.392$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.442$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 12,205,072 \\
# Log Likelihood & $-$1,764,072.000 \\
# Akaike Inf. Crit. & 3,528,237.000 \\
# Bayesian Inf. Crit. & 3,528,895.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %%
# Pseudo-R-squared for Generalized Mixed-Effect models
# https://www.rdocumentation.org/packages/MuMIn/versions/1.47.1/topics/r.squaredGLMM

# The marginal R squared values are those associated with your fixed effects, the conditional ones are those of your
# fixed effects plus the random effects. Usually we will be interested in the marginal effects.
r.squaredGLMM(m_all_tw_0)
# Out:
# Warning message:
# “'r.squaredGLMM' now calculates a revised statistic. See the help page.”
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m        R2c
# theoretical 0.19235363 0.5197861
# delta       0.07611118 0.2056708

# %% [markdown]
# ### Focus on Male and Female (drop unisex)

# %%
mydata = mydata[mydata$gender %in% c("Male", "Female"), ]

# %%
nrow(mydata)
# Out:
# [1] 11396752

# %%
n_distinct(mydata$author_id)
# Out:
# [1] 3503674

# %% [markdown]
# ### SI - A series of regressions

# %%
m1 <- glm(formula = 'self_promotion ~ 1 + gender', data = mydata, family = "binomial")

# %%
tidy(m1)
# Out:
#   term         estimate   std.error   statistic   p.value
# 1 (Intercept)  -3.0267476 0.001754046 -1725.58066 0
# 2 genderFemale -0.2978328 0.003238054   -91.97894 0

# %%
m2 <- glm(formula = 'self_promotion ~ 1 + gender + pub_year + authorship_pos + num_authors', data = mydata, family = "binomial")

# %%
m3 <- glm(formula = 'self_promotion ~ 1 + gender + pub_year + authorship_pos + num_authors + \
        journal_impact + affiliation_cate + affiliation_rank_cate + author_pub_count_cate + \
        I(author_pub_count_cate^2) + author_citation_log', data = mydata, family = "binomial")

# %%
base_str <- "self_promotion ~ 1 + gender + pub_year + authorship_pos + num_authors + journal_impact + \
        affiliation_cate + affiliation_rank_cate + author_pub_count_cate + I(author_pub_count_cate^2) + \
        author_citation_log"
equation <- as.formula(paste(base_str, keywords, sep = " "))
m4 <- glm(formula = equation, data = mydata, family = "binomial")

# %%
base_str <- "self_promotion ~ 1 + gender + pub_year + authorship_pos + num_authors + journal_impact + \
        affiliation_cate + affiliation_rank_cate + author_pub_count_cate + I(author_pub_count_cate^2) + \
        author_citation_log"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m5 <- glmer(equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
r.squaredGLMM(m5)
# Out:
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m        R2c
# theoretical 0.18254972 0.5105761
# delta       0.07211197 0.2016911

# %%
stargazer(m1, m2, m3, m4, m5, type = "latex", dep.var.labels = "Self-promotion = True", 
          single.row=TRUE, ci = FALSE, star.cutoffs = c(0.05, 0.01, 0.001), report = "vc*")
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 09:41:07 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lccccc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{5}{c}{\textit{Dependent variable:}} \\
# \cline{2-6}
# \\[-1.8ex] & \multicolumn{3}{c}{Self-promotion = True} & \multicolumn{2}{c}{NA} \\
# \\[-1.8ex] & \multicolumn{3}{c}{\textit{logistic}} & \textit{logistic} & \textit{generalized linear} \\
#  & \multicolumn{3}{c}{\textit{}} & \textit{} & \textit{mixed-effects} \\
# \\[-1.8ex] & (1) & (2) & (3) & (4) & (5)\\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.298$^{***}$ & $-$0.318$^{***}$ & $-$0.284$^{***}$ & $-$0.311$^{***}$ & $-$0.348$^{***}$ \\
#   pub\_year2014 &  & 0.319$^{***}$ & 0.318$^{***}$ & 0.320$^{***}$ & 0.305$^{***}$ \\
#   pub\_year2015 &  & 0.635$^{***}$ & 0.653$^{***}$ & 0.656$^{***}$ & 0.607$^{***}$ \\
#   pub\_year2016 &  & 0.883$^{***}$ & 0.901$^{***}$ & 0.902$^{***}$ & 0.846$^{***}$ \\
#   pub\_year2017 &  & 1.233$^{***}$ & 1.257$^{***}$ & 1.252$^{***}$ & 1.178$^{***}$ \\
#   pub\_year2018 &  & 1.640$^{***}$ & 1.598$^{***}$ & 1.595$^{***}$ & 1.542$^{***}$ \\
#   authorship\_posfirst\_position &  & 0.275$^{***}$ & 0.315$^{***}$ & 0.339$^{***}$ & 0.361$^{***}$ \\
#   authorship\_posmiddle\_position &  & $-$0.618$^{***}$ & $-$0.649$^{***}$ & $-$0.584$^{***}$ & $-$0.638$^{***}$ \\
#   authorship\_possolo\_author &  & 0.912$^{***}$ & 0.938$^{***}$ & 0.686$^{***}$ & 0.828$^{***}$ \\
#   num\_authors &  & $-$0.001$^{***}$ & $-$0.001$^{***}$ & $-$0.001$^{***}$ & $-$0.002$^{***}$ \\
#   journal\_impact &  &  & 0.034$^{***}$ & 0.035$^{***}$ & 0.033$^{***}$ \\
#   affiliation\_cateinternational &  &  & 0.080$^{***}$ & 0.080$^{***}$ & 0.052$^{***}$ \\
#   affiliation\_rank\_cate &  &  & $-$0.048$^{***}$ & $-$0.053$^{***}$ & $-$0.048$^{***}$ \\
#   author\_pub\_count\_cate &  &  & 0.264$^{***}$ & 0.260$^{***}$ & 0.286$^{***}$ \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) &  &  & $-$0.024$^{***}$ & $-$0.021$^{***}$ & $-$0.021$^{***}$ \\
#   author\_citation\_log &  &  & $-$0.002$^{*}$ & $-$0.013$^{***}$ & $-$0.031$^{***}$ \\
#   Social\_Sciences &  &  &  & 0.843$^{***}$ & 0.898$^{***}$ \\
#   Materials\_Science &  &  &  & $-$0.189$^{***}$ & $-$0.144$^{***}$ \\
#   Engineering &  &  &  & $-$0.484$^{***}$ & $-$0.464$^{***}$ \\
#   Chemistry &  &  &  & $-$0.494$^{***}$ & $-$0.425$^{***}$ \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology &  &  &  & $-$0.156$^{***}$ & $-$0.167$^{***}$ \\
#   Medicine &  &  &  & $-$0.317$^{***}$ & $-$0.279$^{***}$ \\
#   Nursing &  &  &  & 0.248$^{***}$ & 0.259$^{***}$ \\
#   Agricultural\_and\_Biological\_Sciences &  &  &  & 0.482$^{***}$ & 0.490$^{***}$ \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics &  &  &  & $-$0.628$^{***}$ & $-$0.568$^{***}$ \\
#   Neuroscience &  &  &  & $-$0.112$^{***}$ & $-$0.108$^{***}$ \\
#   Business\_\_Management\_and\_Accounting &  &  &  & $-$0.200$^{***}$ & $-$0.181$^{***}$ \\
#   Economics\_\_Econometrics\_and\_Finance &  &  &  & $-$0.476$^{***}$ & $-$0.490$^{***}$ \\
#   Chemical\_Engineering &  &  &  & 0.078$^{***}$ & 0.067$^{***}$ \\
#   Physics\_and\_Astronomy &  &  &  & $-$0.847$^{***}$ & $-$0.728$^{***}$ \\
#   Computer\_Science &  &  &  & 0.107$^{***}$ & 0.134$^{***}$ \\
#   Decision\_Sciences &  &  &  & $-$0.781$^{***}$ & $-$0.779$^{***}$ \\
#   Health\_Professions &  &  &  & 0.942$^{***}$ & 0.905$^{***}$ \\
#   Psychology &  &  &  & $-$0.579$^{***}$ & $-$0.580$^{***}$ \\
#   Immunology\_and\_Microbiology &  &  &  & $-$0.170$^{***}$ & $-$0.175$^{***}$ \\
#   Dentistry &  &  &  & $-$1.390$^{***}$ & $-$1.263$^{***}$ \\
#   Earth\_and\_Planetary\_Sciences &  &  &  & $-$0.104$^{***}$ & $-$0.084$^{***}$ \\
#   Environmental\_Science &  &  &  & 0.161$^{***}$ & 0.168$^{***}$ \\
#   Mathematics &  &  &  & $-$0.211$^{***}$ & $-$0.242$^{***}$ \\
#   Arts\_and\_Humanities &  &  &  & $-$0.226$^{***}$ & $-$0.229$^{***}$ \\
#   Energy &  &  &  & $-$0.441$^{***}$ & $-$0.369$^{***}$ \\
#   Veterinary &  &  &  & $-$0.952$^{***}$ & $-$0.872$^{***}$ \\
#   General &  &  &  & 0.376$^{***}$ & 0.388$^{***}$ \\
#   Constant & $-$3.027$^{***}$ & $-$3.693$^{***}$ & $-$4.307$^{***}$ & $-$4.205$^{***}$ & $-$4.425$^{***}$ \\
#  \hline \\[-1.8ex]
# Observations & 11,396,752 & 11,396,752 & 11,396,752 & 11,396,752 & 11,396,752 \\
# Log Likelihood & $-$1,987,608.000 & $-$1,881,922.000 & $-$1,848,920.000 & $-$1,807,779.000 & $-$1,708,006.000 \\
# Akaike Inf. Crit. & 3,975,221.000 & 3,763,867.000 & 3,697,873.000 & 3,615,646.000 & 3,416,103.000 \\
# Bayesian Inf. Crit. &  &  &  &  & 3,416,744.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{5}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %% [markdown]
# ### SI - gender x location

# %%
base_str <- "self_promotion ~ 1 + gender * affiliation_cate + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_tw_loc <- glmer(equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_all_tw_loc)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.40664684
# 2  fixed    NA    genderFemale                                 -0.41226583
# 3  fixed    NA    affiliation_cateinternational                 0.02253202
# 4  fixed    NA    authorship_posfirst_position                  0.36090270
# 5  fixed    NA    authorship_posmiddle_position                -0.63794437
# 6  fixed    NA    authorship_possolo_author                     0.82749351
# 7  fixed    NA    author_pub_count_cate                         0.28638009
# 8  fixed    NA    I(author_pub_count_cate^2)                   -0.02064193
# 9  fixed    NA    affiliation_rank_cate                        -0.04757269
# 10 fixed    NA    num_authors                                  -0.00223791
# 11 fixed    NA    journal_impact                                0.03333125
# 12 fixed    NA    author_citation_log                          -0.03108767
# 13 fixed    NA    pub_year2014                                  0.30484274
# 14 fixed    NA    pub_year2015                                  0.60653587
# 15 fixed    NA    pub_year2016                                  0.84618512
# 16 fixed    NA    pub_year2017                                  1.17778367
# 17 fixed    NA    pub_year2018                                  1.54169999
# 18 fixed    NA    Social_Sciences                               0.89804480
# 19 fixed    NA    Materials_Science                            -0.14386027
# 20 fixed    NA    Engineering                                  -0.46310112
# 21 fixed    NA    Chemistry                                    -0.42487232
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.16767661
# 23 fixed    NA    Medicine                                     -0.27912038
# 24 fixed    NA    Nursing                                       0.25888860
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.49029097
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.56909254
# 27 fixed    NA    Neuroscience                                 -0.10832669
# 28 fixed    NA    Business__Management_and_Accounting          -0.18091645
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.48995631
# 30 fixed    NA    Chemical_Engineering                          0.06705615
# 31 fixed    NA    Physics_and_Astronomy                        -0.72687650
# 32 fixed    NA    Computer_Science                              0.13496771
# 33 fixed    NA    Decision_Sciences                            -0.77873325
# 34 fixed    NA    Health_Professions                            0.90501805
# 35 fixed    NA    Psychology                                   -0.57820470
# 36 fixed    NA    Immunology_and_Microbiology                  -0.17516164
# 37 fixed    NA    Dentistry                                    -1.26311350
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.08345836
# 39 fixed    NA    Environmental_Science                         0.16846047
# 40 fixed    NA    Mathematics                                  -0.24106319
# 41 fixed    NA    Arts_and_Humanities                          -0.22977843
# 42 fixed    NA    Energy                                       -0.36848430
# 43 fixed    NA    Veterinary                                   -0.87248531
# 44 fixed    NA    General                                       0.38652639
# 45 fixed    NA    genderFemale:affiliation_cateinternational    0.09991983
# 46 ran_pars doi   sd__(Intercept)                               1.48452813
#    std.error    statistic   p.value
# 1  1.159617e-02 -380.008698  0.000000e+00
# 2  6.236604e-03  -66.104215  0.000000e+00
# 3  4.784363e-03    4.709514  2.483083e-06
# 4  4.969984e-03   72.616466  0.000000e+00
# 5  4.395535e-03 -145.134635  0.000000e+00
# 6  9.972566e-03   82.976993  0.000000e+00
# 7  3.174041e-03   90.225701  0.000000e+00
# 8  2.614424e-04  -78.953996  0.000000e+00
# 9  6.852733e-04  -69.421483  0.000000e+00
# 10 7.904005e-05  -28.313623 2.348938e-176
# 11 2.869457e-04  116.158764  0.000000e+00
# 12 1.016068e-03  -30.596048 1.381460e-205
# 13 9.755993e-03   31.246716 2.474021e-214
# 14 9.185961e-03   66.028569  0.000000e+00
# 15 8.899366e-03   95.083750  0.000000e+00
# 16 8.685985e-03  135.595861  0.000000e+00
# 17 8.494249e-03  181.499274  0.000000e+00
# 18 9.037239e-03   99.371584  0.000000e+00
# 19 1.513663e-02   -9.504115  2.017568e-21
# 20 1.272783e-02  -36.384918 7.373073e-290
# 21 1.169644e-02  -36.324914 6.542742e-289
# 22 5.816178e-03  -28.829346 9.198871e-183
# 23 4.785353e-03  -58.328065  0.000000e+00
# 24 1.396719e-02   18.535476  1.068405e-76
# 25 6.657032e-03   73.650087  0.000000e+00
# 26 1.434968e-02  -39.658890  0.000000e+00
# 27 9.920650e-03  -10.919314  9.319720e-28
# 28 1.689546e-02  -10.707991  9.336574e-27
# 29 1.820364e-02  -26.915286 1.454768e-159
# 30 1.708839e-02    3.924077  8.706294e-05
# 31 1.268738e-02  -57.291292  0.000000e+00
# 32 1.314492e-02   10.267672  9.855458e-25
# 33 2.908528e-02  -26.774137 6.466322e-158
# 34 1.561161e-02   57.970819  0.000000e+00
# 35 1.328727e-02  -43.515685  0.000000e+00
# 36 1.083510e-02  -16.166133  8.741653e-59
# 37 5.294463e-02  -23.857255 8.514598e-126
# 38 1.169420e-02   -7.136729  9.557797e-13
# 39 8.779910e-03   19.187039  4.749414e-82
# 40 1.705664e-02  -14.133100  2.374577e-45
# 41 2.214279e-02  -10.377123  3.151286e-25
# 42 2.200338e-02  -16.746717  5.983917e-63
# 43 3.072140e-02  -28.399920 2.026738e-177
# 44 1.507071e-02   25.647519 4.506267e-145
# 45 7.674152e-03   13.020309  9.379046e-39
# 46           NA          NA            NA

# %%
stargazer(m_all_tw_loc, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:48:55 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.412$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.023$^{***}$ \\
#   & p = 0.00001 \\
#   authorship\_posfirst\_position & 0.361$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.638$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.827$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.286$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.021$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.048$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.002$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.033$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.031$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.305$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.607$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.846$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.178$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.542$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.898$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.144$^{***}$ \\
#   & p = 0.000 \\
#   Engineering & $-$0.463$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.425$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.168$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.279$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.259$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.490$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.569$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.108$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.181$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.490$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & 0.067$^{***}$ \\
#   & p = 0.0001 \\
#   Physics\_and\_Astronomy & $-$0.727$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.135$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.779$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.905$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.578$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.175$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.263$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.083$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.168$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.241$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.230$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.368$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.872$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.387$^{***}$ \\
#   & p = 0.000 \\
#   genderFemale:affiliation\_cateinternational & 0.100$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.407$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 11,396,752 \\
# Log Likelihood & $-$1,707,902.000 \\
# Akaike Inf. Crit. & 3,415,897.000 \\
# Bayesian Inf. Crit. & 3,416,552.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %%
r.squaredGLMM(m_all_tw_loc)
# Out:
# Warning message:
# “'r.squaredGLMM' now calculates a revised statistic. See the help page.”
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m        R2c
# theoretical 0.18260111 0.5105050
# delta       0.07212594 0.2016453

# %% [markdown]
# ### 1. Gender gap in overall self-promotion (without Tw control)

# %% [markdown]
# All tweets

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_tw <- glmer(equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_all_tw)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.425075143
# 2  fixed    NA    genderFemale                                 -0.348223403
# 3  fixed    NA    authorship_posfirst_position                  0.361379997
# 4  fixed    NA    authorship_posmiddle_position                -0.637938251
# 5  fixed    NA    authorship_possolo_author                     0.827767711
# 6  fixed    NA    author_pub_count_cate                         0.286002683
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.020620638
# 8  fixed    NA    affiliation_rank_cate                        -0.047512832
# 9  fixed    NA    affiliation_cateinternational                 0.051606361
# 10 fixed    NA    num_authors                                  -0.002237233
# 11 fixed    NA    journal_impact                                0.033319721
# 12 fixed    NA    author_citation_log                          -0.030984806
# 13 fixed    NA    pub_year2014                                  0.304855954
# 14 fixed    NA    pub_year2015                                  0.606516156
# 15 fixed    NA    pub_year2016                                  0.846187549
# 16 fixed    NA    pub_year2017                                  1.177779695
# 17 fixed    NA    pub_year2018                                  1.541697987
# 18 fixed    NA    Social_Sciences                               0.898171129
# 19 fixed    NA    Materials_Science                            -0.143916026
# 20 fixed    NA    Engineering                                  -0.463891597
# 21 fixed    NA    Chemistry                                    -0.425024176
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.167267858
# 23 fixed    NA    Medicine                                     -0.279206702
# 24 fixed    NA    Nursing                                       0.259188664
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.490338931
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.568402778
# 27 fixed    NA    Neuroscience                                 -0.107822276
# 28 fixed    NA    Business__Management_and_Accounting          -0.180547444
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.490159076
# 30 fixed    NA    Chemical_Engineering                          0.067005674
# 31 fixed    NA    Physics_and_Astronomy                        -0.727694529
# 32 fixed    NA    Computer_Science                              0.134350137
# 33 fixed    NA    Decision_Sciences                            -0.779380030
# 34 fixed    NA    Health_Professions                            0.904715605
# 35 fixed    NA    Psychology                                   -0.580132665
# 36 fixed    NA    Immunology_and_Microbiology                  -0.175027777
# 37 fixed    NA    Dentistry                                    -1.262818234
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.084198555
# 39 fixed    NA    Environmental_Science                         0.168319407
# 40 fixed    NA    Mathematics                                  -0.242357555
# 41 fixed    NA    Arts_and_Humanities                          -0.229495247
# 42 fixed    NA    Energy                                       -0.369353848
# 43 fixed    NA    Veterinary                                   -0.872300203
# 44 fixed    NA    General                                       0.387515065
# 45 ran_pars doi   sd__(Intercept)                               1.484913088
#    std.error    statistic   p.value
# 1  1.151645e-02 -384.239575  0.000000e+00
# 2  3.799982e-03  -91.638170  0.000000e+00
# 3  4.969704e-03   72.716610  0.000000e+00
# 4  4.395494e-03 -145.134584  0.000000e+00
# 5  9.972733e-03   83.003092  0.000000e+00
# 6  3.174216e-03   90.101822  0.000000e+00
# 7  2.614406e-04  -78.873120  0.000000e+00
# 8  6.852199e-04  -69.339537  0.000000e+00
# 9  4.239058e-03   12.174016  4.275201e-34
# 10 7.905595e-05  -28.299358 3.519338e-176
# 11 2.869560e-04  116.114398  0.000000e+00
# 12 1.016060e-03  -30.495046 3.031357e-204
# 13 9.756510e-03   31.246415 2.497434e-214
# 14 9.186459e-03   66.022848  0.000000e+00
# 15 8.899853e-03   95.078828  0.000000e+00
# 16 8.686459e-03  135.588013  0.000000e+00
# 17 8.494718e-03  181.489016  0.000000e+00
# 18 9.037725e-03   99.380225  0.000000e+00
# 19 1.513803e-02   -9.506918  1.963945e-21
# 20 1.272873e-02  -36.444461 8.419661e-291
# 21 1.169823e-02  -36.332352 4.992556e-289
# 22 5.816807e-03  -28.755958 7.629954e-182
# 23 4.785793e-03  -58.340744  0.000000e+00
# 24 1.396569e-02   18.558956  6.903336e-77
# 25 6.657994e-03   73.646651  0.000000e+00
# 26 1.435127e-02  -39.606451  0.000000e+00
# 27 9.921375e-03  -10.867675  1.643360e-27
# 28 1.689783e-02  -10.684651  1.201002e-26
# 29 1.820543e-02  -26.923786 1.156892e-159
# 30 1.709104e-02    3.920516  8.835967e-05
# 31 1.268804e-02  -57.352792  0.000000e+00
# 32 1.314608e-02   10.219783  1.617020e-24
# 33 2.908927e-02  -26.792694 3.931064e-158
# 34 1.561347e-02   57.944556  0.000000e+00
# 35 1.328651e-02  -43.663284  0.000000e+00
# 36 1.083676e-02  -16.151302  1.111901e-58
# 37 5.294609e-02  -23.851022 9.882163e-126
# 38 1.169516e-02   -7.199435  6.046263e-13
# 39 8.781001e-03   19.168589  6.772098e-82
# 40 1.705729e-02  -14.208448  8.120486e-46
# 41 2.214425e-02  -10.363649  3.628506e-25
# 42 2.200518e-02  -16.784862  3.149584e-63
# 43 3.072150e-02  -28.393807 2.411454e-177
# 44 1.507203e-02   25.710871 8.835375e-146
# 45           NA          NA            NA

# %%
MEs = ggemmeans(m_all_tw, terms=c('gender', 'pub_year'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="gender [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x      predicted  std.error   conf.low   conf.high  group
# 1  Male   0.02462171 0.008716538 0.02421474 0.02503534 2013
# 2  Male   0.03310707 0.007680173 0.03262858 0.03359233 2014
# 3  Male   0.04424832 0.006907478 0.04367929 0.04482441 2015
# 4  Male   0.05556626 0.006459304 0.05490561 0.05623439 2016
# 5  Male   0.07575889 0.006069873 0.07493008 0.07659611 2017
# 6  Male   0.10550519 0.005705154 0.10445456 0.10656514 2018
# 7  Female 0.01750824 0.009086367 0.01720451 0.01781723 2013
# 8  Female 0.02360141 0.008079836 0.02323922 0.02396911 2014
# 9  Female 0.03164851 0.007327173 0.03121134 0.03209160 2015
# 10 Female 0.03987811 0.006887576 0.03936444 0.04039819 2016
# 11 Female 0.05469990 0.006501843 0.05404469 0.05536258 2017
# 12 Female 0.07686518 0.006136368 0.07601611 0.07772294 2018

# %%
fname = paste(data_root, 'pred_all_tweet.csv', sep = '')
write.csv(MEs, fname, row.names = FALSE)

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_all_tw, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.2 by Marek Hlavac, Harvard University. E-mail: hlavac at fas.harvard.edu
# % Date and time: Thu, Oct 06, 2022 - 12:36:59 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.348$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.361$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.638$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.828$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.286$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.021$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.048$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.052$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.002$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.033$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.031$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.305$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.607$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.846$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.178$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.542$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.898$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.144$^{***}$ \\
#   & p = 0.000 \\
#   Engineering & $-$0.464$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.425$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.167$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.279$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.259$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.490$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.568$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.108$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.181$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.490$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & 0.067$^{***}$ \\
#   & p = 0.0001 \\
#   Physics\_and\_Astronomy & $-$0.728$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.134$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.779$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.905$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.580$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.175$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.263$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.084$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.168$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.242$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.229$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.369$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.872$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.388$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.425$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 11,396,752 \\
# Log Likelihood & $-$1,708,006.000 \\
# Akaike Inf. Crit. & 3,416,103.000 \\
# Bayesian Inf. Crit. & 3,416,744.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %% [markdown]
# Original tweets

# %%
base_str <- "self_promotion_original ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
            affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi)", keywords, sep = " "))
m_org <- glmer(formula = equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_org)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.495998397
# 2  fixed    NA    genderFemale                                 -0.375214975
# 3  fixed    NA    authorship_posfirst_position                  0.389046857
# 4  fixed    NA    authorship_posmiddle_position                -0.791566219
# 5  fixed    NA    authorship_possolo_author                     0.851814398
# 6  fixed    NA    author_pub_count_cate                         0.312382801
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.023830270
# 8  fixed    NA    affiliation_rank_cate                        -0.048430451
# 9  fixed    NA    affiliation_cateinternational                 0.090099054
# 10 fixed    NA    num_authors                                  -0.002013666
# 11 fixed    NA    journal_impact                                0.026494187
# 12 fixed    NA    author_citation_log                          -0.027267346
# 13 fixed    NA    pub_year2014                                  0.263910597
# 14 fixed    NA    pub_year2015                                  0.524263726
# 15 fixed    NA    pub_year2016                                  0.746810416
# 16 fixed    NA    pub_year2017                                  1.059076803
# 17 fixed    NA    pub_year2018                                  1.393230370
# 18 fixed    NA    Social_Sciences                               0.856708844
# 19 fixed    NA    Materials_Science                            -0.107734736
# 20 fixed    NA    Engineering                                  -0.399453813
# 21 fixed    NA    Chemistry                                    -0.382150300
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.128681975
# 23 fixed    NA    Medicine                                     -0.313130249
# 24 fixed    NA    Nursing                                       0.241024298
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.483316486
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.537786322
# 27 fixed    NA    Neuroscience                                 -0.080005604
# 28 fixed    NA    Business__Management_and_Accounting          -0.157075250
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.465285889
# 30 fixed    NA    Chemical_Engineering                          0.083897156
# 31 fixed    NA    Physics_and_Astronomy                        -0.672712327
# 32 fixed    NA    Computer_Science                              0.138969581
# 33 fixed    NA    Decision_Sciences                            -0.712779898
# 34 fixed    NA    Health_Professions                            0.785706958
# 35 fixed    NA    Psychology                                   -0.527658401
# 36 fixed    NA    Immunology_and_Microbiology                  -0.171419403
# 37 fixed    NA    Dentistry                                    -1.162290468
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.047217802
# 39 fixed    NA    Environmental_Science                         0.179850995
# 40 fixed    NA    Mathematics                                  -0.233585711
# 41 fixed    NA    Arts_and_Humanities                          -0.212839041
# 42 fixed    NA    Energy                                       -0.282654462
# 43 fixed    NA    Veterinary                                   -0.864186501
# 44 fixed    NA    General                                       0.431300003
# 45 ran_pars doi   sd__(Intercept)                               1.088422198
#    std.error    statistic   p.value
# 1  1.214685e-02 -370.137083  0.000000e+00
# 2  4.257129e-03  -88.138041  0.000000e+00
# 3  5.361844e-03   72.558407  0.000000e+00
# 4  4.897553e-03 -161.624835  0.000000e+00
# 5  9.881296e-03   86.204725  0.000000e+00
# 6  3.561664e-03   87.706974  0.000000e+00
# 7  2.964468e-04  -80.386340  0.000000e+00
# 8  7.357000e-04  -65.829073  0.000000e+00
# 9  4.421905e-03   20.375619  2.752124e-92
# 10 6.760717e-05  -29.784806 6.146184e-195
# 11 2.695364e-04   98.295395  0.000000e+00
# 12 1.115357e-03  -24.447185 5.391562e-132
# 13 9.840725e-03   26.818206 1.981981e-158
# 14 9.264914e-03   56.585923  0.000000e+00
# 15 8.949709e-03   83.445214  0.000000e+00
# 16 8.699721e-03  121.736875  0.000000e+00
# 17 8.485656e-03  164.186515  0.000000e+00
# 18 8.732247e-03   98.108634  0.000000e+00
# 19 1.505399e-02   -7.156555  8.272986e-13
# 20 1.260726e-02  -31.684427 2.546356e-220
# 21 1.170397e-02  -32.651327 7.673079e-234
# 22 5.788603e-03  -22.230229 1.752364e-109
# 23 4.811347e-03  -65.081622  0.000000e+00
# 24 1.401075e-02   17.202807  2.529725e-66
# 25 6.503760e-03   74.313400  0.000000e+00
# 26 1.476303e-02  -36.427908 1.539664e-290
# 27 9.883781e-03   -8.094636  5.743602e-16
# 28 1.632534e-02   -9.621561  6.483978e-22
# 29 1.767941e-02  -26.317954 1.194962e-152
# 30 1.691582e-02    4.959685  7.060750e-07
# 31 1.273747e-02  -52.813656  0.000000e+00
# 32 1.286104e-02   10.805471  3.242886e-27
# 33 2.834283e-02  -25.148506 1.467396e-139
# 34 1.540072e-02   51.017558  0.000000e+00
# 35 1.298341e-02  -40.640981  0.000000e+00
# 36 1.094618e-02  -15.660209  2.829666e-55
# 37 5.408309e-02  -21.490830 1.896891e-102
# 38 1.140934e-02   -4.138522  3.495500e-05
# 39 8.508593e-03   21.137572  3.590826e-99
# 40 1.687342e-02  -13.843412  1.394284e-43
# 41 2.145273e-02   -9.921304  3.363344e-23
# 42 2.143845e-02  -13.184466  1.078146e-39
# 43 3.212065e-02  -26.904392 1.951135e-159
# 44 1.408066e-02   30.630664 4.782113e-206
# 45           NA          NA            NA

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_org, terms=c('gender', 'pub_year'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="gender [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x      predicted  std.error   conf.low   conf.high  group
# 1  Male   0.02408541 0.008785418 0.02368397 0.02449348 2013
# 2  Male   0.03113302 0.007771325 0.03067685 0.03159575 2014
# 3  Male   0.04002107 0.006999128 0.03949734 0.04055145 2015
# 4  Male   0.04950268 0.006519188 0.04890492 0.05010735 2016
# 5  Male   0.06644085 0.006080920 0.06570541 0.06718394 2017
# 6  Male   0.09041826 0.005669784 0.08950848 0.09133636 2018
# 7  Female 0.01667574 0.009262735 0.01638064 0.01697606 2013
# 8  Female 0.02160321 0.008288187 0.02126251 0.02194925 2014
# 9  Female 0.02784883 0.007544628 0.02745128 0.02825198 2015
# 10 Female 0.03455044 0.007079812 0.03409055 0.03501631 2016
# 11 Female 0.04662341 0.006652952 0.04604722 0.04720645 2017
# 12 Female 0.06393885 0.006250020 0.06320960 0.06467594 2018

# %%
fname = paste(data_root, 'pred_original.csv', sep = '')
write.csv(MEs, fname, row.names = FALSE)

# %% [markdown]
# Retweets

# %%
base_str <- "self_promotion_retweet ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
            affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"

# %%
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_retweet <- glmer(formula = equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_retweet)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -5.650606787
# 2  fixed    NA    genderFemale                                 -0.280162154
# 3  fixed    NA    authorship_posfirst_position                  0.321284964
# 4  fixed    NA    authorship_posmiddle_position                -0.476481053
# 5  fixed    NA    authorship_possolo_author                     0.638180184
# 6  fixed    NA    author_pub_count_cate                         0.237947701
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.016752953
# 8  fixed    NA    affiliation_rank_cate                        -0.050509395
# 9  fixed    NA    affiliation_cateinternational                 0.042039049
# 10 fixed    NA    num_authors                                  -0.001843363
# 11 fixed    NA    journal_impact                                0.040455110
# 12 fixed    NA    author_citation_log                          -0.026667566
# 13 fixed    NA    pub_year2014                                  0.468969942
# 14 fixed    NA    pub_year2015                                  0.882987414
# 15 fixed    NA    pub_year2016                                  1.154876825
# 16 fixed    NA    pub_year2017                                  1.538880644
# 17 fixed    NA    pub_year2018                                  1.902935076
# 18 fixed    NA    Social_Sciences                               0.865171734
# 19 fixed    NA    Materials_Science                            -0.278041314
# 20 fixed    NA    Engineering                                  -0.672264445
# 21 fixed    NA    Chemistry                                    -0.627685398
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.218280471
# 23 fixed    NA    Medicine                                     -0.241052703
# 24 fixed    NA    Nursing                                       0.257804219
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.486373915
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.724725915
# 27 fixed    NA    Neuroscience                                 -0.167227648
# 28 fixed    NA    Business__Management_and_Accounting          -0.287812149
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.537986142
# 30 fixed    NA    Chemical_Engineering                          0.051883964
# 31 fixed    NA    Physics_and_Astronomy                        -1.002622585
# 32 fixed    NA    Computer_Science                              0.007564482
# 33 fixed    NA    Decision_Sciences                            -0.951714080
# 34 fixed    NA    Health_Professions                            1.131556582
# 35 fixed    NA    Psychology                                   -0.666941781
# 36 fixed    NA    Immunology_and_Microbiology                  -0.148154882
# 37 fixed    NA    Dentistry                                    -1.684312369
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.227152307
# 39 fixed    NA    Environmental_Science                         0.130051715
# 40 fixed    NA    Mathematics                                  -0.274192853
# 41 fixed    NA    Arts_and_Humanities                          -0.305475615
# 42 fixed    NA    Energy                                       -0.666600911
# 43 fixed    NA    Veterinary                                   -0.992265230
# 44 fixed    NA    General                                       0.324889114
# 45 ran_pars doi   sd__(Intercept)                               1.856317976
#    std.error    statistic    p.value
# 1  0.0181768047 -310.8690931  0.000000e+00
# 2  0.0053392034  -52.4726508  0.000000e+00
# 3  0.0073228872   43.8740832  0.000000e+00
# 4  0.0063446287  -75.0999114  0.000000e+00
# 5  0.0154091946   41.4155444  0.000000e+00
# 6  0.0045111050   52.7470991  0.000000e+00
# 7  0.0003697853  -45.3045366  0.000000e+00
# 8  0.0009756264  -51.7712489  0.000000e+00
# 9  0.0060792932    6.9151213  4.674633e-12
# 10 0.0001028801  -17.9175910  8.597127e-72
# 11 0.0003741624  108.1218008  0.000000e+00
# 12 0.0014330664  -18.6087445  2.729382e-77
# 13 0.0165197242   28.3884849 2.805304e-177
# 14 0.0153876644   57.3828094  0.000000e+00
# 15 0.0149142293   77.4345630  0.000000e+00
# 16 0.0145394992  105.8413792  0.000000e+00
# 17 0.0142716786  133.3364584  0.000000e+00
# 18 0.0132412472   65.3391421  0.000000e+00
# 19 0.0256645062  -10.8336904  2.383514e-27
# 20 0.0218302106  -30.7951425 3.043777e-208
# 21 0.0192873327  -32.5439192 2.552515e-232
# 22 0.0086187134  -25.3263406 1.638114e-141
# 23 0.0069831237  -34.5193232 4.115352e-261
# 24 0.0201009865   12.8254511  1.180972e-37
# 25 0.0098361866   49.4474065  0.000000e+00
# 26 0.0230109463  -31.4948332 1.022333e-217
# 27 0.0148278543  -11.2779398  1.686493e-29
# 28 0.0265925794  -10.8230249  2.677904e-27
# 29 0.0281975364  -19.0791895  3.760446e-81
# 30 0.0277240798    1.8714404  6.128406e-02
# 31 0.0222160833  -45.1304838  0.000000e+00
# 32 0.0210408870    0.3595134  7.192110e-01
# 33 0.0491390435  -19.3677779  1.443545e-83
# 34 0.0208028280   54.3943632  0.000000e+00
# 35 0.0200356768  -33.2877092 5.815382e-243
# 36 0.0158238604   -9.3627521  7.768628e-21
# 37 0.0991593557  -16.9859148  1.044128e-64
# 38 0.0183445265  -12.3825658  3.247905e-35
# 39 0.0131108085    9.9194275  3.427162e-23
# 40 0.0276781595   -9.9064699  3.901897e-23
# 41 0.0341382152   -8.9482011  3.613223e-19
# 42 0.0384384478  -17.3420351  2.265710e-67
# 43 0.0489792222  -20.2589013  2.965051e-91
# 44 0.0206201427   15.7559101  6.255234e-56
# 45           NA           NA            NA

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_retweet, terms=c('gender', 'pub_year'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="gender [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x      predicted   std.error   conf.low    conf.high   group
# 1  Male   0.006564572 0.014724795 0.006379017 0.006755487 2013
# 2  Male   0.010451411 0.012060050 0.010209758 0.010698722 2014
# 3  Male   0.015727463 0.010384550 0.015415477 0.016045660 2015
# 4  Male   0.020540447 0.009567684 0.020166550 0.020921127 2016
# 5  Male   0.029869255 0.008823401 0.029372192 0.030374466 2017
# 6  Male   0.042429855 0.008235942 0.041778829 0.043090569 2018
# 7  Female 0.004968562 0.015139531 0.004823996 0.005117437 2013
# 8  Female 0.007917946 0.012541558 0.007727173 0.008113390 2014
# 9  Female 0.011930480 0.010913058 0.011680956 0.012185270 2015
# 10 Female 0.015599912 0.010116342 0.015298334 0.015907339 2016
# 11 Female 0.022736976 0.009390763 0.022331577 0.023149560 2017
# 12 Female 0.032398478 0.008810530 0.031861486 0.032944213 2018

# %%
fname = paste(data_root, 'pred_retweet.csv', sep = '')
write.csv(MEs, fname, row.names = FALSE)

# %% [markdown]
# ### 2. Gender gap in who is active on Twitter (their matching)

# %%
base_str <- "is_active_on_twitter ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_ontw <- glmer(equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_ontw)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -5.842051612
# 2  fixed    NA    genderFemale                                 -0.133872233
# 3  fixed    NA    authorship_posfirst_position                  0.295021124
# 4  fixed    NA    authorship_posmiddle_position                -0.240523455
# 5  fixed    NA    authorship_possolo_author                     0.649601930
# 6  fixed    NA    author_pub_count_cate                         0.669910077
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.039330098
# 8  fixed    NA    affiliation_rank_cate                        -0.070999826
# 9  fixed    NA    affiliation_cateinternational                 0.117428093
# 10 fixed    NA    num_authors                                  -0.001351512
# 11 fixed    NA    journal_impact                                0.010842523
# 12 fixed    NA    author_citation_log                          -0.031287619
# 13 fixed    NA    pub_year2014                                  0.498215563
# 14 fixed    NA    pub_year2015                                  0.890654477
# 15 fixed    NA    pub_year2016                                  1.197454468
# 16 fixed    NA    pub_year2017                                  1.511248723
# 17 fixed    NA    pub_year2018                                  1.832136317
# 18 fixed    NA    Social_Sciences                               0.863247989
# 19 fixed    NA    Materials_Science                            -0.155667510
# 20 fixed    NA    Engineering                                  -0.411808491
# 21 fixed    NA    Chemistry                                    -0.451271395
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.153648153
# 23 fixed    NA    Medicine                                     -0.084475974
# 24 fixed    NA    Nursing                                       0.294282100
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.363888530
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.422928803
# 27 fixed    NA    Neuroscience                                 -0.104086727
# 28 fixed    NA    Business__Management_and_Accounting          -0.135163660
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.470315435
# 30 fixed    NA    Chemical_Engineering                         -0.009236815
# 31 fixed    NA    Physics_and_Astronomy                        -0.707731992
# 32 fixed    NA    Computer_Science                              0.178402871
# 33 fixed    NA    Decision_Sciences                            -0.630151665
# 34 fixed    NA    Health_Professions                            0.705679047
# 35 fixed    NA    Psychology                                   -0.447802210
# 36 fixed    NA    Immunology_and_Microbiology                  -0.196503943
# 37 fixed    NA    Dentistry                                    -1.041098487
# 38 fixed    NA    Earth_and_Planetary_Sciences                  0.008391614
# 39 fixed    NA    Environmental_Science                         0.228126473
# 40 fixed    NA    Mathematics                                  -0.261786518
# 41 fixed    NA    Arts_and_Humanities                          -0.250623104
# 42 fixed    NA    Energy                                       -0.369220253
# 43 fixed    NA    Veterinary                                   -0.594837907
# 44 fixed    NA    General                                       0.099656640
# 45 ran_pars doi   sd__(Intercept)                               1.020575254
#    std.error    statistic    p.value
# 1  1.166827e-02 -500.6786298  0.000000e+00
# 2  3.205392e-03  -41.7647001  0.000000e+00
# 3  4.571097e-03   64.5405538  0.000000e+00
# 4  3.582538e-03  -67.1377286  0.000000e+00
# 5  9.183880e-03   70.7328407  0.000000e+00
# 6  3.355295e-03  199.6575736  0.000000e+00
# 7  2.635286e-04 -149.2441080  0.000000e+00
# 8  5.827622e-04 -121.8332716  0.000000e+00
# 9  3.480081e-03   33.7429182 1.357961e-249
# 10 3.937613e-05  -34.3231345 3.545632e-258
# 11 2.489599e-04   43.5512778  0.000000e+00
# 12 8.976373e-04  -34.8555253 3.511307e-266
# 13 8.618499e-03   57.8076938  0.000000e+00
# 14 8.066219e-03  110.4178450  0.000000e+00
# 15 7.808158e-03  153.3594107  0.000000e+00
# 16 7.664712e-03  197.1696733  0.000000e+00
# 17 7.515900e-03  243.7680381  0.000000e+00
# 18 7.611617e-03  113.4119031  0.000000e+00
# 19 1.245671e-02  -12.4966743  7.784009e-36
# 20 1.033136e-02  -39.8600572  0.000000e+00
# 21 9.633529e-03  -46.8438300  0.000000e+00
# 22 4.579964e-03  -33.5478960 9.662008e-247
# 23 3.732068e-03  -22.6351671 1.953227e-113
# 24 1.061396e-02   27.7259585 3.397492e-169
# 25 5.447193e-03   66.8029450  0.000000e+00
# 26 1.070860e-02  -39.4943227  0.000000e+00
# 27 7.685774e-03  -13.5427783  8.741898e-42
# 28 1.434999e-02   -9.4190761  4.550747e-21
# 29 1.579645e-02  -29.7734924 8.611793e-195
# 30 1.439991e-02   -0.6414494  5.212308e-01
# 31 1.012020e-02  -69.9326339  0.000000e+00
# 32 1.065778e-02   16.7392073  6.788621e-63
# 33 2.354870e-02  -26.7595132 9.569673e-158
# 34 1.265051e-02   55.7826763  0.000000e+00
# 35 1.069445e-02  -41.8724090  0.000000e+00
# 36 8.539137e-03  -23.0121541 3.522408e-117
# 37 3.796559e-02  -27.4221609 1.492745e-165
# 38 9.227711e-03    0.9093928  3.631428e-01
# 39 7.120363e-03   32.0386004 3.164463e-225
# 40 1.407545e-02  -18.5988004  3.285786e-77
# 41 1.996122e-02  -12.5554990  3.708362e-36
# 42 1.861611e-02  -19.8333687  1.534129e-87
# 43 2.237542e-02  -26.5844353 1.027432e-155
# 44 1.336935e-02    7.4541147  9.047323e-14
# 45           NA           NA            NA

# %%
r.squaredGLMM(m_ontw)
# Out:
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m        R2c
# theoretical 0.23629542 0.4199421
# delta       0.08458409 0.1503221

# %%
MEs = ggemmeans(m_ontw, terms=c('gender', 'pub_year'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="gender [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x      predicted  std.error   conf.low   conf.high  group
# 1  Male   0.02311103 0.007862319 0.02276566 0.02346150 2013
# 2  Male   0.03747638 0.006491341 0.03702014 0.03793803 2014
# 3  Male   0.05450538 0.005713752 0.05393113 0.05508539 2015
# 4  Male   0.07265465 0.005295617 0.07195843 0.07335707 2016
# 5  Male   0.09684220 0.005007077 0.09598725 0.09770394 2017
# 6  Male   0.12876453 0.004740085 0.12772589 0.12981037 2018
# 7  Female 0.02027397 0.008108874 0.01996068 0.02059207 2013
# 8  Female 0.03293532 0.006772964 0.03251512 0.03336076 2014
# 9  Female 0.04800380 0.006013468 0.04746804 0.04854530 2015
# 10 Female 0.06413500 0.005600334 0.06347932 0.06479699 2016
# 11 Female 0.08574853 0.005312258 0.08493580 0.08656830 2017
# 12 Female 0.11447755 0.005043169 0.11347935 0.11548338 2018

# %%
fname = paste(data_root, 'pred_gender_on_tw.csv', sep = '')
write.csv(MEs, fname, row.names = FALSE)

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_ontw, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Tue, Nov 29, 2022 - 12:43:10 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & is\_active\_on\_twitter \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.134$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.295$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.241$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.650$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.670$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.039$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.071$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.117$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.001$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.011$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.031$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.498$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.891$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 1.197$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.511$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.832$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.863$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.156$^{***}$ \\
#   & p = 0.000 \\
#   Engineering & $-$0.412$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.451$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.154$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.084$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.294$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.364$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.423$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.104$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.135$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.470$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & $-$0.009 \\
#   & p = 0.522 \\
#   Physics\_and\_Astronomy & $-$0.708$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.178$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.630$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.706$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.448$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.197$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.041$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & 0.008 \\
#   & p = 0.364 \\
#   Environmental\_Science & 0.228$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.262$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.251$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.369$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.595$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.100$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$5.842$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 11,396,752 \\
# Log Likelihood & $-$2,110,867.000 \\
# Akaike Inf. Crit. & 4,221,824.000 \\
# Bayesian Inf. Crit. & 4,222,465.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %% [markdown]
# ### 3. Gap among subset of observations where the author is active on Twitter (their matching)

# %%
nrow(mydata[mydata$is_active_on_twitter == 'True', ])
# Out:
# [1] 618742

# %%
# remove quadratic term for pub cate
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_on_tw <- glmer(formula = equation, data = mydata[mydata$is_active_on_twitter == 'True', ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_on_tw)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                   0.311811655
# 2  fixed    NA    genderFemale                                 -0.188533590
# 3  fixed    NA    authorship_posfirst_position                  0.332898629
# 4  fixed    NA    authorship_posmiddle_position                -0.741090466
# 5  fixed    NA    authorship_possolo_author                     0.375352091
# 6  fixed    NA    author_pub_count_cate                        -0.109233173
# 7  fixed    NA    affiliation_rank_cate                         0.005031903
# 8  fixed    NA    affiliation_cateinternational                 0.243482105
# 9  fixed    NA    num_authors                                  -0.002438394
# 10 fixed    NA    journal_impact                                0.022156645
# 11 fixed    NA    author_citation_log                          -0.022154911
# 12 fixed    NA    pub_year2014                                  0.080230136
# 13 fixed    NA    pub_year2015                                  0.170981771
# 14 fixed    NA    pub_year2016                                  0.225740393
# 15 fixed    NA    pub_year2017                                  0.438493474
# 16 fixed    NA    pub_year2018                                  0.650446217
# 17 fixed    NA    Social_Sciences                               0.321580805
# 18 fixed    NA    Materials_Science                             0.057339422
# 19 fixed    NA    Engineering                                  -0.098761010
# 20 fixed    NA    Chemistry                                    -0.038329385
# 21 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.095440854
# 22 fixed    NA    Medicine                                     -0.395856842
# 23 fixed    NA    Nursing                                      -0.026301724
# 24 fixed    NA    Agricultural_and_Biological_Sciences          0.371493047
# 25 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.268013958
# 26 fixed    NA    Neuroscience                                 -0.029834985
# 27 fixed    NA    Business__Management_and_Accounting          -0.088399317
# 28 fixed    NA    Economics__Econometrics_and_Finance          -0.167165307
# 29 fixed    NA    Chemical_Engineering                          0.122227748
# 30 fixed    NA    Physics_and_Astronomy                        -0.234504717
# 31 fixed    NA    Computer_Science                             -0.065310088
# 32 fixed    NA    Decision_Sciences                            -0.312335315
# 33 fixed    NA    Health_Professions                            0.519092567
# 34 fixed    NA    Psychology                                   -0.348536951
# 35 fixed    NA    Immunology_and_Microbiology                   0.030888947
# 36 fixed    NA    Dentistry                                    -0.698434648
# 37 fixed    NA    Earth_and_Planetary_Sciences                 -0.092513628
# 38 fixed    NA    Environmental_Science                         0.122271457
# 39 fixed    NA    Mathematics                                   0.132859761
# 40 fixed    NA    Arts_and_Humanities                           0.008049614
# 41 fixed    NA    Energy                                       -0.031369448
# 42 fixed    NA    Veterinary                                   -0.615759612
# 43 fixed    NA    General                                       0.507237113
# 44 ran_pars doi   sd__(Intercept)                               0.929031561
#    std.error    statistic   p.value
# 1  0.0214723587  14.5215371  8.850312e-48
# 2  0.0068740473 -27.4268682 1.311736e-165
# 3  0.0096221909  34.5969678 2.806152e-262
# 4  0.0075423733 -98.2569327  0.000000e+00
# 5  0.0183198179  20.4888549  2.706849e-93
# 6  0.0032394346 -33.7198270 2.961115e-249
# 7  0.0011773508   4.2739202  1.920658e-05
# 8  0.0069903289  34.8312803 8.178121e-266
# 9  0.0001561743 -15.6132822  5.911597e-55
# 10 0.0004889344  45.3161965  0.000000e+00
# 11 0.0019223666 -11.5248105  9.892961e-31
# 12 0.0194069359   4.1340960  3.563545e-05
# 13 0.0180379842   9.4789844  2.567699e-21
# 14 0.0174022840  12.9718831  1.766368e-38
# 15 0.0170043181  25.7871837 1.234709e-146
# 16 0.0166702198  39.0184548  0.000000e+00
# 17 0.0139900038  22.9864703 6.365975e-117
# 18 0.0277770248   2.0642751  3.899164e-02
# 19 0.0220607369  -4.4767775  7.577816e-06
# 20 0.0206859597  -1.8529179  6.389413e-02
# 21 0.0093738150 -10.1816447  2.394791e-24
# 22 0.0074025088 -53.4760378  0.000000e+00
# 23 0.0205220767  -1.2816307  1.999722e-01
# 24 0.0107085472  34.6912649 1.066989e-263
# 25 0.0230595599 -11.6226832  3.160517e-31
# 26 0.0154241438  -1.9343041  5.307575e-02
# 27 0.0275631905  -3.2071511  1.340566e-03
# 28 0.0304614198  -5.4877713  4.070365e-08
# 29 0.0307633739   3.9731581  7.092593e-05
# 30 0.0227518697 -10.3070525  6.547873e-25
# 31 0.0215961919  -3.0241484  2.493341e-03
# 32 0.0464153682  -6.7291358  1.706737e-11
# 33 0.0230950837  22.4763233 7.076306e-112
# 34 0.0200998639 -17.3402643  2.336602e-67
# 35 0.0176158389   1.7534758  7.952037e-02
# 36 0.0920591910  -7.5867998  3.279032e-14
# 37 0.0182545102  -5.0679874  4.020439e-07
# 38 0.0135421336   9.0289655  1.733022e-19
# 39 0.0297415589   4.4671418  7.927159e-06
# 40 0.0387277621   0.2078513  8.353451e-01
# 41 0.0382109406  -0.8209546  4.116721e-01
# 42 0.0511887614 -12.0291954  2.495813e-33
# 43 0.0246216691  20.6012481  2.674607e-94
# 44           NA          NA            NA

# %%
r.squaredGLMM(m_on_tw)
# Out:
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m       R2c
# theoretical 0.1391187 0.3180333
# delta       0.1196608 0.2735515

# %%
MEs = ggemmeans(m_on_tw, terms=c('gender', 'pub_year'), typical='median')

# %%
MEs
# Out:
#    x      predicted std.error   conf.low  conf.high group
# 1  Male   0.4108908 0.017164471 0.4027726 0.4190578 2013
# 2  Male   0.4304405 0.013401594 0.4240131 0.4368915 2014
# 3  Male   0.4528152 0.011292428 0.4473373 0.4583046 2015
# 4  Male   0.4664147 0.010174301 0.4614554 0.4713807 2016
# 5  Male   0.5195424 0.009353608 0.5149647 0.5241168 2017
# 6  Male   0.5720358 0.008731704 0.5678411 0.5762202 2018
# 7  Female 0.3661387 0.017902777 0.3580342 0.3743198 2013
# 8  Female 0.3849506 0.014266244 0.3783520 0.3915917 2014
# 9  Female 0.4066489 0.012224163 0.4008812 0.4124426 2015
# 10 Female 0.4199260 0.011116018 0.4146283 0.4252421 2016
# 11 Female 0.4724469 0.010301568 0.4674175 0.4774818 2017
# 12 Female 0.5253853 0.009648514 0.5206676 0.5300984 2018

# %%
fname = paste(data_root, 'pred_on_tweet_subset.csv', sep = '')
write.csv(MEs, fname, row.names=FALSE)

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_on_tw, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Thu, Nov 24, 2022 - 12:26:36 AM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.189$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.333$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.741$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.375$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & $-$0.109$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & 0.005$^{***}$ \\
#   & p = 0.00002 \\
#   affiliation\_cateinternational & 0.243$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.002$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.022$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.022$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.080$^{***}$ \\
#   & p = 0.00004 \\
#   pub\_year2015 & 0.171$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.226$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 0.438$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 0.650$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.322$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & 0.057$^{*}$ \\
#   & p = 0.039 \\
#   Engineering & $-$0.099$^{***}$ \\
#   & p = 0.00001 \\
#   Chemistry & $-$0.038 \\
#   & p = 0.064 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.095$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.396$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & $-$0.026 \\
#   & p = 0.200 \\
#   Agricultural\_and\_Biological\_Sciences & 0.371$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.268$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.030 \\
#   & p = 0.054 \\
#   Business\_\_Management\_and\_Accounting & $-$0.088$^{**}$ \\
#   & p = 0.002 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.167$^{***}$ \\
#   & p = 0.00000 \\
#   Chemical\_Engineering & 0.122$^{***}$ \\
#   & p = 0.0001 \\
#   Physics\_and\_Astronomy & $-$0.235$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & $-$0.065$^{**}$ \\
#   & p = 0.003 \\
#   Decision\_Sciences & $-$0.312$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.519$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.349$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & 0.031 \\
#   & p = 0.080 \\
#   Dentistry & $-$0.698$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.093$^{***}$ \\
#   & p = 0.00000 \\
#   Environmental\_Science & 0.122$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & 0.133$^{***}$ \\
#   & p = 0.00001 \\
#   Arts\_and\_Humanities & 0.008 \\
#   & p = 0.836 \\
#   Energy & $-$0.031 \\
#   & p = 0.412 \\
#   Veterinary & $-$0.616$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.507$^{***}$ \\
#   & p = 0.000 \\
#   Constant & 0.312$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 618,742 \\
# Log Likelihood & $-$379,665.700 \\
# Akaike Inf. Crit. & 759,419.300 \\
# Bayesian Inf. Crit. & 759,918.100 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Gender x Journal Impact (all tweets)

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender * journal_impact + authorship_pos + author_pub_count_cate + \
            I(author_pub_count_cate^2) + affiliation_rank_cate + affiliation_cate + num_authors + \
            author_citation_log + pub_year"

# %%
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_x_jif_1 <- glmer(formula = equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_x_jif_1)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.446969704
# 2  fixed    NA    genderFemale                                 -0.274572366
# 3  fixed    NA    journal_impact                                0.036234859
# 4  fixed    NA    authorship_posfirst_position                  0.359101808
# 5  fixed    NA    authorship_posmiddle_position                -0.638217030
# 6  fixed    NA    authorship_possolo_author                     0.826967311
# 7  fixed    NA    author_pub_count_cate                         0.287843159
# 8  fixed    NA    I(author_pub_count_cate^2)                   -0.020794985
# 9  fixed    NA    affiliation_rank_cate                        -0.047520374
# 10 fixed    NA    affiliation_cateinternational                 0.050943702
# 11 fixed    NA    num_authors                                  -0.002236436
# 12 fixed    NA    author_citation_log                          -0.031195339
# 13 fixed    NA    pub_year2014                                  0.304826332
# 14 fixed    NA    pub_year2015                                  0.606447555
# 15 fixed    NA    pub_year2016                                  0.846169909
# 16 fixed    NA    pub_year2017                                  1.177673367
# 17 fixed    NA    pub_year2018                                  1.541345965
# 18 fixed    NA    Social_Sciences                               0.893105731
# 19 fixed    NA    Materials_Science                            -0.144790057
# 20 fixed    NA    Engineering                                  -0.462446619
# 21 fixed    NA    Chemistry                                    -0.424641707
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.167191420
# 23 fixed    NA    Medicine                                     -0.279548974
# 24 fixed    NA    Nursing                                       0.251751429
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.490649353
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.568634942
# 27 fixed    NA    Neuroscience                                 -0.107547269
# 28 fixed    NA    Business__Management_and_Accounting          -0.177326887
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.482652322
# 30 fixed    NA    Chemical_Engineering                          0.066746787
# 31 fixed    NA    Physics_and_Astronomy                        -0.724768465
# 32 fixed    NA    Computer_Science                              0.137683566
# 33 fixed    NA    Decision_Sciences                            -0.774438717
# 34 fixed    NA    Health_Professions                            0.903359456
# 35 fixed    NA    Psychology                                   -0.581219214
# 36 fixed    NA    Immunology_and_Microbiology                  -0.175273526
# 37 fixed    NA    Dentistry                                    -1.261308759
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.081801770
# 39 fixed    NA    Environmental_Science                         0.169003505
# 40 fixed    NA    Mathematics                                  -0.238039478
# 41 fixed    NA    Arts_and_Humanities                          -0.227084683
# 42 fixed    NA    Energy                                       -0.369561430
# 43 fixed    NA    Veterinary                                   -0.874866943
# 44 fixed    NA    General                                       0.379013117
# 45 fixed    NA    genderFemale:journal_impact                  -0.010679943
# 46 ran_pars doi   sd__(Intercept)                               1.484168823
#    std.error    statistic   p.value
# 1  1.154638e-02 -385.139642  0.000000e+00
# 2  4.604832e-03  -59.627016  0.000000e+00
# 3  3.049132e-04  118.836619  0.000000e+00
# 4  4.970378e-03   72.248397  0.000000e+00
# 5  4.395717e-03 -145.190651  0.000000e+00
# 6  9.972120e-03   82.927932  0.000000e+00
# 7  3.175099e-03   90.656438  0.000000e+00
# 8  2.615752e-04  -79.499062  0.000000e+00
# 9  6.852678e-04  -69.345702  0.000000e+00
# 10 4.238926e-03   12.018068  2.855704e-33
# 11 7.903219e-05  -28.297789 3.679288e-176
# 12 1.016331e-03  -30.694087 6.825740e-207
# 13 9.755560e-03   31.246421 2.496936e-214
# 14 9.185369e-03   66.023209  0.000000e+00
# 15 8.898743e-03   95.088703  0.000000e+00
# 16 8.685390e-03  135.592458  0.000000e+00
# 17 8.493712e-03  181.469071  0.000000e+00
# 18 9.035898e-03   98.839731  0.000000e+00
# 19 1.514086e-02   -9.562868  1.145380e-21
# 20 1.273057e-02  -36.325693 6.360036e-289
# 21 1.169774e-02  -36.301178 1.550157e-288
# 22 5.815907e-03  -28.747263 9.799986e-182
# 23 4.784115e-03  -58.432746  0.000000e+00
# 24 1.396190e-02   18.031313  1.106334e-72
# 25 6.656537e-03   73.709405  0.000000e+00
# 26 1.434747e-02  -39.633109  0.000000e+00
# 27 9.918393e-03  -10.843215  2.147879e-27
# 28 1.689316e-02  -10.496964  8.920266e-26
# 29 1.820197e-02  -26.516494 6.255743e-155
# 30 1.709043e-02    3.905507  9.402804e-05
# 31 1.268954e-02  -57.115443  0.000000e+00
# 32 1.314531e-02   10.473972  1.137672e-25
# 33 2.908192e-02  -26.629561 3.087273e-156
# 34 1.560522e-02   57.888303  0.000000e+00
# 35 1.328074e-02  -43.764057  0.000000e+00
# 36 1.083328e-02  -16.179167  7.074459e-59
# 37 5.293940e-02  -23.825521 1.816851e-125
# 38 1.169317e-02   -6.995689  2.639590e-12
# 39 8.778915e-03   19.251069  1.382800e-82
# 40 1.705827e-02  -13.954495  2.953877e-44
# 41 2.213459e-02  -10.259265  1.075215e-24
# 42 2.200683e-02  -16.793035  2.744447e-63
# 43 3.071797e-02  -28.480624 2.035868e-178
# 44 1.509238e-02   25.112882 3.597174e-139
# 45 3.850486e-04  -27.736610 2.527592e-169
# 46           NA          NA            NA

# %%
MEs = ggemmeans(m_x_jif_1, terms=c('journal_impact [0:40 by=5]', 'gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="journal_impact [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x  predicted  std.error   conf.low   conf.high  group
# 1   0 0.04425078 0.005161337 0.04382492 0.04468060 Male
# 2   0 0.03398714 0.005950657 0.03360630 0.03437215 Female
# 3   5 0.05257793 0.004830762 0.05210829 0.05305158 Male
# 4   5 0.03844141 0.005414385 0.03805107 0.03883560 Female
# 5  10 0.06236983 0.004968072 0.06180282 0.06294170 Male
# 6  10 0.04345318 0.005612115 0.04299827 0.04391268 Female
# 7  15 0.07384320 0.005538575 0.07310422 0.07458905 Male
# 8  15 0.04908501 0.006476967 0.04849586 0.04968094 Female
# 9  20 0.08723082 0.006427947 0.08623291 0.08823917 Male
# 10 20 0.05540447 0.007789826 0.05461084 0.05620895 Female
# 11 25 0.10277625 0.007523947 0.10142435 0.10414408 Male
# 12 25 0.06248408 0.009364117 0.06141754 0.06356789 Female
# 13 30 0.12072561 0.008749267 0.11891712 0.12255779 Male
# 14 30 0.07040090 0.011089049 0.06899173 0.07183663 Female
# 15 35 0.14131601 0.010056747 0.13894105 0.14372479 Male
# 16 35 0.07923602 0.012904353 0.07741030 0.08110102 Female
# 17 40 0.16476016 0.011418199 0.16170351 0.16786301 Male
# 18 40 0.08907368 0.014776761 0.08675152 0.09145177 Female

# %%
write.csv(MEs, paste(data_root, "gender_jif_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# ### Gender x Affiliation rank (all tweets)

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender * affiliation_rank_cate + authorship_pos + author_pub_count_cate + \
            I(author_pub_count_cate^2) + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"

# %%
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_x_affi_1 <- glmer(formula = equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_x_affi_1)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.422724602
# 2  fixed    NA    genderFemale                                 -0.356963538
# 3  fixed    NA    affiliation_rank_cate                        -0.048167163
# 4  fixed    NA    authorship_posfirst_position                  0.361373332
# 5  fixed    NA    authorship_posmiddle_position                -0.637952072
# 6  fixed    NA    authorship_possolo_author                     0.827763583
# 7  fixed    NA    author_pub_count_cate                         0.286187861
# 8  fixed    NA    I(author_pub_count_cate^2)                   -0.020637995
# 9  fixed    NA    affiliation_cateinternational                 0.051566808
# 10 fixed    NA    num_authors                                  -0.002237177
# 11 fixed    NA    journal_impact                                0.033318749
# 12 fixed    NA    author_citation_log                          -0.031000381
# 13 fixed    NA    pub_year2014                                  0.304860252
# 14 fixed    NA    pub_year2015                                  0.606517915
# 15 fixed    NA    pub_year2016                                  0.846184954
# 16 fixed    NA    pub_year2017                                  1.177783797
# 17 fixed    NA    pub_year2018                                  1.541697054
# 18 fixed    NA    Social_Sciences                               0.898074536
# 19 fixed    NA    Materials_Science                            -0.143877010
# 20 fixed    NA    Engineering                                  -0.463840400
# 21 fixed    NA    Chemistry                                    -0.425036174
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.167329574
# 23 fixed    NA    Medicine                                     -0.279144960
# 24 fixed    NA    Nursing                                       0.258967758
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.490378002
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.568480957
# 27 fixed    NA    Neuroscience                                 -0.107871652
# 28 fixed    NA    Business__Management_and_Accounting          -0.180565479
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.489987943
# 30 fixed    NA    Chemical_Engineering                          0.066950562
# 31 fixed    NA    Physics_and_Astronomy                        -0.727814139
# 32 fixed    NA    Computer_Science                              0.134443955
# 33 fixed    NA    Decision_Sciences                            -0.779241471
# 34 fixed    NA    Health_Professions                            0.904796517
# 35 fixed    NA    Psychology                                   -0.580041309
# 36 fixed    NA    Immunology_and_Microbiology                  -0.175077567
# 37 fixed    NA    Dentistry                                    -1.262858243
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.084142894
# 39 fixed    NA    Environmental_Science                         0.168381062
# 40 fixed    NA    Mathematics                                  -0.242411981
# 41 fixed    NA    Arts_and_Humanities                          -0.229427041
# 42 fixed    NA    Energy                                       -0.369238724
# 43 fixed    NA    Veterinary                                   -0.872289242
# 44 fixed    NA    General                                       0.387386298
# 45 fixed    NA    genderFemale:affiliation_rank_cate            0.002207616
# 46 ran_pars doi   sd__(Intercept)                               1.484923745
#    std.error    statistic   p.value
# 1  0.0115978429 -381.340276  0.000000e+00
# 2  0.0063639173  -56.091794  0.000000e+00
# 3  0.0007846050  -61.390334  0.000000e+00
# 4  0.0049697211   72.715013  0.000000e+00
# 5  0.0043955279 -145.136623  0.000000e+00
# 6  0.0099727492   83.002547  0.000000e+00
# 7  0.0031760304   90.108667  0.000000e+00
# 8  0.0002616367  -78.880357  0.000000e+00
# 9  0.0042391094   12.164538  4.801538e-34
# 10 0.0000790557  -28.298742 3.581270e-176
# 11 0.0002869588  116.109890  0.000000e+00
# 12 0.0010160976  -30.509255 1.964304e-204
# 13 0.0097565501   31.246727 2.473224e-214
# 14 0.0091864983   66.022754  0.000000e+00
# 15 0.0088998899   95.078138  0.000000e+00
# 16 0.0086864959  135.587906  0.000000e+00
# 17 0.0084947549  181.488115  0.000000e+00
# 18 0.0090378474   99.368190  0.000000e+00
# 19 0.0151381669   -9.504256  2.014835e-21
# 20 0.0127288358  -36.440128 9.861134e-291
# 21 0.0116982103  -36.333436 4.799532e-289
# 22 0.0058169281  -28.765969 5.719114e-182
# 23 0.0047859192  -58.326301  0.000000e+00
# 24 0.0139661864   18.542482  9.379181e-77
# 25 0.0066580405   73.652000  0.000000e+00
# 26 0.0143512718  -39.611887  0.000000e+00
# 27 0.0099214500  -10.872569  1.557522e-27
# 28 0.0168977255  -10.685786  1.186397e-26
# 29 0.0182057062  -26.913976 1.507059e-159
# 30 0.0170911839    3.917257  8.956220e-05
# 31 0.0126884039  -57.360575  0.000000e+00
# 32 0.0131462397   10.226799  1.504085e-24
# 33 0.0290895423  -26.787684 4.496560e-158
# 34 0.0156132981   57.950377  0.000000e+00
# 35 0.0132865006  -43.656439  0.000000e+00
# 36 0.0108367572  -16.155900  1.032011e-58
# 37 0.0529462480  -23.851704 9.722371e-126
# 38 0.0116953274   -7.194574  6.265624e-13
# 39 0.0087810974   19.175401  5.940899e-82
# 40 0.0170575177  -14.211445  7.780292e-46
# 41 0.0221442418  -10.360573  3.747092e-25
# 42 0.0220054585  -16.779415  3.452193e-63
# 43 0.0307214338  -28.393507 2.432107e-177
# 44 0.0150723696   25.701751 1.117356e-145
# 45 0.0012886975    1.713060  8.670153e-02
# 46           NA          NA            NA

# %%
MEs = ggemmeans(m_x_affi_1, terms=c('affiliation_rank_cate', 'gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="affiliation_rank_cate [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x predicted  std.error   conf.low   conf.high  group
# 1  0 0.06063785 0.005771201 0.05999674 0.06128537 Male
# 2  0 0.04322103 0.006969604 0.04265965 0.04378945 Female
# 3  1 0.05795157 0.005389575 0.05737757 0.05853096 Male
# 4  1 0.04135986 0.006319545 0.04087154 0.04185376 Female
# 5  2 0.05537729 0.005100930 0.05485662 0.05590260 Male
# 6  2 0.03957553 0.005820682 0.03914418 0.04001144 Female
# 7  3 0.05291093 0.004921652 0.05242962 0.05339640 Male
# 8  3 0.03786513 0.005514206 0.03747336 0.03826084 Female
# 9  4 0.05054854 0.004863851 0.05009297 0.05100802 Male
# 10 4 0.03622587 0.005432773 0.03585594 0.03659947 Female
# 11 5 0.04828624 0.004931799 0.04784397 0.04873239 Male
# 12 5 0.03465502 0.005586234 0.03429059 0.03502317 Female
# 13 6 0.04612028 0.005120492 0.04568077 0.04656381 Male
# 14 6 0.03314994 0.005956461 0.03277779 0.03352616 Female
# 15 7 0.04404698 0.005417329 0.04360206 0.04449623 Male
# 16 7 0.03170808 0.006506557 0.03131887 0.03210196 Female
# 17 8 0.04206278 0.005805746 0.04160666 0.04252367 Male
# 18 8 0.03032696 0.007195385 0.02991498 0.03074444 Female
# 19 9 0.04016420 0.006268741 0.03969321 0.04064054 Male
# 20 9 0.02900421 0.007987132 0.02856657 0.02944835 Female

# %%
write.csv(MEs, paste(data_root, "gender_affi_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# ### Gender x Prior pubs (all tweets)

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender * author_pub_count_cate + gender * I(author_pub_count_cate^2) + \
            authorship_pos + affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + \
            author_citation_log + pub_year"

# %%
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_x_pub_1 <- glmer(formula = equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_x_pub_1)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.398753137
# 2  fixed    NA    genderFemale                                 -0.410416988
# 3  fixed    NA    author_pub_count_cate                         0.276654425
# 4  fixed    NA    I(author_pub_count_cate^2)                   -0.019937989
# 5  fixed    NA    authorship_posfirst_position                  0.361585737
# 6  fixed    NA    authorship_posmiddle_position                -0.637747907
# 7  fixed    NA    authorship_possolo_author                     0.827844306
# 8  fixed    NA    affiliation_rank_cate                        -0.047484897
# 9  fixed    NA    affiliation_cateinternational                 0.051698895
# 10 fixed    NA    num_authors                                  -0.002237775
# 11 fixed    NA    journal_impact                                0.033316586
# 12 fixed    NA    author_citation_log                          -0.030955711
# 13 fixed    NA    pub_year2014                                  0.304819510
# 14 fixed    NA    pub_year2015                                  0.606421317
# 15 fixed    NA    pub_year2016                                  0.846027807
# 16 fixed    NA    pub_year2017                                  1.177561918
# 17 fixed    NA    pub_year2018                                  1.541384992
# 18 fixed    NA    Social_Sciences                               0.898280442
# 19 fixed    NA    Materials_Science                            -0.143969267
# 20 fixed    NA    Engineering                                  -0.464030397
# 21 fixed    NA    Chemistry                                    -0.425130187
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.167113395
# 23 fixed    NA    Medicine                                     -0.279568066
# 24 fixed    NA    Nursing                                       0.258929316
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.490620374
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.568290479
# 27 fixed    NA    Neuroscience                                 -0.107622591
# 28 fixed    NA    Business__Management_and_Accounting          -0.180548507
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.490161493
# 30 fixed    NA    Chemical_Engineering                          0.066860694
# 31 fixed    NA    Physics_and_Astronomy                        -0.727924683
# 32 fixed    NA    Computer_Science                              0.134072257
# 33 fixed    NA    Decision_Sciences                            -0.779344011
# 34 fixed    NA    Health_Professions                            0.904787922
# 35 fixed    NA    Psychology                                   -0.580037895
# 36 fixed    NA    Immunology_and_Microbiology                  -0.174754579
# 37 fixed    NA    Dentistry                                    -1.262849430
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.084070611
# 39 fixed    NA    Environmental_Science                         0.168379966
# 40 fixed    NA    Mathematics                                  -0.242418873
# 41 fixed    NA    Arts_and_Humanities                          -0.229658821
# 42 fixed    NA    Energy                                       -0.369743624
# 43 fixed    NA    Veterinary                                   -0.872422692
# 44 fixed    NA    General                                       0.387673699
# 45 fixed    NA    genderFemale:author_pub_count_cate            0.020805272
# 46 fixed    NA    genderFemale:I(author_pub_count_cate^2)      -0.001279618
# 47 ran_pars doi   sd__(Intercept)                               1.484824937
#    std.error    statistic   p.value
# 1  1.237284e-02 -355.516985  0.000000e+00
# 2  1.216888e-02  -33.726756 2.343594e-249
# 3  3.698525e-03   74.801281  0.000000e+00
# 4  3.134588e-04  -63.606418  0.000000e+00
# 5  4.970781e-03   72.742238  0.000000e+00
# 6  4.395533e-03 -145.090004  0.000000e+00
# 7  9.972872e-03   83.009622  0.000000e+00
# 8  6.852405e-04  -69.296690  0.000000e+00
# 9  4.239094e-03   12.195742  3.275060e-34
# 10 7.906016e-05  -28.304710 3.024062e-176
# 11 2.869408e-04  116.109612  0.000000e+00
# 12 1.016290e-03  -30.459512 8.963603e-204
# 13 9.756329e-03   31.243257 2.756712e-214
# 14 9.186294e-03   66.013708  0.000000e+00
# 15 8.899720e-03   95.062297  0.000000e+00
# 16 8.686357e-03  135.564524  0.000000e+00
# 17 8.494797e-03  181.450470  0.000000e+00
# 18 9.038003e-03   99.389265  0.000000e+00
# 19 1.513702e-02   -9.511073  1.887053e-21
# 20 1.272794e-02  -36.457607 5.212350e-291
# 21 1.169778e-02  -36.342825 3.411301e-289
# 22 5.816705e-03  -28.729908 1.614707e-181
# 23 4.786121e-03  -58.412238  0.000000e+00
# 24 1.396655e-02   18.539247  9.960611e-77
# 25 6.657957e-03   73.689329  0.000000e+00
# 26 1.435112e-02  -39.599026  0.000000e+00
# 27 9.921254e-03  -10.847681  2.045502e-27
# 28 1.689750e-02  -10.684927  1.197428e-26
# 29 1.820526e-02  -26.924171 1.144929e-159
# 30 1.709024e-02    3.912215  9.145348e-05
# 31 1.268706e-02  -57.375371  0.000000e+00
# 32 1.314565e-02   10.198985  2.003558e-24
# 33 2.908795e-02  -26.792677 3.932901e-158
# 34 1.561316e-02   57.950346  0.000000e+00
# 35 1.328684e-02  -43.655071  0.000000e+00
# 36 1.083665e-02  -16.126253  1.668418e-58
# 37 5.294465e-02  -23.852258 9.594455e-126
# 38 1.169456e-02   -7.188865  6.533234e-13
# 39 8.780667e-03   19.176216  5.848460e-82
# 40 1.705664e-02  -14.212584  7.654810e-46
# 41 2.214468e-02  -10.370834  3.365738e-25
# 42 2.200414e-02  -16.803366  2.305802e-63
# 43 3.072100e-02  -28.398254 2.125016e-177
# 44 1.507142e-02   25.722432 6.560054e-146
# 45 5.594187e-03    3.719088  1.999436e-04
# 46 5.779342e-04   -2.214124  2.682025e-02
# 47           NA          NA            NA

# %%
MEs = ggemmeans(m_x_pub_1, terms=c('author_pub_count_cate', 'gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using `terms="author_pub_count_cate [all]"` to get smooth plots. See also package-vignette 'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#    x predicted  std.error   conf.low   conf.high  group
# 1  0 0.02143957 0.012278217 0.02094046 0.02195031 Male
# 2  0 0.01432584 0.013591256 0.01395451 0.01470689 Female
# 3  1 0.02754165 0.009568524 0.02704379 0.02804842 Male
# 4  1 0.01879816 0.010199951 0.01843295 0.01917047 Female
# 5  2 0.03398411 0.007546232 0.03350188 0.03447302 Male
# 6  2 0.02363259 0.007987264 0.02327405 0.02399652 Female
# 7  3 0.04029793 0.006177675 0.03983226 0.04076881 Male
# 8  3 0.02847500 0.006783712 0.02810948 0.02884513 Female
# 9  4 0.04594684 0.005367600 0.04548787 0.04641021 Male
# 10 4 0.03289762 0.006208042 0.03251270 0.03328694 Female
# 11 5 0.05040133 0.004984624 0.04993580 0.05087098 Male
# 12 5 0.03645984 0.005916287 0.03605466 0.03686940 Female
# 13 6 0.05321734 0.004958463 0.05272980 0.05370914 Male
# 14 6 0.03877858 0.005904153 0.03834953 0.03921223 Female
# 15 7 0.05410399 0.005357755 0.05356909 0.05464392 Male
# 16 7 0.03959295 0.006585673 0.03910504 0.04008670 Female
# 17 8 0.05296824 0.006343261 0.05234805 0.05359537 Male
# 18 8 0.03880939 0.008462238 0.03819540 0.03943285 Female
# 19 9 0.04992916 0.008035653 0.04918733 0.05068157 Male
# 20 9 0.03651795 0.011681369 0.03572089 0.03733210 Female

# %%
write.csv(MEs, paste(data_root, "gender_pub_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# ### Disciplines

# %%
nrow(mydata[mydata$General == 1, ])
# Out:
# [1] 184839

# %% [markdown]
# Life Sciences

# %%
nrow(mydata[mydata$Life_Sciences == 1, ])
# Out:
# [1] 4123459

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_life <- glmer(equation, data = mydata[(mydata$Life_Sciences == 1), ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
tidy(m_all_life)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.813465949
# 2  fixed    NA    genderFemale                                 -0.466440791
# 3  fixed    NA    authorship_posfirst_position                  0.333586352
# 4  fixed    NA    authorship_posmiddle_position                -0.699493571
# 5  fixed    NA    authorship_possolo_author                     0.675606457
# 6  fixed    NA    author_pub_count_cate                         0.267688879
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.023081625
# 8  fixed    NA    affiliation_rank_cate                        -0.066842773
# 9  fixed    NA    affiliation_cateinternational                 0.064354916
# 10 fixed    NA    num_authors                                  -0.005235464
# 11 fixed    NA    journal_impact                                0.049670375
# 12 fixed    NA    author_citation_log                          -0.008881011
# 13 fixed    NA    pub_year2014                                  0.262261498
# 14 fixed    NA    pub_year2015                                  0.568613619
# 15 fixed    NA    pub_year2016                                  0.810452074
# 16 fixed    NA    pub_year2017                                  1.173954660
# 17 fixed    NA    pub_year2018                                  1.573131719
# 18 fixed    NA    Social_Sciences                               0.269341773
# 19 fixed    NA    Materials_Science                            -0.035045103
# 20 fixed    NA    Engineering                                   0.022371256
# 21 fixed    NA    Chemistry                                    -0.436537109
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology  0.056226492
# 23 fixed    NA    Medicine                                     -0.247277340
# 24 fixed    NA    Nursing                                       0.366345062
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.838951907
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.182316745
# 27 fixed    NA    Neuroscience                                  0.187416997
# 28 fixed    NA    Business__Management_and_Accounting          -0.095990099
# 29 fixed    NA    Economics__Econometrics_and_Finance           0.196476592
# 30 fixed    NA    Chemical_Engineering                          0.225671280
# 31 fixed    NA    Physics_and_Astronomy                        -0.355542917
# 32 fixed    NA    Computer_Science                              0.446295665
# 33 fixed    NA    Decision_Sciences                            -0.642337703
# 34 fixed    NA    Health_Professions                            0.312887053
# 35 fixed    NA    Psychology                                    0.387456852
# 36 fixed    NA    Immunology_and_Microbiology                   0.011168877
# 37 fixed    NA    Dentistry                                    -0.492494094
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.264601884
# 39 fixed    NA    Environmental_Science                         0.261234472
# 40 fixed    NA    Mathematics                                   0.229154687
# 41 fixed    NA    Arts_and_Humanities                           0.039854458
# 42 fixed    NA    Energy                                       -0.933937376
# 43 fixed    NA    Veterinary                                   -0.441393052
# 44 ran_pars doi   sd__(Intercept)                               1.466174726
#    std.error    statistic    p.value
# 1  0.0220898968 -217.9035052  0.000000e+00
# 2  0.0068443824  -68.1494350  0.000000e+00
# 3  0.0090991841   36.6611281 3.042284e-294
# 4  0.0078527233  -89.0765594  0.000000e+00
# 5  0.0245341379   27.5374036 6.263644e-167
# 6  0.0059048075   45.3340567  0.000000e+00
# 7  0.0004762754  -48.4627718  0.000000e+00
# 8  0.0012426536  -53.7903502  0.000000e+00
# 9  0.0075346643    8.5411789  1.328593e-17
# 10 0.0003729941  -14.0363191  9.344145e-45
# 11 0.0006749756   73.5884037  0.000000e+00
# 12 0.0018488558   -4.8035173  1.559024e-06
# 13 0.0162767766   16.1126189  2.080237e-58
# 14 0.0153359234   37.0772339 6.540123e-301
# 15 0.0150035371   54.0174006  0.000000e+00
# 16 0.0147858017   79.3974302  0.000000e+00
# 17 0.0144609348  108.7849260  0.000000e+00
# 18 0.0468019536    5.7549259  8.667983e-09
# 19 0.0431083663   -0.8129536  4.162446e-01
# 20 0.0321506270    0.6958264  4.865375e-01
# 21 0.0223188334  -19.5591365  3.448681e-85
# 22 0.0094551313    5.9466643  2.736618e-09
# 23 0.0083894917  -29.4746509 6.084602e-191
# 24 0.0395467700    9.2635900  1.976717e-20
# 25 0.0094485263   88.7918269  0.000000e+00
# 26 0.0162012627  -11.2532429  2.232306e-29
# 27 0.0129025863   14.5255372  8.348526e-48
# 28 0.1278262997   -0.7509417  4.526877e-01
# 29 0.0715891155    2.7445037  6.060247e-03
# 30 0.0294103025    7.6732050  1.677511e-14
# 31 0.0520402161   -6.8320800  8.369218e-12
# 32 0.0333498036   13.3822577  7.677926e-41
# 33 0.0864394510   -7.4310711  1.077218e-13
# 34 0.0516151054    6.0619280  1.344994e-09
# 35 0.0526283693    7.3621292  1.809997e-13
# 36 0.0120631225    0.9258695  3.545138e-01
# 37 0.1227712250   -4.0114782  6.033975e-05
# 38 0.0250115385  -10.5791926  3.721511e-26
# 39 0.0137911695   18.9421552  5.125546e-80
# 40 0.0361865066    6.3326004  2.410633e-10
# 41 0.0975910604    0.4083823  6.829931e-01
# 42 0.1253061175   -7.4532465  9.107093e-14
# 43 0.0374763957  -11.7778950  5.074453e-32
# 44           NA           NA            NA

# %%
stargazer(m_all_life, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:17:13 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.466$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.334$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.699$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.676$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.268$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.023$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.067$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.064$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.005$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.050$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.009$^{***}$ \\
#   & p = 0.00001 \\
#   pub\_year2014 & 0.262$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.569$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.810$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.174$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.573$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.269$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.035 \\
#   & p = 0.417 \\
#   Engineering & 0.022 \\
#   & p = 0.487 \\
#   Chemistry & $-$0.437$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & 0.056$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.247$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.366$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.839$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.182$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & 0.187$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.096 \\
#   & p = 0.453 \\
#   Economics\_\_Econometrics\_and\_Finance & 0.196$^{**}$ \\
#   & p = 0.007 \\
#   Chemical\_Engineering & 0.226$^{***}$ \\
#   & p = 0.000 \\
#   Physics\_and\_Astronomy & $-$0.356$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.446$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.642$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.313$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & 0.387$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & 0.011 \\
#   & p = 0.355 \\
#   Dentistry & $-$0.492$^{***}$ \\
#   & p = 0.0001 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.265$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.261$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & 0.229$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & 0.040 \\
#   & p = 0.683 \\
#   Energy & $-$0.934$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.441$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.813$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 4,123,459 \\
# Log Likelihood & $-$539,992.200 \\
# Akaike Inf. Crit. & 1,080,072.000 \\
# Bayesian Inf. Crit. & 1,080,655.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_all_life, terms=c('gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using
#   `terms="gender [all]"` to get smooth plots. See also package-vignette
#   'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#   x      predicted  std.error  conf.low   conf.high  group
# 1 Male   0.03363180 0.01098575 0.03293899 0.03433867 1
# 2 Female 0.02136272 0.01190659 0.02088025 0.02185609 1

# %%
write.csv(MEs, paste(data_root, "pred_life_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# 3. gender gap in self-promotion among active subset

# %%
nrow(mydata[(mydata$Life_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ])
# Out:
# [1] 193077

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + \
            affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi)", keywords, sep = " "))
m_life <- glmer(formula = equation, data = mydata[(mydata$Life_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ], 
                     family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
tidy(m_life)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                   1.206971e-01
# 2  fixed    NA    genderFemale                                 -2.183207e-01
# 3  fixed    NA    authorship_posfirst_position                  2.453335e-01
# 4  fixed    NA    authorship_posmiddle_position                -8.476353e-01
# 5  fixed    NA    authorship_possolo_author                     1.916216e-01
# 6  fixed    NA    author_pub_count_cate                        -1.453093e-01
# 7  fixed    NA    affiliation_rank_cate                        -7.905535e-03
# 8  fixed    NA    affiliation_cateinternational                 2.714540e-01
# 9  fixed    NA    num_authors                                  -2.468949e-03
# 10 fixed    NA    journal_impact                                1.770711e-02
# 11 fixed    NA    author_citation_log                          -7.899626e-05
# 12 fixed    NA    pub_year2014                                  5.803326e-02
# 13 fixed    NA    pub_year2015                                  1.240212e-01
# 14 fixed    NA    pub_year2016                                  1.654833e-01
# 15 fixed    NA    pub_year2017                                  3.665215e-01
# 16 fixed    NA    pub_year2018                                  6.193980e-01
# 17 fixed    NA    Social_Sciences                               6.869611e-03
# 18 fixed    NA    Materials_Science                            -1.222321e-01
# 19 fixed    NA    Engineering                                   1.942277e-01
# 20 fixed    NA    Chemistry                                    -3.175450e-02
# 21 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology  1.312894e-01
# 22 fixed    NA    Medicine                                     -3.467002e-01
# 23 fixed    NA    Nursing                                       1.150580e-01
# 24 fixed    NA    Agricultural_and_Biological_Sciences          6.061823e-01
# 25 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics    6.634757e-03
# 26 fixed    NA    Neuroscience                                  2.008603e-01
# 27 fixed    NA    Business__Management_and_Accounting          -4.254359e-01
# 28 fixed    NA    Economics__Econometrics_and_Finance           3.447276e-02
# 29 fixed    NA    Chemical_Engineering                          3.535924e-01
# 30 fixed    NA    Physics_and_Astronomy                        -1.551008e-01
# 31 fixed    NA    Computer_Science                              1.506277e-03
# 32 fixed    NA    Decision_Sciences                            -2.125549e-01
# 33 fixed    NA    Health_Professions                            3.260287e-01
# 34 fixed    NA    Psychology                                    2.696857e-01
# 35 fixed    NA    Immunology_and_Microbiology                   1.586835e-01
# 36 fixed    NA    Dentistry                                    -2.299170e-01
# 37 fixed    NA    Earth_and_Planetary_Sciences                 -1.655655e-01
# 38 fixed    NA    Environmental_Science                         1.746602e-01
# 39 fixed    NA    Mathematics                                   2.165479e-01
# 40 fixed    NA    Arts_and_Humanities                           1.376976e-01
# 41 fixed    NA    Energy                                       -3.844244e-01
# 42 fixed    NA    Veterinary                                   -4.227217e-01
# 43 ran_pars doi   sd__(Intercept)                               9.041339e-01
#    std.error    statistic    p.value
# 1  0.0392268322   3.07690162  2.091643e-03
# 2  0.0125685128 -17.37045065  1.381368e-67
# 3  0.0179843905  13.64147019  2.269388e-42
# 4  0.0135153406 -62.71653156  0.000000e+00
# 5  0.0441673282   4.33853645  1.434347e-05
# 6  0.0058457544 -24.85723986 2.159407e-136
# 7  0.0021254844  -3.71940404  1.996934e-04
# 8  0.0123784798  21.92951139 1.358786e-106
# 9  0.0003607207  -6.84448979  7.674891e-12
# 10 0.0010340683  17.12372975  9.874123e-66
# 11 0.0035040729  -0.02254413  9.820139e-01
# 12 0.0318648612   1.82123056  6.857182e-02
# 13 0.0295551622   4.19626052  2.713581e-05
# 14 0.0286546498   5.77509260  7.691077e-09
# 15 0.0281111811  13.03828174  7.410840e-39
# 16 0.0275094264  22.51584657 2.903403e-112
# 17 0.0735417172   0.09341108  9.255770e-01
# 18 0.0729255783  -1.67612060  9.371457e-02
# 19 0.0554059065   3.50554222  4.556782e-04
# 20 0.0387499862  -0.81947124  4.125176e-01
# 21 0.0149706218   8.76980257  1.789798e-18
# 22 0.0134086303 -25.85649320 2.056581e-147
# 23 0.0616983470   1.86484715  6.220283e-02
# 24 0.0149549157  40.53398493  0.000000e+00
# 25 0.0262728140   0.25253316  8.006290e-01
# 26 0.0199985970  10.04371745  9.791305e-24
# 27 0.1922513373  -2.21291505  2.690350e-02
# 28 0.1090995031   0.31597541  7.520212e-01
# 29 0.0511776079   6.90912406  4.876554e-12
# 30 0.0823772001  -1.88281208  5.972584e-02
# 31 0.0514399255   0.02928226  9.766395e-01
# 32 0.1307694304  -1.62541701  1.040737e-01
# 33 0.0771199718   4.22755222  2.362474e-05
# 34 0.0820593618   3.28647138  1.014511e-03
# 35 0.0192919864   8.22535983  1.946057e-16
# 36 0.1892017942  -1.21519441  2.242920e-01
# 37 0.0375363522  -4.41080307  1.029879e-05
# 38 0.0213217497   8.19164418  2.576815e-16
# 39 0.0550484601   3.93376832  8.362439e-05
# 40 0.1565123521   0.87978732  3.789745e-01
# 41 0.2052301063  -1.87313849  6.104926e-02
# 42 0.0608712126  -6.94452581  3.797337e-12
# 43           NA           NA            NA

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_life, terms=c('gender'), typical='median')

# %%
MEs
# Out:
#   x      predicted std.error  conf.low  conf.high group
# 1 Male   0.4167002 0.01778392 0.4082535 0.4251961 1
# 2 Female 0.3647851 0.02002754 0.3557386 0.3739281 1

# %%
write.csv(MEs, paste(data_root, "pred_life.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# Social Sciences

# %%
nrow(mydata[mydata$Social_Sciences == 1, ])
# Out:
# [1] 804121

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_social <- glmer(equation, data = mydata[(mydata$Social_Sciences == 1), ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
tidy(m_all_social)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -3.659023198
# 2  fixed    NA    genderFemale                                 -0.194535354
# 3  fixed    NA    authorship_posfirst_position                  0.441591263
# 4  fixed    NA    authorship_posmiddle_position                -0.227395932
# 5  fixed    NA    authorship_possolo_author                     0.694386698
# 6  fixed    NA    author_pub_count_cate                         0.359038145
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.020269595
# 8  fixed    NA    affiliation_rank_cate                        -0.027050760
# 9  fixed    NA    affiliation_cateinternational                 0.263132215
# 10 fixed    NA    num_authors                                  -0.066394440
# 11 fixed    NA    journal_impact                                0.095123738
# 12 fixed    NA    author_citation_log                          -0.098447912
# 13 fixed    NA    pub_year2014                                  0.350260312
# 14 fixed    NA    pub_year2015                                  0.695393173
# 15 fixed    NA    pub_year2016                                  0.925966223
# 16 fixed    NA    pub_year2017                                  1.234011053
# 17 fixed    NA    pub_year2018                                  1.589529407
# 18 fixed    NA    Materials_Science                            -1.804010492
# 19 fixed    NA    Engineering                                  -0.178132799
# 20 fixed    NA    Chemistry                                    -0.498255938
# 21 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology  0.038976520
# 22 fixed    NA    Medicine                                     -0.389726846
# 23 fixed    NA    Nursing                                       0.041444810
# 24 fixed    NA    Agricultural_and_Biological_Sciences          0.006497785
# 25 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.327288896
# 26 fixed    NA    Neuroscience                                  0.009944356
# 27 fixed    NA    Business__Management_and_Accounting          -0.379814022
# 28 fixed    NA    Economics__Econometrics_and_Finance          -0.448119940
# 29 fixed    NA    Chemical_Engineering                         -0.617955593
# 30 fixed    NA    Physics_and_Astronomy                        -0.621578912
# 31 fixed    NA    Computer_Science                             -0.021017930
# 32 fixed    NA    Decision_Sciences                            -0.557121978
# 33 fixed    NA    Health_Professions                           -0.041461081
# 34 fixed    NA    Psychology                                   -0.584683847
# 35 fixed    NA    Immunology_and_Microbiology                  -1.287289382
# 36 fixed    NA    Dentistry                                    -2.586013260
# 37 fixed    NA    Earth_and_Planetary_Sciences                  0.149001519
# 38 fixed    NA    Environmental_Science                        -0.070891938
# 39 fixed    NA    Mathematics                                  -0.708665561
# 40 fixed    NA    Arts_and_Humanities                          -0.248022375
# 41 fixed    NA    Energy                                       -0.551990870
# 42 fixed    NA    Veterinary                                   -0.092669789
# 43 fixed    NA    General                                       0.263818140
# 44 ran_pars doi   sd__(Intercept)                               1.199819228
#    std.error    statistic    p.value
# 1  0.0305181780 -119.8965153  0.000000e+00
# 2  0.0100548715  -19.3473735  2.144978e-83
# 3  0.0122354734   36.0910649 3.131978e-285
# 4  0.0133592909  -17.0215570  5.683889e-65
# 5  0.0172369362   40.2848098  0.000000e+00
# 6  0.0084934797   42.2722086  0.000000e+00
# 7  0.0007677849  -26.4000953 1.366722e-153
# 8  0.0018249422  -14.8228035  1.043374e-49
# 9  0.0113704843   23.1416894 1.762724e-118
# 10 0.0024237917  -27.3927997 3.341445e-165
# 11 0.0030975161   30.7096833 4.226448e-207
# 12 0.0028433301  -34.6241590 1.094095e-262
# 13 0.0238972741   14.6569149  1.216773e-48
# 14 0.0225693752   30.8113613 1.845927e-208
# 15 0.0218338520   42.4096592  0.000000e+00
# 16 0.0215206392   57.3408178  0.000000e+00
# 17 0.0209419226   75.9017899  0.000000e+00
# 18 0.6173066118   -2.9223897  3.473566e-03
# 19 0.0329851251   -5.4003979  6.649326e-08
# 20 0.0906087590   -5.4989820  3.819901e-08
# 21 0.0595378414    0.6546512  5.126923e-01
# 22 0.0153422398  -25.4022131 2.383799e-142
# 23 0.0299416315    1.3841868  1.663013e-01
# 24 0.0325129047    0.1998525  8.415959e-01
# 25 0.0693555090   -4.7190036  2.370026e-06
# 26 0.0270964531    0.3669984  7.136202e-01
# 27 0.0169737422  -22.3765635 6.658237e-111
# 28 0.0172395327  -25.9937405 5.828647e-149
# 29 0.1432644621   -4.3133907  1.607697e-05
# 30 0.1950613510   -3.1865816  1.439649e-03
# 31 0.0230541627   -0.9116761  3.619392e-01
# 32 0.0322504500  -17.2748590  7.275099e-67
# 33 0.0453555580   -0.9141345  3.606462e-01
# 34 0.0136075143  -42.9677189  0.000000e+00
# 35 0.3517096900   -3.6600907  2.521259e-04
# 36 1.0343754920   -2.5000721  1.241680e-02
# 37 0.0506288909    2.9430137  3.250340e-03
# 38 0.0228176632   -3.1068886  1.890676e-03
# 39 0.0427281227  -16.5854598  8.878361e-62
# 40 0.0209427706  -11.8428636  2.343137e-32
# 41 0.0496298576  -11.1221530  9.788095e-29
# 42 0.1658709717   -0.5586860  5.763760e-01
# 43 0.3560873396    0.7408804  4.587659e-01
# 44           NA           NA            NA

# %%
stargazer(m_all_social, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:17:39 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.195$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.442$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.227$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.694$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.359$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.020$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.027$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.263$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.066$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.095$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.098$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.350$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.695$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.926$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.234$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.590$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$1.804$^{**}$ \\
#   & p = 0.004 \\
#   Engineering & $-$0.178$^{***}$ \\
#   & p = 0.00000 \\
#   Chemistry & $-$0.498$^{***}$ \\
#   & p = 0.00000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & 0.039 \\
#   & p = 0.513 \\
#   Medicine & $-$0.390$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.041 \\
#   & p = 0.167 \\
#   Agricultural\_and\_Biological\_Sciences & 0.006 \\
#   & p = 0.842 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.327$^{***}$ \\
#   & p = 0.00001 \\
#   Neuroscience & 0.010 \\
#   & p = 0.714 \\
#   Business\_\_Management\_and\_Accounting & $-$0.380$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.448$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & $-$0.618$^{***}$ \\
#   & p = 0.00002 \\
#   Physics\_and\_Astronomy & $-$0.622$^{**}$ \\
#   & p = 0.002 \\
#   Computer\_Science & $-$0.021 \\
#   & p = 0.362 \\
#   Decision\_Sciences & $-$0.557$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & $-$0.041 \\
#   & p = 0.361 \\
#   Psychology & $-$0.585$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$1.287$^{***}$ \\
#   & p = 0.0003 \\
#   Dentistry & $-$2.586$^{*}$ \\
#   & p = 0.013 \\
#   Earth\_and\_Planetary\_Sciences & 0.149$^{**}$ \\
#   & p = 0.004 \\
#   Environmental\_Science & $-$0.071$^{**}$ \\
#   & p = 0.002 \\
#   Mathematics & $-$0.709$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.248$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.552$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.093 \\
#   & p = 0.577 \\
#   General & 0.264 \\
#   & p = 0.459 \\
#   Constant & $-$3.659$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 804,121 \\
# Log Likelihood & $-$196,121.000 \\
# Akaike Inf. Crit. & 392,330.000 \\
# Bayesian Inf. Crit. & 392,840.300 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_all_social, terms=c('gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using
#   `terms="gender [all]"` to get smooth plots. See also package-vignette
#   'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#   x      predicted  std.error  conf.low   conf.high  group
# 1 Male   0.11474562 0.01155370 0.11246537 0.11706600 1
# 2 Female 0.09641637 0.01233801 0.09433008 0.09854377 1

# %%
write.csv(MEs, paste(data_root, "pred_social_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# 3. gender gap in self-promotion among active subset

# %%
nrow(mydata[(mydata$Social_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ])
# Out:
# [1] 77120

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + \
            affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi)", keywords, sep = " "))
m_social <- glmer(formula = equation, data = mydata[(mydata$Social_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ], 
                     family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
tidy(m_social)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                   0.21836386
# 2  fixed    NA    genderFemale                                 -0.14331643
# 3  fixed    NA    authorship_posfirst_position                  0.49101458
# 4  fixed    NA    authorship_posmiddle_position                -0.30396662
# 5  fixed    NA    authorship_possolo_author                     0.49275160
# 6  fixed    NA    author_pub_count_cate                        -0.02841247
# 7  fixed    NA    affiliation_rank_cate                         0.01812928
# 8  fixed    NA    affiliation_cateinternational                 0.26544087
# 9  fixed    NA    num_authors                                  -0.04429829
# 10 fixed    NA    journal_impact                                0.07427620
# 11 fixed    NA    author_citation_log                          -0.07146913
# 12 fixed    NA    pub_year2014                                  0.09306342
# 13 fixed    NA    pub_year2015                                  0.21990492
# 14 fixed    NA    pub_year2016                                  0.32236381
# 15 fixed    NA    pub_year2017                                  0.50427246
# 16 fixed    NA    pub_year2018                                  0.77341343
# 17 fixed    NA    Materials_Science                            -1.03440462
# 18 fixed    NA    Engineering                                  -0.06751987
# 19 fixed    NA    Chemistry                                    -0.04879178
# 20 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology  0.03410765
# 21 fixed    NA    Medicine                                     -0.26394662
# 22 fixed    NA    Nursing                                       0.04270256
# 23 fixed    NA    Agricultural_and_Biological_Sciences          0.04590268
# 24 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.13758124
# 25 fixed    NA    Neuroscience                                  0.18067504
# 26 fixed    NA    Business__Management_and_Accounting          -0.14967694
# 27 fixed    NA    Economics__Econometrics_and_Finance          -0.09382173
# 28 fixed    NA    Chemical_Engineering                         -0.23376250
# 29 fixed    NA    Physics_and_Astronomy                        -0.66500826
# 30 fixed    NA    Computer_Science                             -0.01584336
# 31 fixed    NA    Decision_Sciences                            -0.17847397
# 32 fixed    NA    Health_Professions                            0.03355462
# 33 fixed    NA    Psychology                                   -0.41056123
# 34 fixed    NA    Immunology_and_Microbiology                  -1.00172451
# 35 fixed    NA    Dentistry                                    -1.07948246
# 36 fixed    NA    Earth_and_Planetary_Sciences                  0.09880202
# 37 fixed    NA    Environmental_Science                         0.02897386
# 38 fixed    NA    Mathematics                                  -0.14873750
# 39 fixed    NA    Arts_and_Humanities                           0.02761223
# 40 fixed    NA    Energy                                       -0.25184920
# 41 fixed    NA    Veterinary                                   -0.36145901
# 42 fixed    NA    General                                       0.07247065
# 43 ran_pars doi   sd__(Intercept)                               0.80777083
#    std.error   statistic   p.value
# 1  0.055402366   3.9414177  8.100144e-05
# 2  0.017696638  -8.0985118  5.563557e-16
# 3  0.022678256  21.6513381 5.904102e-104
# 4  0.022030072 -13.7978044  2.627333e-43
# 5  0.031404351  15.6905518  1.755231e-55
# 6  0.009025351  -3.1480732  1.643505e-03
# 7  0.003160481   5.7362419  9.680038e-09
# 8  0.019428605  13.6623745  1.703375e-42
# 9  0.003120429 -14.1962164  9.669391e-46
# 10 0.005308885  13.9909232  1.770980e-44
# 11 0.005325663 -13.4197624  4.631958e-41
# 12 0.048406327   1.9225467  5.453700e-02
# 13 0.045161446   4.8693064  1.119907e-06
# 14 0.043470543   7.4156840  1.209987e-13
# 15 0.042742072  11.7980350  3.995321e-32
# 16 0.041783524  18.5100097  1.714699e-76
# 17 1.268422416  -0.8155048  4.147834e-01
# 18 0.055841976  -1.2091239  2.266153e-01
# 19 0.148835916  -0.3278226  7.430458e-01
# 20 0.094148475   0.3622752  7.171464e-01
# 21 0.023926870 -11.0313894  2.696665e-28
# 22 0.046281077   0.9226786  3.561747e-01
# 23 0.054069893   0.8489508  3.959087e-01
# 24 0.104593055  -1.3153956  1.883770e-01
# 25 0.043338788   4.1688993  3.060742e-05
# 26 0.028825446  -5.1925281  2.074576e-07
# 27 0.030417986  -3.0844163  2.039520e-03
# 28 0.235723438  -0.9916812  3.213531e-01
# 29 0.381598038  -1.7426931  8.138724e-02
# 30 0.038121612  -0.4156006  6.777023e-01
# 31 0.053817341  -3.3162911  9.122076e-04
# 32 0.076214005   0.4402684  6.597427e-01
# 33 0.021499847 -19.0960072  2.725501e-81
# 34 0.602828471  -1.6617074  9.657146e-02
# 35 1.259954335  -0.8567632  3.915758e-01
# 36 0.084877705   1.1640515  2.444032e-01
# 37 0.038006815   0.7623332  4.458612e-01
# 38 0.073752540  -2.0167102  4.372576e-02
# 39 0.038258901   0.7217205  4.704663e-01
# 40 0.086209845  -2.9213508  3.485171e-03
# 41 0.293370559  -1.2320903  2.179154e-01
# 42 0.680332519   0.1065224  9.151679e-01
# 43          NA          NA            NA

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_social, terms=c('gender'), typical='median')

# %%
MEs
# Out:
#   x      predicted std.error  conf.low  conf.high group
# 1 Male   0.5537216 0.01795944 0.5450077 0.5624027 1
# 2 Female 0.5180928 0.02041974 0.5080945 0.5280766 1

# %%
write.csv(MEs, paste(data_root, "pred_social.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# Physical Sciences

# %%
nrow(mydata[mydata$Physical_Sciences == 1, ])
# Out:
# [1] 2561568

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_phy <- glmer(equation, data = mydata[(mydata$Physical_Sciences == 1), ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
tidy(m_all_phy)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -5.0482005523
# 2  fixed    NA    genderFemale                                 -0.2843431306
# 3  fixed    NA    authorship_posfirst_position                  0.3618488393
# 4  fixed    NA    authorship_posmiddle_position                -0.5559860800
# 5  fixed    NA    authorship_possolo_author                     0.8438211181
# 6  fixed    NA    author_pub_count_cate                         0.2665663776
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.0228229415
# 8  fixed    NA    affiliation_rank_cate                        -0.0426525804
# 9  fixed    NA    affiliation_cateinternational                 0.0228971403
# 10 fixed    NA    num_authors                                  -0.0015649006
# 11 fixed    NA    journal_impact                                0.0344165420
# 12 fixed    NA    author_citation_log                           0.0003394498
# 13 fixed    NA    pub_year2014                                  0.2916469679
# 14 fixed    NA    pub_year2015                                  0.6289588226
# 15 fixed    NA    pub_year2016                                  0.8188496051
# 16 fixed    NA    pub_year2017                                  1.1192034640
# 17 fixed    NA    pub_year2018                                  1.5472247164
# 18 fixed    NA    Social_Sciences                               0.8834164845
# 19 fixed    NA    Materials_Science                             0.0378740684
# 20 fixed    NA    Engineering                                  -0.2362778304
# 21 fixed    NA    Chemistry                                    -0.1320521180
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology  0.3081571264
# 23 fixed    NA    Medicine                                      0.1668708265
# 24 fixed    NA    Nursing                                       0.6804708936
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.3000590422
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.6563714365
# 27 fixed    NA    Neuroscience                                  0.1474539500
# 28 fixed    NA    Business__Management_and_Accounting          -0.1360035711
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.1392644772
# 30 fixed    NA    Chemical_Engineering                          0.0042133601
# 31 fixed    NA    Physics_and_Astronomy                        -0.4339705634
# 32 fixed    NA    Computer_Science                              0.4390374278
# 33 fixed    NA    Decision_Sciences                            -0.5007942821
# 34 fixed    NA    Health_Professions                           -0.2965376635
# 35 fixed    NA    Psychology                                    0.0987688367
# 36 fixed    NA    Immunology_and_Microbiology                   0.1607746455
# 37 fixed    NA    Dentistry                                    -1.1762907210
# 38 fixed    NA    Earth_and_Planetary_Sciences                  0.3780490664
# 39 fixed    NA    Environmental_Science                         0.5613086599
# 40 fixed    NA    Mathematics                                  -0.1685143417
# 41 fixed    NA    Arts_and_Humanities                          -0.2636886285
# 42 fixed    NA    Energy                                       -0.1493372219
# 43 fixed    NA    General                                       2.1225438972
# 44 ran_pars doi   sd__(Intercept)                               1.3607880584
#    std.error    statistic    p.value
# 1  2.847375e-02 -177.2931350  0.000000e+00
# 2  9.337878e-03  -30.4505092 1.179452e-203
# 3  1.118594e-02   32.3485266 1.455117e-229
# 4  9.907004e-03  -56.1205075  0.000000e+00
# 5  2.446021e-02   34.4977054 8.682828e-261
# 6  7.714589e-03   34.5535441 1.260951e-261
# 7  6.292700e-04  -36.2689167 5.001984e-288
# 8  1.566954e-03  -27.2200566 3.760451e-163
# 9  9.821648e-03    2.3312930  1.973791e-02
# 10 7.034405e-05  -22.2463807 1.222708e-109
# 11 9.637988e-04   35.7092587 2.839644e-279
# 12 2.509383e-03    0.1352722  8.923966e-01
# 13 2.165296e-02   13.4691503  2.375842e-41
# 14 2.036487e-02   30.8845066 1.928650e-209
# 15 1.966821e-02   41.6331528  0.000000e+00
# 16 1.916705e-02   58.3920520  0.000000e+00
# 17 1.850948e-02   83.5909396  0.000000e+00
# 18 1.921675e-02   45.9711709  0.000000e+00
# 19 1.546925e-02    2.4483459  1.435138e-02
# 20 1.394112e-02  -16.9482710  1.981973e-64
# 21 1.403801e-02   -9.4067581  5.116751e-21
# 22 1.536931e-02   20.0501543  2.012199e-89
# 23 2.195563e-02    7.6003646  2.952975e-14
# 24 1.590363e-01    4.2787144  1.879758e-05
# 25 1.431968e-02   20.9543135  1.713823e-97
# 26 3.179100e-02  -20.6464517  1.050586e-94
# 27 4.013251e-02    3.6741775  2.386168e-04
# 28 3.508886e-02   -3.8759762  1.061981e-04
# 29 3.751687e-02   -3.7120498  2.055876e-04
# 30 1.723529e-02    0.2444612  8.068737e-01
# 31 1.431980e-02  -30.3056402 9.660680e-202
# 32 1.605685e-02   27.3426932 1.319096e-164
# 33 3.457926e-02  -14.4825030  1.563002e-47
# 34 6.993146e-02   -4.2404045  2.231173e-05
# 35 4.939735e-02    1.9994766  4.555681e-02
# 36 2.749933e-02    5.8464933  5.020438e-09
# 37 3.033457e-01   -3.8777228  1.054388e-04
# 38 1.449280e-02   26.0852975 5.353565e-150
# 39 1.330633e-02   42.1835917  0.000000e+00
# 40 1.889563e-02   -8.9181653  4.740767e-19
# 41 7.232075e-02   -3.6460994  2.662510e-04
# 42 2.248025e-02   -6.6430401  3.072782e-11
# 43 4.838121e-01    4.3871248  1.148589e-05
# 44           NA           NA            NA

# %%
stargazer(m_all_phy, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:18:01 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.284$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.362$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.556$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.844$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.267$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.023$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.043$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.023$^{*}$ \\
#   & p = 0.020 \\
#   num\_authors & $-$0.002$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.034$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & 0.0003 \\
#   & p = 0.893 \\
#   pub\_year2014 & 0.292$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.629$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.819$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.119$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.547$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.883$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & 0.038$^{*}$ \\
#   & p = 0.015 \\
#   Engineering & $-$0.236$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.132$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & 0.308$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & 0.167$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.680$^{***}$ \\
#   & p = 0.00002 \\
#   Agricultural\_and\_Biological\_Sciences & 0.300$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.656$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & 0.147$^{***}$ \\
#   & p = 0.0003 \\
#   Business\_\_Management\_and\_Accounting & $-$0.136$^{***}$ \\
#   & p = 0.0002 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.139$^{***}$ \\
#   & p = 0.0003 \\
#   Chemical\_Engineering & 0.004 \\
#   & p = 0.807 \\
#   Physics\_and\_Astronomy & $-$0.434$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.439$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.501$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & $-$0.297$^{***}$ \\
#   & p = 0.00003 \\
#   Psychology & 0.099$^{*}$ \\
#   & p = 0.046 \\
#   Immunology\_and\_Microbiology & 0.161$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.176$^{***}$ \\
#   & p = 0.0002 \\
#   Earth\_and\_Planetary\_Sciences & 0.378$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.561$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.169$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.264$^{***}$ \\
#   & p = 0.0003 \\
#   Energy & $-$0.149$^{***}$ \\
#   & p = 0.000 \\
#   General & 2.123$^{***}$ \\
#   & p = 0.00002 \\
#   Constant & $-$5.048$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 2,561,568 \\
# Log Likelihood & $-$322,601.200 \\
# Akaike Inf. Crit. & 645,290.400 \\
# Bayesian Inf. Crit. & 645,851.600 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_all_phy, terms=c('gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using
#   `terms="gender [all]"` to get smooth plots. See also package-vignette
#   'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#   x      predicted  std.error  conf.low   conf.high  group
# 1 Male   0.03170544 0.01505750 0.03081183 0.03262410 1
# 2 Female 0.02404731 0.01668219 0.02329178 0.02482672 1

# %%
write.csv(MEs, paste(data_root, "pred_phy_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# 3. gender gap in self-promotion among active subset

# %%
nrow(mydata[(mydata$Physical_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ])
# Out:
# [1] 109732

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + \
            affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi)", keywords, sep = " "))
m_phy <- glmer(formula = equation, data = mydata[(mydata$Physical_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ], 
                     family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 1 column / coefficient

# %%
tidy(m_phy)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                   0.052969313
# 2  fixed    NA    genderFemale                                 -0.169027063
# 3  fixed    NA    authorship_posfirst_position                  0.387579056
# 4  fixed    NA    authorship_posmiddle_position                -0.613668220
# 5  fixed    NA    authorship_possolo_author                     0.561928675
# 6  fixed    NA    author_pub_count_cate                        -0.085244367
# 7  fixed    NA    affiliation_rank_cate                         0.024360717
# 8  fixed    NA    affiliation_cateinternational                 0.138415808
# 9  fixed    NA    num_authors                                  -0.001579563
# 10 fixed    NA    journal_impact                                0.028256275
# 11 fixed    NA    author_citation_log                          -0.035735183
# 12 fixed    NA    pub_year2014                                  0.095324879
# 13 fixed    NA    pub_year2015                                  0.223215909
# 14 fixed    NA    pub_year2016                                  0.250427289
# 15 fixed    NA    pub_year2017                                  0.425897087
# 16 fixed    NA    pub_year2018                                  0.724503415
# 17 fixed    NA    Social_Sciences                               0.241751814
# 18 fixed    NA    Materials_Science                             0.096138480
# 19 fixed    NA    Engineering                                  -0.100529979
# 20 fixed    NA    Chemistry                                    -0.001968520
# 21 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology  0.135244669
# 22 fixed    NA    Medicine                                     -0.123145964
# 23 fixed    NA    Nursing                                      -0.231972188
# 24 fixed    NA    Agricultural_and_Biological_Sciences          0.156207719
# 25 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.388856257
# 26 fixed    NA    Neuroscience                                  0.276315706
# 27 fixed    NA    Business__Management_and_Accounting          -0.044621531
# 28 fixed    NA    Economics__Econometrics_and_Finance          -0.048773589
# 29 fixed    NA    Chemical_Engineering                          0.026238550
# 30 fixed    NA    Physics_and_Astronomy                        -0.230488222
# 31 fixed    NA    Computer_Science                             -0.033238593
# 32 fixed    NA    Decision_Sciences                            -0.098465920
# 33 fixed    NA    Health_Professions                           -0.304321635
# 34 fixed    NA    Psychology                                    0.011260014
# 35 fixed    NA    Immunology_and_Microbiology                   0.222066810
# 36 fixed    NA    Dentistry                                    -1.700623313
# 37 fixed    NA    Earth_and_Planetary_Sciences                  0.017473319
# 38 fixed    NA    Environmental_Science                         0.207114820
# 39 fixed    NA    Mathematics                                   0.048072130
# 40 fixed    NA    Arts_and_Humanities                          -0.169990110
# 41 fixed    NA    Energy                                        0.018123198
# 42 fixed    NA    General                                       1.384221291
# 43 ran_pars doi   sd__(Intercept)                               0.806392272
#    std.error    statistic    p.value
# 1  0.0516660867   1.02522401  3.052575e-01
# 2  0.0169382918  -9.97899109  1.883724e-23
# 3  0.0223299764  17.35689496  1.749319e-67
# 4  0.0168777184 -36.35966702 1.848533e-289
# 5  0.0477144479  11.77690825  5.134192e-32
# 6  0.0080291413 -10.61687218  2.487569e-26
# 7  0.0027060208   9.00241326  2.208096e-19
# 8  0.0165279133   8.37466934  5.537914e-17
# 9  0.0001177879 -13.41022299  5.268019e-41
# 10 0.0017796554  15.87738525  9.088898e-57
# 11 0.0049255342  -7.25508777  4.014015e-13
# 12 0.0423508147   2.25083932  2.439572e-02
# 13 0.0392845532   5.68202744  1.331073e-08
# 14 0.0378373445   6.61852178  3.628085e-11
# 15 0.0369251224  11.53407379  8.883817e-31
# 16 0.0359399796  20.15870412  2.257164e-90
# 17 0.0299401911   8.07449134  6.775851e-16
# 18 0.0276784785   3.47340191  5.139052e-04
# 19 0.0241400819  -4.16444234  3.121145e-05
# 20 0.0241932721  -0.08136644  9.351505e-01
# 21 0.0255915732   5.28473449  1.258872e-07
# 22 0.0342260223  -3.59802149  3.206471e-04
# 23 0.2567708301  -0.90342111  3.663024e-01
# 24 0.0223108617   7.00142025  2.533806e-12
# 25 0.0530704740  -7.32716759  2.350678e-13
# 26 0.0628924164   4.39346621  1.115575e-05
# 27 0.0562353422  -0.79347843  4.274991e-01
# 28 0.0595623087  -0.81886666  4.128625e-01
# 29 0.0310150790   0.84599333  3.975565e-01
# 30 0.0242740528  -9.49525089  2.196817e-21
# 31 0.0269154769  -1.23492492  2.168584e-01
# 32 0.0552813570  -1.78117770  7.488342e-02
# 33 0.1010662894  -3.01110921  2.602952e-03
# 34 0.0761203993   0.14792374  8.824030e-01
# 35 0.0443633466   5.00563701  5.567759e-07
# 36 0.7863019788  -2.16281195  3.055565e-02
# 37 0.0234812730   0.74413849  4.567927e-01
# 38 0.0219785156   9.42351267  4.362442e-21
# 39 0.0319333980   1.50538724  1.322245e-01
# 40 0.1214278808  -1.39992651  1.615353e-01
# 41 0.0385934100   0.46959307  6.386458e-01
# 42 0.7314725299   1.89237632  5.844086e-02
# 43           NA           NA            NA

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_phy, terms=c('gender'), typical='median')

# %%
MEs
# Out:
#   x      predicted std.error  conf.low  conf.high group
# 1 Male   0.4625152 0.02583562 0.4499536 0.4751245 1
# 2 Female 0.4208590 0.02900532 0.4070684 0.4347741 1

# %%
write.csv(MEs, paste(data_root, "pred_phy.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# Health Sciences

# %%
nrow(mydata[mydata$Health_Sciences == 1, ])
# Out:
# [1] 4952083

# %% [markdown]
# 1. Gender gap among all obs, without on_tw control

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_health <- glmer(equation, data = mydata[(mydata$Health_Sciences == 1), ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 3 columns / coefficients

# %%
tidy(m_all_health)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.91825743
# 2  fixed    NA    genderFemale                                 -0.33985683
# 3  fixed    NA    authorship_posfirst_position                  0.43833257
# 4  fixed    NA    authorship_posmiddle_position                -0.62766951
# 5  fixed    NA    authorship_possolo_author                     0.74342094
# 6  fixed    NA    author_pub_count_cate                         0.29702684
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.01702610
# 8  fixed    NA    affiliation_rank_cate                        -0.04171189
# 9  fixed    NA    affiliation_cateinternational                 0.12746164
# 10 fixed    NA    num_authors                                  -0.01043556
# 11 fixed    NA    journal_impact                                0.02902527
# 12 fixed    NA    author_citation_log                          -0.05512402
# 13 fixed    NA    pub_year2014                                  0.26067599
# 14 fixed    NA    pub_year2015                                  0.52233355
# 15 fixed    NA    pub_year2016                                  0.76284078
# 16 fixed    NA    pub_year2017                                  1.13186236
# 17 fixed    NA    pub_year2018                                  1.50263117
# 18 fixed    NA    Social_Sciences                               0.73258750
# 19 fixed    NA    Materials_Science                            -0.58599420
# 20 fixed    NA    Engineering                                  -0.11346670
# 21 fixed    NA    Chemistry                                    -0.37325807
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.42447861
# 23 fixed    NA    Medicine                                      0.23005646
# 24 fixed    NA    Nursing                                       0.40980026
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.91983212
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.19975985
# 27 fixed    NA    Neuroscience                                 -0.40666911
# 28 fixed    NA    Business__Management_and_Accounting          -0.86530184
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.25297888
# 30 fixed    NA    Chemical_Engineering                         -0.09789834
# 31 fixed    NA    Physics_and_Astronomy                        -0.84529868
# 32 fixed    NA    Computer_Science                             -0.29676354
# 33 fixed    NA    Decision_Sciences                            -0.52350888
# 34 fixed    NA    Health_Professions                            1.01798521
# 35 fixed    NA    Psychology                                   -0.56665446
# 36 fixed    NA    Immunology_and_Microbiology                  -0.16814209
# 37 fixed    NA    Dentistry                                    -0.91329314
# 38 fixed    NA    Environmental_Science                         0.87604556
# 39 fixed    NA    Mathematics                                  -0.03524926
# 40 fixed    NA    Arts_and_Humanities                          -0.86355068
# 41 fixed    NA    Veterinary                                   -0.63956690
# 42 ran_pars doi   sd__(Intercept)                               1.59211958
#    std.error    statistic    p.value
# 1  0.0298975804 -164.5035273  0.000000e+00
# 2  0.0062684152  -54.2173448  0.000000e+00
# 3  0.0084674007   51.7670756  0.000000e+00
# 4  0.0074498236  -84.2529364  0.000000e+00
# 5  0.0214074723   34.7271703 3.065299e-264
# 6  0.0051407090   57.7793529  0.000000e+00
# 7  0.0004280812  -39.7730702  0.000000e+00
# 8  0.0011608284  -35.9328640 9.374645e-283
# 9  0.0072070900   17.6855897  5.415156e-70
# 10 0.0004148589  -25.1544911 1.262020e-139
# 11 0.0003877911   74.8476860  0.000000e+00
# 12 0.0016903301  -32.6113932 2.827670e-233
# 13 0.0154233820   16.9013507  4.397177e-64
# 14 0.0145838771   35.8158225 6.264389e-281
# 15 0.0142792218   53.4231337  0.000000e+00
# 16 0.0140495257   80.5623182  0.000000e+00
# 17 0.0138229796  108.7053017  0.000000e+00
# 18 0.0193099659   37.9383115  0.000000e+00
# 19 0.1224156538   -4.7869221  1.693585e-06
# 20 0.0473494365   -2.3963686  1.655843e-02
# 21 0.0916456079   -4.0728418  4.644296e-05
# 22 0.0108624323  -39.0776757  0.000000e+00
# 23 0.0233927806    9.8345070  7.995829e-23
# 24 0.0161005420   25.4525754 6.610927e-143
# 25 0.0143986716   63.8831234  0.000000e+00
# 26 0.0229300917   -8.7116900  2.993775e-18
# 27 0.0173718987  -23.4095948 3.412613e-121
# 28 0.3218507785   -2.6885187  7.176982e-03
# 29 0.1660908175   -1.5231358  1.277247e-01
# 30 0.1140527359   -0.8583603  3.906936e-01
# 31 0.0674906025  -12.5246871  5.470665e-36
# 32 0.0563496787   -5.2664638  1.390767e-07
# 33 0.1721308412   -3.0413427  2.355256e-03
# 34 0.0172789123   58.9148895  0.000000e+00
# 35 0.0263924582  -21.4703176 2.949953e-102
# 36 0.0161828381  -10.3901484  2.749250e-25
# 37 0.0565439719  -16.1519100  1.100991e-58
# 38 0.0333154311   26.2954892 2.159610e-152
# 39 0.0500987563   -0.7035955  4.816847e-01
# 40 0.1207265793   -7.1529458  8.493515e-13
# 41 0.0370340000  -17.2697224  7.952402e-67
# 42           NA           NA            NA

# %%
stargazer(m_all_health, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:18:19 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.340$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.438$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.628$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.743$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.297$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.017$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.042$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.127$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.010$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.029$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.055$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.261$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.522$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.763$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.132$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.503$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.733$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.586$^{***}$ \\
#   & p = 0.00001 \\
#   Engineering & $-$0.113$^{*}$ \\
#   & p = 0.017 \\
#   Chemistry & $-$0.373$^{***}$ \\
#   & p = 0.00005 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.424$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & 0.230$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.410$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.920$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.200$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.407$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.865$^{**}$ \\
#   & p = 0.008 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.253 \\
#   & p = 0.128 \\
#   Chemical\_Engineering & $-$0.098 \\
#   & p = 0.391 \\
#   Physics\_and\_Astronomy & $-$0.845$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & $-$0.297$^{***}$ \\
#   & p = 0.00000 \\
#   Decision\_Sciences & $-$0.524$^{**}$ \\
#   & p = 0.003 \\
#   Health\_Professions & 1.018$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.567$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.168$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$0.913$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.876$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.035 \\
#   & p = 0.482 \\
#   Arts\_and\_Humanities & $-$0.864$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.640$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.918$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 4,952,083 \\
# Log Likelihood & $-$630,388.100 \\
# Akaike Inf. Crit. & 1,260,860.000 \\
# Bayesian Inf. Crit. & 1,261,424.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_all_health, terms=c('gender'), typical='median')
# Out:
# Model contains polynomial or cubic / quadratic terms. Consider using
#   `terms="gender [all]"` to get smooth plots. See also package-vignette
#   'Marginal Effects at Specific Values'.

# %%
MEs
# Out:
#   x      predicted  std.error   conf.low   conf.high  group
# 1 Male   0.03458188 0.008118810 0.03405454 0.03511709 1
# 2 Female 0.02486564 0.008833066 0.02444929 0.02528889 1

# %%
write.csv(MEs, paste(data_root, "pred_health_1.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# 3. gender gap in self-promotion among active subset

# %%
nrow(mydata[(mydata$Health_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ])
# Out:
# [1] 257918

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + \
            affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi)", keywords, sep = " "))
m_health <- glmer(formula = equation, data = mydata[(mydata$Health_Sciences == 1) & (mydata$is_active_on_twitter == 'True'), ], 
                     family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# fixed-effect model matrix is rank deficient so dropping 3 columns / coefficients

# %%
tidy(m_health)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -0.3683193159
# 2  fixed    NA    genderFemale                                 -0.1666184025
# 3  fixed    NA    authorship_posfirst_position                  0.3749206066
# 4  fixed    NA    authorship_posmiddle_position                -0.7507860693
# 5  fixed    NA    authorship_possolo_author                     0.4120372069
# 6  fixed    NA    author_pub_count_cate                        -0.0928089394
# 7  fixed    NA    affiliation_rank_cate                         0.0054113966
# 8  fixed    NA    affiliation_cateinternational                 0.3284011212
# 9  fixed    NA    num_authors                                  -0.0053155447
# 10 fixed    NA    journal_impact                                0.0176719170
# 11 fixed    NA    author_citation_log                          -0.0308561526
# 12 fixed    NA    pub_year2014                                  0.0286390993
# 13 fixed    NA    pub_year2015                                  0.0962445983
# 14 fixed    NA    pub_year2016                                  0.1384846685
# 15 fixed    NA    pub_year2017                                  0.3400742490
# 16 fixed    NA    pub_year2018                                  0.5582398670
# 17 fixed    NA    Social_Sciences                               0.3764625552
# 18 fixed    NA    Materials_Science                            -0.3391693322
# 19 fixed    NA    Engineering                                   0.1285289443
# 20 fixed    NA    Chemistry                                     0.6012661981
# 21 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.3090201484
# 22 fixed    NA    Medicine                                      0.2888049155
# 23 fixed    NA    Nursing                                       0.1859323709
# 24 fixed    NA    Agricultural_and_Biological_Sciences          0.9091864329
# 25 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.0582997352
# 26 fixed    NA    Neuroscience                                 -0.1898642983
# 27 fixed    NA    Business__Management_and_Accounting          -1.7395565078
# 28 fixed    NA    Economics__Econometrics_and_Finance           0.0000418626
# 29 fixed    NA    Chemical_Engineering                         -0.1955023381
# 30 fixed    NA    Physics_and_Astronomy                        -0.1277978494
# 31 fixed    NA    Computer_Science                             -0.1739068091
# 32 fixed    NA    Decision_Sciences                            -0.0571685054
# 33 fixed    NA    Health_Professions                            0.6467765361
# 34 fixed    NA    Psychology                                   -0.2942618588
# 35 fixed    NA    Immunology_and_Microbiology                   0.0775996380
# 36 fixed    NA    Dentistry                                    -0.2308739919
# 37 fixed    NA    Environmental_Science                         0.3807885720
# 38 fixed    NA    Mathematics                                  -0.0263491918
# 39 fixed    NA    Arts_and_Humanities                          -0.2548252035
# 40 fixed    NA    Veterinary                                   -0.3073379960
# 41 ran_pars doi   sd__(Intercept)                               1.0120349917
#    std.error    statistic     p.value
# 1  0.0483770154 -7.613519e+00  2.667325e-14
# 2  0.0109133899 -1.526734e+01  1.262233e-52
# 3  0.0155373213  2.413032e+01 1.201582e-128
# 4  0.0123206274 -6.093732e+01  0.000000e+00
# 5  0.0372066725  1.107428e+01  1.672139e-28
# 6  0.0052541051 -1.766408e+01  7.929313e-70
# 7  0.0019241138  2.812410e+00  4.917180e-03
# 8  0.0114546029  2.866980e+01 9.083624e-181
# 9  0.0004638389 -1.145989e+01  2.097731e-30
# 10 0.0006418312  2.753359e+01 6.958389e-167
# 11 0.0030652604 -1.006641e+01  7.776879e-24
# 12 0.0301215680  9.507838e-01  3.417141e-01
# 13 0.0279996618  3.437349e+00  5.874390e-04
# 14 0.0271291557  5.104644e+00  3.314187e-07
# 15 0.0265964822  1.278644e+01  1.952204e-37
# 16 0.0261168255  2.137472e+01 2.296900e-101
# 17 0.0279537283  1.346735e+01  2.434579e-41
# 18 0.1954455085 -1.735365e+00  8.267614e-02
# 19 0.0692164051  1.856914e+00  6.332332e-02
# 20 0.1457585120  4.125085e+00  3.705985e-05
# 21 0.0165039022 -1.872407e+01  3.151528e-78
# 22 0.0341955339  8.445691e+00  3.022520e-17
# 23 0.0239670959  7.757818e+00  8.640295e-15
# 24 0.0233438092  3.894765e+01  0.000000e+00
# 25 0.0350583754 -1.662933e+00  9.632581e-02
# 26 0.0257273633 -7.379858e+00  1.584580e-13
# 27 0.5518013808 -3.152505e+00  1.618762e-03
# 28 0.2372684725  1.764356e-04  9.998592e-01
# 29 0.1988465395 -9.831820e-01  3.255179e-01
# 30 0.1068003014 -1.196606e+00  2.314603e-01
# 31 0.0813304627 -2.138274e+00  3.249452e-02
# 32 0.2432458182 -2.350236e-01  8.141904e-01
# 33 0.0249922894  2.587904e+01 1.146668e-147
# 34 0.0381130173 -7.720770e+00  1.156286e-14
# 35 0.0264343605  2.935559e+00  3.329468e-03
# 36 0.0962866961 -2.397777e+00  1.649492e-02
# 37 0.0499547275  7.622673e+00  2.484750e-14
# 38 0.0764403242 -3.447028e-01  7.303178e-01
# 39 0.2003101176 -1.272153e+00  2.033186e-01
# 40 0.0580912431 -5.290608e+00  1.219104e-07
# 41           NA            NA            NA

# %%
# weighted average for factor variable, median for non-factor variables
MEs = ggemmeans(m_health, terms=c('gender'), typical='median')

# %%
MEs
# Out:
#   x      predicted std.error  conf.low  conf.high group
# 1 Male   0.3479061 0.01224770 0.3424802 0.3533718 1
# 2 Female 0.3111230 0.01413553 0.3052164 0.3170918 1

# %%
write.csv(MEs, paste(data_root, "pred_health.csv", sep = ''), row.names=FALSE)

# %% [markdown]
# ## Robustness check

# %% [markdown]
# ### Mixed gender team

# %% [markdown]
# Predicting if the author is the first one to self-promote (all obs)

# %%
base_str <- "self_promotion_first ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_first <- glmer(formula = equation, data = mydata, family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# boundary (singular) fit: see help('isSingular')

# %%
tidy(m_all_first)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.336110e+00
# 2  fixed    NA    genderFemale                                 -3.226285e-01
# 3  fixed    NA    authorship_posfirst_position                  3.518395e-01
# 4  fixed    NA    authorship_posmiddle_position                -7.574488e-01
# 5  fixed    NA    authorship_possolo_author                     9.300299e-01
# 6  fixed    NA    author_pub_count_cate                         2.987045e-01
# 7  fixed    NA    I(author_pub_count_cate^2)                   -2.316048e-02
# 8  fixed    NA    affiliation_rank_cate                        -4.904548e-02
# 9  fixed    NA    affiliation_cateinternational                 5.324689e-02
# 10 fixed    NA    num_authors                                  -1.547413e-02
# 11 fixed    NA    journal_impact                                2.164558e-02
# 12 fixed    NA    author_citation_log                          -1.328757e-02
# 13 fixed    NA    pub_year2014                                  2.872680e-01
# 14 fixed    NA    pub_year2015                                  5.616218e-01
# 15 fixed    NA    pub_year2016                                  7.752995e-01
# 16 fixed    NA    pub_year2017                                  1.050694e+00
# 17 fixed    NA    pub_year2018                                  1.348054e+00
# 18 fixed    NA    Social_Sciences                               8.040424e-01
# 19 fixed    NA    Materials_Science                            -1.120425e-01
# 20 fixed    NA    Engineering                                  -4.102791e-01
# 21 fixed    NA    Chemistry                                    -3.491637e-01
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -1.386468e-01
# 23 fixed    NA    Medicine                                     -2.532766e-01
# 24 fixed    NA    Nursing                                       2.132861e-01
# 25 fixed    NA    Agricultural_and_Biological_Sciences          4.079296e-01
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -5.104509e-01
# 27 fixed    NA    Neuroscience                                 -9.463784e-02
# 28 fixed    NA    Business__Management_and_Accounting          -1.398053e-01
# 29 fixed    NA    Economics__Econometrics_and_Finance          -4.400938e-01
# 30 fixed    NA    Chemical_Engineering                          7.349149e-02
# 31 fixed    NA    Physics_and_Astronomy                        -6.578316e-01
# 32 fixed    NA    Computer_Science                              1.128792e-01
# 33 fixed    NA    Decision_Sciences                            -7.029167e-01
# 34 fixed    NA    Health_Professions                            6.833793e-01
# 35 fixed    NA    Psychology                                   -5.225964e-01
# 36 fixed    NA    Immunology_and_Microbiology                  -1.416796e-01
# 37 fixed    NA    Dentistry                                    -1.197898e+00
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -7.438039e-02
# 39 fixed    NA    Environmental_Science                         1.436645e-01
# 40 fixed    NA    Mathematics                                  -2.633820e-01
# 41 fixed    NA    Arts_and_Humanities                          -2.066842e-01
# 42 fixed    NA    Energy                                       -2.789033e-01
# 43 fixed    NA    Veterinary                                   -8.209293e-01
# 44 fixed    NA    General                                       2.675674e-01
# 45 ran_pars doi   sd__(Intercept)                               1.708617e-07
#    std.error    statistic   p.value
# 1  0.0116060330 -373.608267  0.000000e+00
# 2  0.0041278044  -78.159844  0.000000e+00
# 3  0.0052627051   66.855249  0.000000e+00
# 4  0.0048960448 -154.706264  0.000000e+00
# 5  0.0087673379  106.078933  0.000000e+00
# 6  0.0034901788   85.584284  0.000000e+00
# 7  0.0002910875  -79.565384  0.000000e+00
# 8  0.0006967838  -70.388365  0.000000e+00
# 9  0.0040649763   13.098942  3.338784e-39
# 10 0.0002785563  -55.551167  0.000000e+00
# 11 0.0002199744   98.400435  0.000000e+00
# 12 0.0010813283  -12.288191  1.048250e-34
# 13 0.0091357824   31.444266 5.027906e-217
# 14 0.0085628146   65.588460  0.000000e+00
# 15 0.0082664264   93.788952  0.000000e+00
# 16 0.0080416683  130.656215  0.000000e+00
# 17 0.0078413525  171.916045  0.000000e+00
# 18 0.0076258450  105.436499  0.000000e+00
# 19 0.0137676054   -8.138124  4.014481e-16
# 20 0.0116493698  -35.218994 1.023885e-271
# 21 0.0106165156  -32.888731 3.185216e-237
# 22 0.0051877846  -26.725625 2.371526e-157
# 23 0.0042974331  -58.936714  0.000000e+00
# 24 0.0123442799   17.278131  6.873910e-67
# 25 0.0058321875   69.944532  0.000000e+00
# 26 0.0134392329  -37.982142  0.000000e+00
# 27 0.0088836276  -10.653062  1.687218e-26
# 28 0.0144420438   -9.680440  3.651417e-22
# 29 0.0156819151  -28.063778 2.712496e-173
# 30 0.0154311602    4.762538  1.911733e-06
# 31 0.0118245328  -55.632775  0.000000e+00
# 32 0.0115895230    9.739760  2.040355e-22
# 33 0.0259958840  -27.039538 5.070483e-161
# 34 0.0134629365   50.760048  0.000000e+00
# 35 0.0114542105  -45.624832  0.000000e+00
# 36 0.0097844825  -14.480026  1.620351e-47
# 37 0.0515348201  -23.244446 1.618977e-119
# 38 0.0103701999   -7.172513  7.363364e-13
# 39 0.0076332928   18.820779  5.102905e-79
# 40 0.0155661525  -16.920173  3.194887e-64
# 41 0.0189059100  -10.932256  8.081385e-28
# 42 0.0197221172  -14.141650  2.102947e-45
# 43 0.0294152821  -27.908259 2.118285e-171
# 44 0.0122787409   21.791111 2.817325e-105
# 45           NA          NA            NA

# %%
r.squaredGLMM(m_all_first)
# Out:
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m       R2c
# theoretical 0.8628439 0.8628439
# delta       0.3788889 0.3788889

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_all_first, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 08:59:59 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion\_first \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.323$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.352$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.757$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.930$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.299$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.023$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.049$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.053$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.015$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.022$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.013$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.287$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.562$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.775$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.051$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.348$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.804$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.112$^{***}$ \\
#   & p = 0.000 \\
#   Engineering & $-$0.410$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.349$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.139$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.253$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.213$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.408$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.510$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.095$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.140$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.440$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & 0.073$^{***}$ \\
#   & p = 0.00001 \\
#   Physics\_and\_Astronomy & $-$0.658$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.113$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.703$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.683$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.523$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.142$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.198$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.074$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.144$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.263$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.207$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.279$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.821$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.268$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.336$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 11,396,752 \\
# Log Likelihood & $-$1,342,219.000 \\
# Akaike Inf. Crit. & 2,684,528.000 \\
# Bayesian Inf. Crit. & 2,685,169.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %% [markdown]
# Solo-author (all obs)

# %%
base_str <- "self_promotion ~ 1 + gender + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_solo <- glmer(formula = equation, data = mydata[mydata$authorship_pos == 'solo_author', ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)
# Out:
# boundary (singular) fit: see help('isSingular')

# %%
tidy(m_all_solo)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -2.95835749
# 2  fixed    NA    genderFemale                                 -0.09188927
# 3  fixed    NA    author_pub_count_cate                         0.26707775
# 4  fixed    NA    I(author_pub_count_cate^2)                   -0.02042258
# 5  fixed    NA    affiliation_rank_cate                        -0.02518316
# 6  fixed    NA    affiliation_cateinternational                 0.16930360
# 7  fixed    NA    journal_impact                                0.02538979
# 8  fixed    NA    author_citation_log                          -0.09829392
# 9  fixed    NA    pub_year2014                                  0.41723423
# 10 fixed    NA    pub_year2015                                  0.69680351
# 11 fixed    NA    pub_year2016                                  0.89778118
# 12 fixed    NA    pub_year2017                                  1.21431399
# 13 fixed    NA    pub_year2018                                  1.47149811
# 14 fixed    NA    Social_Sciences                               0.49686351
# 15 fixed    NA    Materials_Science                             0.15631459
# 16 fixed    NA    Engineering                                  -0.11883034
# 17 fixed    NA    Chemistry                                    -0.53702782
# 18 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.06711791
# 19 fixed    NA    Medicine                                     -0.37340832
# 20 fixed    NA    Nursing                                       0.05947735
# 21 fixed    NA    Agricultural_and_Biological_Sciences          0.23659655
# 22 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.31544462
# 23 fixed    NA    Neuroscience                                  0.03596338
# 24 fixed    NA    Business__Management_and_Accounting          -0.19582744
# 25 fixed    NA    Economics__Econometrics_and_Finance          -0.46059658
# 26 fixed    NA    Chemical_Engineering                          0.22695430
# 27 fixed    NA    Physics_and_Astronomy                        -1.12442067
# 28 fixed    NA    Computer_Science                              0.16619229
# 29 fixed    NA    Decision_Sciences                            -0.41826650
# 30 fixed    NA    Health_Professions                            0.52684836
# 31 fixed    NA    Psychology                                   -0.41381952
# 32 fixed    NA    Immunology_and_Microbiology                  -0.01689242
# 33 fixed    NA    Dentistry                                    -1.49037480
# 34 fixed    NA    Earth_and_Planetary_Sciences                 -0.15221147
# 35 fixed    NA    Environmental_Science                         0.09112992
# 36 fixed    NA    Mathematics                                  -1.11242250
# 37 fixed    NA    Arts_and_Humanities                          -0.32926028
# 38 fixed    NA    Energy                                       -0.16601651
# 39 fixed    NA    Veterinary                                   -1.43332414
# 40 fixed    NA    General                                      -0.01500114
# 41 ran_pars doi   sd__(Intercept)                               0.00000000
#    std.error   statistic   p.value
# 1  0.039818491 -74.2960715  0.000000e+00
# 2  0.016667739  -5.5130016  3.527650e-08
# 3  0.012167606  21.9499009 8.679043e-107
# 4  0.001147705 -17.7942750  7.827379e-71
# 5  0.002669630  -9.4332026  3.977549e-21
# 6  0.016455161  10.2887841  7.916973e-25
# 7  0.001061060  23.9287078 1.539696e-126
# 8  0.004342323 -22.6362510 1.905797e-113
# 9  0.033940111  12.2932489  9.846752e-35
# 10 0.032290420  21.5792644 2.813076e-103
# 11 0.031460312  28.5369442 4.079300e-179
# 12 0.031132397  39.0048348  0.000000e+00
# 13 0.030816681  47.7500509  0.000000e+00
# 14 0.020067394  24.7597421 2.434976e-135
# 15 0.100457243   1.5560311  1.197007e-01
# 16 0.055512825  -2.1405925  3.230691e-02
# 17 0.080813208  -6.6452976  3.026050e-11
# 18 0.032254932  -2.0808573  3.744697e-02
# 19 0.022570124 -16.5443629  1.758149e-61
# 20 0.055961941   1.0628179  2.878645e-01
# 21 0.032943249   7.1819433  6.872742e-13
# 22 0.083855549  -3.7617620  1.687205e-04
# 23 0.052988781   0.6786980  4.973292e-01
# 24 0.039445584  -4.9644961  6.887969e-07
# 25 0.038356511 -12.0083025  3.213739e-33
# 26 0.112702575   2.0137455  4.403626e-02
# 27 0.060919470 -18.4574926  4.539310e-76
# 28 0.045866856   3.6233633  2.907969e-04
# 29 0.097254074  -4.3007607  1.702128e-05
# 30 0.077879442   6.7649222  1.333808e-11
# 31 0.038699996 -10.6930118  1.097481e-26
# 32 0.060010476  -0.2814912  7.783337e-01
# 33 0.384599116  -3.8751384  1.065641e-04
# 34 0.047840624  -3.1816363  1.464456e-03
# 35 0.037522800   2.4286547  1.515496e-02
# 36 0.060460051 -18.3992982  1.330770e-75
# 37 0.030233044 -10.8907420  1.275963e-27
# 38 0.093473150  -1.7760877  7.571846e-02
# 39 0.223227632  -6.4209082  1.354637e-10
# 40 0.059592000  -0.2517308  8.012492e-01
# 41          NA          NA            NA

# %%
r.squaredGLMM(m_all_solo)
# Out:
# Warning message:
# “the null model is correct only if all variables used by the original model remain unchanged.”
#             R2m       R2c
# theoretical 0.1496402 0.1496402
# delta       0.0576489 0.0576489

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_all_solo, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Nov 23, 2022 - 09:02:38 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.092$^{***}$ \\
#   & p = 0.00000 \\
#   author\_pub\_count\_cate & 0.267$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.020$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.025$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.169$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.025$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.098$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.417$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.697$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.898$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.214$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.471$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.497$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & 0.156 \\
#   & p = 0.120 \\
#   Engineering & $-$0.119$^{*}$ \\
#   & p = 0.033 \\
#   Chemistry & $-$0.537$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.067$^{*}$ \\
#   & p = 0.038 \\
#   Medicine & $-$0.373$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.059 \\
#   & p = 0.288 \\
#   Agricultural\_and\_Biological\_Sciences & 0.237$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.315$^{***}$ \\
#   & p = 0.0002 \\
#   Neuroscience & 0.036 \\
#   & p = 0.498 \\
#   Business\_\_Management\_and\_Accounting & $-$0.196$^{***}$ \\
#   & p = 0.00000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.461$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & 0.227$^{*}$ \\
#   & p = 0.045 \\
#   Physics\_and\_Astronomy & $-$1.124$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.166$^{***}$ \\
#   & p = 0.0003 \\
#   Decision\_Sciences & $-$0.418$^{***}$ \\
#   & p = 0.00002 \\
#   Health\_Professions & 0.527$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.414$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.017 \\
#   & p = 0.779 \\
#   Dentistry & $-$1.490$^{***}$ \\
#   & p = 0.0002 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.152$^{**}$ \\
#   & p = 0.002 \\
#   Environmental\_Science & 0.091$^{*}$ \\
#   & p = 0.016 \\
#   Mathematics & $-$1.112$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.329$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.166 \\
#   & p = 0.076 \\
#   Veterinary & $-$1.433$^{***}$ \\
#   & p = 0.000 \\
#   General & $-$0.015 \\
#   & p = 0.802 \\
#   Constant & $-$2.958$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 176,097 \\
# Log Likelihood & $-$60,190.820 \\
# Akaike Inf. Crit. & 120,463.600 \\
# Bayesian Inf. Crit. & 120,876.900 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

# %% [markdown]
# Subset of authors of non-East Asian ethnicity

# %%
nrow(mydata)
# Out:
# [1] 11396752

# %%
table(mydata$author_eth_ethnea_broad)
# Out:
#                 African               CARIBBEAN                 Chinese
#                   72522                     787                  957964
#               EastAsian         EasternEuropean                 English
#                  606158                  564347                 3495178
#                  Indian           MiddleEastern                     org
#                  442445                  683016                     162
#              POLYNESIAN        SouthernEuropean                 unknown
#                      16                 1807743                   39553
# WesternNorthernEuropean
#                 2726861

# %%
# num of observations with East Asian names (Chinese + non-Chinese East Asian).
nrow(mydata[mydata$author_eth_ethnea_broad %in% c('Chinese', 'EastAsian', 'unknown'), ])
# Out:
# [1] 1603675

# %%
nrow(mydata[!mydata$author_eth_ethnea_broad %in% c('Chinese', 'EastAsian', 'unknown'), ])
# Out:
# [1] 9793077

# %%
base_str <- "self_promotion ~ 1 + gender + authorship_pos + author_pub_count_cate + I(author_pub_count_cate^2) + \
        affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year"
equation <- as.formula(paste(base_str, " + (1|doi) + ", keywords, sep = " "))
m_all_exc <- glmer(formula = equation, data = mydata[!mydata$author_eth_ethnea_broad %in% c('Chinese', 'EastAsian', 'unknown'), ], family = "binomial", control = glmerControl(optimizer = "nloptwrap"), nAGQ = 0)

# %%
tidy(m_all_exc)
# Out:
#    effect   group term                                         estimate
# 1  fixed    NA    (Intercept)                                  -4.298877979
# 2  fixed    NA    genderFemale                                 -0.331991022
# 3  fixed    NA    authorship_posfirst_position                  0.361318772
# 4  fixed    NA    authorship_posmiddle_position                -0.623033593
# 5  fixed    NA    authorship_possolo_author                     0.765935885
# 6  fixed    NA    author_pub_count_cate                         0.279594819
# 7  fixed    NA    I(author_pub_count_cate^2)                   -0.019727072
# 8  fixed    NA    affiliation_rank_cate                        -0.043569604
# 9  fixed    NA    affiliation_cateinternational                 0.096181908
# 10 fixed    NA    num_authors                                  -0.002130662
# 11 fixed    NA    journal_impact                                0.032464600
# 12 fixed    NA    author_citation_log                          -0.038418209
# 13 fixed    NA    pub_year2014                                  0.315211317
# 14 fixed    NA    pub_year2015                                  0.625997456
# 15 fixed    NA    pub_year2016                                  0.868247841
# 16 fixed    NA    pub_year2017                                  1.210358901
# 17 fixed    NA    pub_year2018                                  1.577680184
# 18 fixed    NA    Social_Sciences                               0.814851726
# 19 fixed    NA    Materials_Science                            -0.078270115
# 20 fixed    NA    Engineering                                  -0.439705000
# 21 fixed    NA    Chemistry                                    -0.415284914
# 22 fixed    NA    Biochemistry__Genetics_and_Molecular_Biology -0.137445566
# 23 fixed    NA    Medicine                                     -0.297594195
# 24 fixed    NA    Nursing                                       0.228017176
# 25 fixed    NA    Agricultural_and_Biological_Sciences          0.457477422
# 26 fixed    NA    Pharmacology__Toxicology_and_Pharmaceutics   -0.561676759
# 27 fixed    NA    Neuroscience                                 -0.117108968
# 28 fixed    NA    Business__Management_and_Accounting          -0.183905252
# 29 fixed    NA    Economics__Econometrics_and_Finance          -0.483736381
# 30 fixed    NA    Chemical_Engineering                          0.078682116
# 31 fixed    NA    Physics_and_Astronomy                        -0.758758020
# 32 fixed    NA    Computer_Science                              0.144322146
# 33 fixed    NA    Decision_Sciences                            -0.697055469
# 34 fixed    NA    Health_Professions                            0.870111197
# 35 fixed    NA    Psychology                                   -0.581097821
# 36 fixed    NA    Immunology_and_Microbiology                  -0.180154794
# 37 fixed    NA    Dentistry                                    -1.268409722
# 38 fixed    NA    Earth_and_Planetary_Sciences                 -0.118925023
# 39 fixed    NA    Environmental_Science                         0.163780331
# 40 fixed    NA    Mathematics                                  -0.292331826
# 41 fixed    NA    Arts_and_Humanities                          -0.244263071
# 42 fixed    NA    Energy                                       -0.349698817
# 43 fixed    NA    Veterinary                                   -0.913878544
# 44 fixed    NA    General                                       0.382287659
# 45 ran_pars doi   sd__(Intercept)                               1.450514214
#    std.error    statistic   p.value
# 1  1.175699e-02 -365.644331  0.000000e+00
# 2  3.902762e-03  -85.065659  0.000000e+00
# 3  5.070041e-03   71.265451  0.000000e+00
# 4  4.474048e-03 -139.255023  0.000000e+00
# 5  1.006810e-02   76.075512  0.000000e+00
# 6  3.259163e-03   85.787315  0.000000e+00
# 7  2.680684e-04  -73.589701  0.000000e+00
# 8  6.972592e-04  -62.486957  0.000000e+00
# 9  4.297686e-03   22.379931 6.173952e-111
# 10 7.628723e-05  -27.929474 1.170639e-171
# 11 2.901105e-04  111.904258  0.000000e+00
# 12 1.038204e-03  -37.004488 9.697905e-300
# 13 9.908639e-03   31.811766 4.450682e-222
# 14 9.336487e-03   67.048503  0.000000e+00
# 15 9.045869e-03   95.982797  0.000000e+00
# 16 8.833219e-03  137.023540  0.000000e+00
# 17 8.637966e-03  182.644868  0.000000e+00
# 18 9.095465e-03   89.588788  0.000000e+00
# 19 1.582151e-02   -4.947070  7.533882e-07
# 20 1.313110e-02  -33.485767 7.766648e-246
# 21 1.218286e-02  -34.087639 1.124625e-254
# 22 5.960269e-03  -23.060296 1.159564e-117
# 23 4.879700e-03  -60.986165  0.000000e+00
# 24 1.407588e-02   16.199144  5.113399e-59
# 25 6.782836e-03   67.446333  0.000000e+00
# 26 1.464353e-02  -38.356639  0.000000e+00
# 27 1.010745e-02  -11.586406  4.829759e-31
# 28 1.706698e-02  -10.775500  4.493353e-27
# 29 1.837465e-02  -26.326284 9.593707e-153
# 30 1.788735e-02    4.398758  1.088723e-05
# 31 1.316269e-02  -57.644587  0.000000e+00
# 32 1.347979e-02   10.706559  9.482101e-27
# 33 2.950315e-02  -23.626473 2.060420e-123
# 34 1.571340e-02   55.373826  0.000000e+00
# 35 1.334648e-02  -43.539423  0.000000e+00
# 36 1.105866e-02  -16.290828  1.146655e-59
# 37 5.351201e-02  -23.703271 3.336222e-124
# 38 1.189797e-02   -9.995402  1.596380e-23
# 39 8.927327e-03   18.345955  3.556232e-75
# 40 1.746321e-02  -16.739866  6.713955e-63
# 41 2.224972e-02  -10.978255  4.862236e-28
# 42 2.250208e-02  -15.540736  1.838588e-54
# 43 3.121767e-02  -29.274396 2.197202e-188
# 44 1.536241e-02   24.884607 1.092085e-136
# 45           NA          NA            NA

# %%
# use this search string in Sublime: " \\\\ \n  &" with " &"
stargazer(m_all_exc, type = "latex", single.row=TRUE, ci = FALSE, report = ('vc*p'), star.cutoffs = c(0.05, 0.01, 0.001))
# Out:
# % Table created by stargazer v.5.2.3 by Marek Hlavac, Social Policy Institute. E-mail: marek.hlavac at gmail.com
# % Date and time: Wed, Dec 07, 2022 - 03:40:42 PM
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{1}{c}{\textit{Dependent variable:}} \\
# \cline{2-2}
# \\[-1.8ex] & self\_promotion \\
# \hline \\[-1.8ex]
#  genderFemale & $-$0.332$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posfirst\_position & 0.361$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_posmiddle\_position & $-$0.623$^{***}$ \\
#   & p = 0.000 \\
#   authorship\_possolo\_author & 0.766$^{***}$ \\
#   & p = 0.000 \\
#   author\_pub\_count\_cate & 0.280$^{***}$ \\
#   & p = 0.000 \\
#   I(author\_pub\_count\_cate$\hat{\mkern6mu}$2) & $-$0.020$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_rank\_cate & $-$0.044$^{***}$ \\
#   & p = 0.000 \\
#   affiliation\_cateinternational & 0.096$^{***}$ \\
#   & p = 0.000 \\
#   num\_authors & $-$0.002$^{***}$ \\
#   & p = 0.000 \\
#   journal\_impact & 0.032$^{***}$ \\
#   & p = 0.000 \\
#   author\_citation\_log & $-$0.038$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2014 & 0.315$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2015 & 0.626$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2016 & 0.868$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2017 & 1.210$^{***}$ \\
#   & p = 0.000 \\
#   pub\_year2018 & 1.578$^{***}$ \\
#   & p = 0.000 \\
#   Social\_Sciences & 0.815$^{***}$ \\
#   & p = 0.000 \\
#   Materials\_Science & $-$0.078$^{***}$ \\
#   & p = 0.00000 \\
#   Engineering & $-$0.440$^{***}$ \\
#   & p = 0.000 \\
#   Chemistry & $-$0.415$^{***}$ \\
#   & p = 0.000 \\
#   Biochemistry\_\_Genetics\_and\_Molecular\_Biology & $-$0.137$^{***}$ \\
#   & p = 0.000 \\
#   Medicine & $-$0.298$^{***}$ \\
#   & p = 0.000 \\
#   Nursing & 0.228$^{***}$ \\
#   & p = 0.000 \\
#   Agricultural\_and\_Biological\_Sciences & 0.457$^{***}$ \\
#   & p = 0.000 \\
#   Pharmacology\_\_Toxicology\_and\_Pharmaceutics & $-$0.562$^{***}$ \\
#   & p = 0.000 \\
#   Neuroscience & $-$0.117$^{***}$ \\
#   & p = 0.000 \\
#   Business\_\_Management\_and\_Accounting & $-$0.184$^{***}$ \\
#   & p = 0.000 \\
#   Economics\_\_Econometrics\_and\_Finance & $-$0.484$^{***}$ \\
#   & p = 0.000 \\
#   Chemical\_Engineering & 0.079$^{***}$ \\
#   & p = 0.00002 \\
#   Physics\_and\_Astronomy & $-$0.759$^{***}$ \\
#   & p = 0.000 \\
#   Computer\_Science & 0.144$^{***}$ \\
#   & p = 0.000 \\
#   Decision\_Sciences & $-$0.697$^{***}$ \\
#   & p = 0.000 \\
#   Health\_Professions & 0.870$^{***}$ \\
#   & p = 0.000 \\
#   Psychology & $-$0.581$^{***}$ \\
#   & p = 0.000 \\
#   Immunology\_and\_Microbiology & $-$0.180$^{***}$ \\
#   & p = 0.000 \\
#   Dentistry & $-$1.268$^{***}$ \\
#   & p = 0.000 \\
#   Earth\_and\_Planetary\_Sciences & $-$0.119$^{***}$ \\
#   & p = 0.000 \\
#   Environmental\_Science & 0.164$^{***}$ \\
#   & p = 0.000 \\
#   Mathematics & $-$0.292$^{***}$ \\
#   & p = 0.000 \\
#   Arts\_and\_Humanities & $-$0.244$^{***}$ \\
#   & p = 0.000 \\
#   Energy & $-$0.350$^{***}$ \\
#   & p = 0.000 \\
#   Veterinary & $-$0.914$^{***}$ \\
#   & p = 0.000 \\
#   General & 0.382$^{***}$ \\
#   & p = 0.000 \\
#   Constant & $-$4.299$^{***}$ \\
#   & p = 0.000 \\
#  \hline \\[-1.8ex]
# Observations & 9,793,077 \\
# Log Likelihood & $-$1,606,795.000 \\
# Akaike Inf. Crit. & 3,213,680.000 \\
# Bayesian Inf. Crit. & 3,214,315.000 \\
# \hline
# \hline \\[-1.8ex]
# \textit{Note:}  & \multicolumn{1}{r}{$^{*}$p$<$0.05; $^{**}$p$<$0.01; $^{***}$p$<$0.001} \\
# \end{tabular}
# \end{table}

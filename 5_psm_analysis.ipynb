# %%
import os
import math
import json
import numpy as np
import pandas as pd
import seaborn as sns
from collections import Counter
import matplotlib.colors
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from datetime import datetime
# from patsy import dmatrices
from patsy import dmatrix
from scipy.stats import ttest_rel
from scipy.stats import ttest_ind
import statsmodels.formula.api as smf

# %%
from causalinference import CausalModel
from causalinference.utils import random_data

# %%
Data_Root = '/Data/Promotion/'

# %%
CIs = {'90': 1.645, '95': 1.96, '99': 2.576}

# %%
labels = ['Male', 'Female']

# %%
colors = sns.color_palette()[:len(labels)]

# %%
reg_data = pd.read_csv(Data_Root+"revision/reg_data_drop_missing.csv", header=0, dtype={'matched_tid': str, \
        'matched_tid_retweet': str, 'matched_tid_original': str, 'pub_year': str})

# %%
reg_data = reg_data.loc[reg_data['gender'].isin(['Female', 'Male'])]
reg_data = reg_data.loc[reg_data.affiliation_cate != 'unknown']
reg_data.index = range(len(reg_data))

# %%
len(reg_data)
# Out:
# 11396752

# %%
reg_data['author_citation_log'] = reg_data['author_citation'].apply(lambda x: np.log2(x+1))

# %%
reg_data['gender_CT'] = reg_data['gender'].apply(lambda gen: 1 if gen == 'Female' else 0)

# %%
co_feats_ = ['authorship_pos', 'author_pub_count_cate', 'affiliation_rank_cate', 'affiliation_cate', 'num_authors', \
         'journal_impact', 'author_citation_log', 'pub_year', \
        'Social_Sciences', 'Materials_Science', 'Engineering', 'Chemistry',
       'Biochemistry__Genetics_and_Molecular_Biology', 'Medicine', 'Nursing',
       'Agricultural_and_Biological_Sciences',
       'Pharmacology__Toxicology_and_Pharmaceutics', 'Neuroscience',
       'Business__Management_and_Accounting',
       'Economics__Econometrics_and_Finance', 'Chemical_Engineering',
       'Physics_and_Astronomy', 'Computer_Science', 'Decision_Sciences',
       'Health_Professions', 'Psychology', 'Immunology_and_Microbiology',
       'Dentistry', 'Earth_and_Planetary_Sciences', 'Environmental_Science',
       'Mathematics', 'Arts_and_Humanities', 'Energy', 'Veterinary', 'General']

# %%
X = dmatrix(formula_like=' + '.join(co_feats_), data=reg_data, return_type="dataframe")

# %%
list(X.columns)
# Out:
# ['Intercept',
#  'authorship_pos[T.last_position]',
#  'authorship_pos[T.middle_position]',
#  'authorship_pos[T.solo_author]',
#  'affiliation_cate[T.international]',
#  'pub_year[T.2014]',
#  'pub_year[T.2015]',
#  'pub_year[T.2016]',
#  'pub_year[T.2017]',
#  'pub_year[T.2018]',
#  'author_pub_count_cate',
#  'affiliation_rank_cate',
#  'num_authors',
#  'journal_impact',
#  'author_citation_log',
#  'Social_Sciences',
#  'Materials_Science',
#  'Engineering',
#  'Chemistry',
#  'Biochemistry__Genetics_and_Molecular_Biology',
#  'Medicine',
#  'Nursing',
#  'Agricultural_and_Biological_Sciences',
#  'Pharmacology__Toxicology_and_Pharmaceutics',
#  'Neuroscience',
#  'Business__Management_and_Accounting',
#  'Economics__Econometrics_and_Finance',
#  'Chemical_Engineering',
#  'Physics_and_Astronomy',
#  'Computer_Science',
#  'Decision_Sciences',
#  'Health_Professions',
#  'Psychology',
#  'Immunology_and_Microbiology',
#  'Dentistry',
#  'Earth_and_Planetary_Sciences',
#  'Environmental_Science',
#  'Mathematics',
#  'Arts_and_Humanities',
#  'Energy',
#  'Veterinary',
#  'General']

# %%
X['gender'] = reg_data['gender']
X['gender_CT'] = reg_data['gender_CT']
X['self_promotion'] = reg_data['self_promotion']

# %%
co_feats = [
 'authorship_pos[T.last_position]',
 'authorship_pos[T.middle_position]',
 'authorship_pos[T.solo_author]',
 'affiliation_cate[T.international]',
 'pub_year[T.2014]',
 'pub_year[T.2015]',
 'pub_year[T.2016]',
 'pub_year[T.2017]',
 'pub_year[T.2018]',
 'author_pub_count_cate',
 'affiliation_rank_cate',
 'num_authors',
 'journal_impact',
 'author_citation_log',
 'Social_Sciences',
 'Materials_Science',
 'Engineering',
 'Chemistry',
 'Biochemistry__Genetics_and_Molecular_Biology',
 'Medicine',
 'Nursing',
 'Agricultural_and_Biological_Sciences',
 'Pharmacology__Toxicology_and_Pharmaceutics',
 'Neuroscience',
 'Business__Management_and_Accounting',
 'Economics__Econometrics_and_Finance',
 'Chemical_Engineering',
 'Physics_and_Astronomy',
 'Computer_Science',
 'Decision_Sciences',
 'Health_Professions',
 'Psychology',
 'Immunology_and_Microbiology',
 'Dentistry',
 'Earth_and_Planetary_Sciences',
 'Environmental_Science',
 'Mathematics',
 'Arts_and_Humanities',
 'Energy',
 'Veterinary',
 'General']

# %%
# Y is the outcome, D is treatment status, and X is the independent variable
causal = CausalModel(Y=X['self_promotion'].values, D=X['gender_CT'].values, \
                     X=X[co_feats].values)

# %%
print(causal.summary_stats)
# Out:
# Summary Statistics
#
#                    Controls (N_c=7371102)     Treated (N_t=4025650)
#        Variable         Mean         S.d.         Mean         S.d.     Raw-diff
# --------------------------------------------------------------------------------
#               Y        0.046        0.210        0.035        0.183       -0.011
#
#                    Controls (N_c=7371102)     Treated (N_t=4025650)
#        Variable         Mean         S.d.         Mean         S.d.     Nor-diff
# --------------------------------------------------------------------------------
#              X0        0.192        0.394        0.135        0.342       -0.153
#              X1        0.640        0.480        0.658        0.474        0.037
#              X2        0.017        0.128        0.013        0.114       -0.030
#              X3        0.653        0.476        0.650        0.477       -0.006
#              X4        0.150        0.357        0.148        0.355       -0.006
#              X5        0.168        0.374        0.172        0.377        0.010
#              X6        0.179        0.384        0.185        0.388        0.014
#              X7        0.184        0.388        0.190        0.392        0.014
#              X8        0.185        0.389        0.177        0.382       -0.021
#              X9        5.409        2.739        4.084        2.618       -0.495
#             X10        4.278        2.843        4.351        2.855        0.026
#             X11       59.758      321.328       30.234      205.111       -0.110
#             X12        5.587        6.773        5.234        6.387       -0.054
#             X13        7.838        4.406        5.926        4.301       -0.439
#             X14        0.063        0.242        0.085        0.279        0.087
#             X15        0.041        0.198        0.028        0.164       -0.073
#             X16        0.047        0.211        0.027        0.162       -0.106
#             X17        0.058        0.233        0.046        0.209       -0.054
#             X18        0.217        0.412        0.246        0.431        0.068
#             X19        0.397        0.489        0.457        0.498        0.120
#             X20        0.014        0.116        0.029        0.168        0.106
#             X21        0.111        0.314        0.114        0.318        0.010
#             X22        0.033        0.179        0.040        0.196        0.037
#             X23        0.048        0.214        0.054        0.226        0.027
#             X24        0.010        0.100        0.009        0.093       -0.014
#             X25        0.009        0.094        0.006        0.076       -0.036
#             X26        0.023        0.150        0.018        0.131       -0.038
#             X27        0.088        0.283        0.039        0.193       -0.203
#             X28        0.027        0.162        0.014        0.118       -0.089
#             X29        0.005        0.070        0.003        0.054       -0.033
#             X30        0.010        0.101        0.011        0.103        0.005
#             X31        0.022        0.145        0.040        0.195        0.105
#             X32        0.046        0.210        0.056        0.230        0.044
#             X33        0.004        0.065        0.004        0.062       -0.008
#             X34        0.037        0.190        0.022        0.146       -0.092
#             X35        0.049        0.216        0.044        0.206       -0.024
#             X36        0.020        0.141        0.010        0.098       -0.088
#             X37        0.004        0.061        0.004        0.065        0.009
#             X38        0.011        0.106        0.006        0.079       -0.054
#             X39        0.008        0.088        0.010        0.099        0.021
#             X40        0.018        0.131        0.014        0.117       -0.030

# %%
causal.est_propensity()

# %%
# Automated propensity score estimation of which features to use in the matching.
# causal.est_propensity_s()

# %%
# Propensity model results
print(causal.propensity)
# Out:
# Estimated Parameters of Propensity Score
#
#                     Coef.       S.e.          z      P>|z|      [95% Conf. int.]
# --------------------------------------------------------------------------------
#      Intercept      0.225      0.003     75.843      0.000      0.219      0.231
#             X0     -0.167      0.002    -71.758      0.000     -0.172     -0.162
#             X1     -0.030      0.002    -16.818      0.000     -0.033     -0.026
#             X2     -0.358      0.006    -62.505      0.000     -0.369     -0.347
#             X3      0.048      0.001     32.877      0.000      0.045      0.050
#             X4      0.033      0.002     13.401      0.000      0.028      0.038
#             X5      0.068      0.002     28.586      0.000      0.063      0.072
#             X6      0.100      0.002     42.848      0.000      0.096      0.105
#             X7      0.127      0.002     54.302      0.000      0.122      0.131
#             X8      0.188      0.002     79.389      0.000      0.183      0.193
#             X9     -0.193      0.001   -316.640      0.000     -0.195     -0.192
#            X10     -0.021      0.000    -88.081      0.000     -0.022     -0.021
#            X11      0.000      0.000     52.411      0.000      0.000      0.000
#            X12     -0.004      0.000    -36.529      0.000     -0.004     -0.004
#            X13      0.011      0.000     30.006      0.000      0.010      0.012
#            X14      0.378      0.004     93.718      0.000      0.370      0.386
#            X15      0.041      0.004      9.201      0.000      0.032      0.049
#            X16     -0.307      0.004    -75.258      0.000     -0.315     -0.299
#            X17     -0.087      0.003    -25.984      0.000     -0.093     -0.080
#            X18      0.102      0.002     61.426      0.000      0.099      0.106
#            X19      0.151      0.001    103.778      0.000      0.148      0.154
#            X20      0.675      0.005    148.962      0.000      0.666      0.683
#            X21     -0.083      0.002    -37.370      0.000     -0.087     -0.079
#            X22      0.124      0.003     36.097      0.000      0.117      0.130
#            X23      0.017      0.003      5.914      0.000      0.012      0.023
#            X24     -0.180      0.008    -23.972      0.000     -0.195     -0.165
#            X25     -0.647      0.009    -75.340      0.000     -0.664     -0.630
#            X26     -0.108      0.005    -20.720      0.000     -0.119     -0.098
#            X27     -0.594      0.004   -163.280      0.000     -0.602     -0.587
#            X28     -0.418      0.005    -79.256      0.000     -0.429     -0.408
#            X29     -0.406      0.012    -34.365      0.000     -0.429     -0.383
#            X30     -0.070      0.006    -11.017      0.000     -0.082     -0.057
#            X31      0.227      0.005     43.267      0.000      0.217      0.238
#            X32      0.092      0.003     31.293      0.000      0.086      0.098
#            X33     -0.217      0.010    -21.326      0.000     -0.237     -0.197
#            X34     -0.318      0.004    -75.850      0.000     -0.326     -0.310
#            X35     -0.011      0.003     -3.468      0.001     -0.018     -0.005
#            X36     -0.399      0.006    -63.059      0.000     -0.411     -0.386
#            X37     -0.221      0.011    -20.887      0.000     -0.242     -0.200
#            X38     -0.372      0.008    -49.061      0.000     -0.387     -0.358
#            X39      0.122      0.007     17.804      0.000      0.108      0.135
#            X40     -0.158      0.006    -27.935      0.000     -0.169     -0.147

# %%
causal.propensity['fitted']
# Out:
# array([0.22737879, 0.42781661, 0.34181751, ..., 0.29336662, 0.44319718,
#        0.54685937])

# %% [markdown]
# ### 1 on 1 matching using the nearest neighbor

# %% [markdown]
# Check covariate balance before matching

# %%
for feat in co_feats:
    print(feat)
    f_avg = np.mean(X.loc[X['gender']=='Female', feat])
    m_avg = np.mean(X.loc[X['gender']=='Male', feat])
    print('\tFemale:\t', f_avg)
    print('\tMale:\t', m_avg)
    print('\tDiff:\t', f_avg-m_avg)
    print('\tT-test:\t', ttest_ind(X.loc[X['gender']=='Female', feat], X.loc[X['gender']=='Male', feat])[1])
# Out:
# authorship_pos[T.last_position]
# 	Female:	 0.13526237998832485
# 	Male:	 0.19153947401623259
# 	Diff:	 -0.05627709402790773
# 	T-test:	 0.0
# authorship_pos[T.middle_position]
# 	Female:	 0.6580847813396594
# 	Male:	 0.6402958472152468
# 	Diff:	 0.017788934124412625
# 	T-test:	 0.0
# authorship_pos[T.solo_author]
# 	Female:	 0.013133282823891795
# 	Male:	 0.016717581713019302
# 	Diff:	 -0.0035842988891275074
# 	T-test:	 0.0
# affiliation_cate[T.international]
# 	Female:	 0.650354601120316
# 	Male:	 0.6530828090562306
# 	Diff:	 -0.0027282079359146616
# 	T-test:	 2.4062679946893132e-20
# pub_year[T.2014]
# 	Female:	 0.14788270217232
# 	Male:	 0.14987067062699716
# 	Diff:	 -0.0019879684546771637
# 	T-test:	 2.1730750520364815e-19
# pub_year[T.2015]
# 	Female:	 0.17185721560493336
# 	Male:	 0.1679662009832451
# 	Diff:	 0.0038910146216882546
# 	T-test:	 6.648496794265946e-63
# pub_year[T.2016]
# 	Female:	 0.18450958230347894
# 	Male:	 0.17919735746432489
# 	Diff:	 0.005312224839154056
# 	T-test:	 9.030368977533984e-110
# pub_year[T.2017]
# 	Female:	 0.1898771626942233
# 	Male:	 0.18427190398396331
# 	Diff:	 0.0056052587102599916
# 	T-test:	 2.1296198888138154e-119
# pub_year[T.2018]
# 	Female:	 0.17721610174754387
# 	Male:	 0.18533416034671613
# 	Diff:	 -0.008118058599172251
# 	T-test:	 3.7926501873229636e-252
# author_pub_count_cate
# 	Female:	 4.083574081204278
# 	Male:	 5.408816076619209
# 	Diff:	 -1.325241995414931
# 	T-test:	 0.0
# affiliation_rank_cate
# 	Female:	 4.351107771415796
# 	Male:	 4.278362448382888
# 	Diff:	 0.07274532303290826
# 	T-test:	 0.0
# num_authors
# 	Female:	 30.234357432961136
# 	Male:	 59.75761670371676
# 	Diff:	 -29.52325927075562
# 	T-test:	 0.0
# journal_impact
# 	Female:	 5.2335768996311165
# 	Male:	 5.587131912433172
# 	Diff:	 -0.3535550128020555
# 	T-test:	 0.0
# author_citation_log
# 	Female:	 5.925967647807714
# 	Male:	 7.8381556507593055
# 	Diff:	 -1.9121880029515914
# 	T-test:	 0.0
# Social_Sciences
# 	Female:	 0.08525554879336256
# 	Male:	 0.0625295919117657
# 	Diff:	 0.022725956881596857
# 	T-test:	 0.0
# Materials_Science
# 	Female:	 0.027651683579049346
# 	Male:	 0.04093146452185847
# 	Diff:	 -0.01327978094280912
# 	T-test:	 0.0
# Engineering
# 	Female:	 0.02683293381193099
# 	Male:	 0.04685283150334916
# 	Diff:	 -0.020019897691418168
# 	T-test:	 0.0
# Chemistry
# 	Female:	 0.04568107013774173
# 	Male:	 0.05754512690232749
# 	Diff:	 -0.01186405676458576
# 	T-test:	 0.0
# Biochemistry__Genetics_and_Molecular_Biology
# 	Female:	 0.24596027970638282
# 	Male:	 0.21738092893030106
# 	Diff:	 0.028579350776081758
# 	T-test:	 0.0
# Medicine
# 	Female:	 0.4565071479140015
# 	Male:	 0.3973910549603031
# 	Diff:	 0.05911609295369841
# 	T-test:	 0.0
# Nursing
# 	Female:	 0.029067852396507398
# 	Male:	 0.013703378409361314
# 	Diff:	 0.015364473987146084
# 	T-test:	 0.0
# Agricultural_and_Biological_Sciences
# 	Female:	 0.11412815321749283
# 	Male:	 0.11102763196059422
# 	Diff:	 0.0031005212568986085
# 	T-test:	 1.267687674299663e-56
# Pharmacology__Toxicology_and_Pharmaceutics
# 	Female:	 0.04006135655111597
# 	Male:	 0.03308216329118767
# 	Diff:	 0.006979193259928303
# 	T-test:	 0.0
# Neuroscience
# 	Female:	 0.05414703215629774
# 	Male:	 0.04820676745485275
# 	Diff:	 0.005940264701444993
# 	T-test:	 0.0
# Business__Management_and_Accounting
# 	Female:	 0.008794604598015227
# 	Male:	 0.010140003489301871
# 	Diff:	 -0.0013453988912866446
# 	T-test:	 4.26479537425425e-109
# Economics__Econometrics_and_Finance
# 	Female:	 0.0057940953634816736
# 	Male:	 0.008899212085248583
# 	Diff:	 -0.003105116721766909
# 	T-test:	 0.0
# Chemical_Engineering
# 	Female:	 0.017548470433346168
# 	Male:	 0.022919910754185736
# 	Diff:	 -0.005371440320839568
# 	T-test:	 0.0
# Physics_and_Astronomy
# 	Female:	 0.03856768472172196
# 	Male:	 0.08781400664378271
# 	Diff:	 -0.04924632192206075
# 	T-test:	 0.0
# Computer_Science
# 	Female:	 0.014188267733161104
# 	Male:	 0.026809966813646047
# 	Diff:	 -0.012621699080484943
# 	T-test:	 0.0
# Decision_Sciences
# 	Female:	 0.002887732415883149
# 	Male:	 0.004968320883363166
# 	Diff:	 -0.0020805884674800165
# 	T-test:	 0.0
# Health_Professions
# 	Female:	 0.01080868927999205
# 	Male:	 0.01029045589112727
# 	Diff:	 0.0005182333888647805
# 	T-test:	 2.1376736710195383e-16
# Psychology
# 	Female:	 0.039713835032851835
# 	Male:	 0.02157696366160718
# 	Diff:	 0.018136871371244655
# 	T-test:	 0.0
# Immunology_and_Microbiology
# 	Female:	 0.0558217927539652
# 	Male:	 0.04621249305734746
# 	Diff:	 0.009609299696617737
# 	T-test:	 0.0
# Dentistry
# 	Female:	 0.003810316346428527
# 	Male:	 0.004295287190436383
# 	Diff:	 -0.0004849708440078557
# 	T-test:	 2.7167914326577253e-34
# Earth_and_Planetary_Sciences
# 	Female:	 0.021717983431247128
# 	Male:	 0.037316265600448886
# 	Diff:	 -0.015598282169201758
# 	T-test:	 0.0
# Environmental_Science
# 	Female:	 0.04421919441580863
# 	Male:	 0.04921611449685542
# 	Diff:	 -0.004996920081046796
# 	T-test:	 0.0
# Mathematics
# 	Female:	 0.009694831890502156
# 	Male:	 0.020392744531279042
# 	Diff:	 -0.010697912640776887
# 	T-test:	 0.0
# Arts_and_Humanities
# 	Female:	 0.004273595568417523
# 	Male:	 0.003705958756234821
# 	Diff:	 0.000567636812182702
# 	T-test:	 8.245266369292056e-49
# Energy
# 	Female:	 0.006330654676884478
# 	Male:	 0.011370077364280131
# 	Diff:	 -0.005039422687395653
# 	T-test:	 0.0
# Veterinary
# 	Female:	 0.009884863313998982
# 	Male:	 0.00788267480222089
# 	Diff:	 0.0020021885117780924
# 	T-test:	 1.5968424301255844e-268
# General
# 	Female:	 0.01378311577012408
# 	Male:	 0.017548665043571506
# 	Diff:	 -0.003765549273447426
# 	T-test:	 0.0

# %%
len(causal.propensity['fitted'])
# Out:
# 11396752

# %%
X['pscore'] = causal.propensity['fitted']

# %%
tem = X[['gender', 'pscore']].sort_values(by = ['pscore'])
tem['index'] = tem.index

# %%
tem = tem.values.tolist()

# %%
tem[-10:]
# Out:
# [['Female', 0.8572876306171883, 3463197],
#  ['Female', 0.8575073542839112, 4991019],
#  ['Male', 0.8580432050696255, 5813196],
#  ['Male', 0.8587982301092821, 5556808],
#  ['Female', 0.8593047742409025, 2470824],
#  ['Female', 0.8593657656142847, 9668339],
#  ['Female', 0.8593657656142847, 9668340],
#  ['Female', 0.8593657656142847, 9668337],
#  ['Female', 0.8593737653763763, 3176813],
#  ['Female', 0.8610430114682025, 1008134]]

# %%
leng = len(tem)

# %%
pairs = {}

for i, elms in enumerate(tem):
    gen, score, ix = elms
    if gen == 'Female':
        pre_male_ix, nex_male_ix = 0, 0
        j = i-1
        while j >= 0:
            if tem[j][0] != 'Male':
                j -= 1
            else:
                break
        if j >= 0:
            pre_male_ix = j
        n = i+1
        while n <= leng-1:
            if tem[n][0] != 'Male':
                n += 1
            else:
                break
        if n <= leng-1:
            nex_male_ix = n
        if abs(score - tem[pre_male_ix][1]) <= abs(score - tem[nex_male_ix][1]):
            pairs[ix] = tem[pre_male_ix][2]
        else:
            pairs[ix] = tem[nex_male_ix][2]

# %%
del tem

# %%
len(pairs)
# Out:
# 4025650

# %% [markdown]
# Check covariate balance after matching

# %%
for feat in co_feats:
    print('\n')
    print('Feat:', feat, '\n')
    print('Before matching:\n')
    f_avg = np.mean(X.loc[X['gender']=='Female', feat])
    m_avg = np.mean(X.loc[X['gender']=='Male', feat])
    print('\tFemale:\t', f_avg)
    print('\tMale:\t', m_avg)
    print('\tDiff:\t', f_avg-m_avg)
    print('\tT-test:\t', ttest_ind(X.loc[X['gender']=='Female', feat], X.loc[X['gender']=='Male', feat])[1])

    print('\nAfter matching:\n')
    f_avg = np.mean(X.loc[pairs.keys(), feat])
    m_avg = np.mean(X.loc[pairs.values(), feat])
    print('\tFemale:\t', f_avg)
    print('\tMale:\t', m_avg)
    print('\tDiff:\t', f_avg-m_avg)
    print('\tT-test:\t', ttest_rel(X.loc[pairs.keys(), feat], X.loc[pairs.values(), feat])[1])
# Out:
# Feat: authorship_pos[T.last_position]
#
# Before matching:
#
# 	Female:	 0.13526237998832485
# 	Male:	 0.19153947401623259
# 	Diff:	 -0.05627709402790773
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.13526237998832485
# 	Male:	 0.13353868319401835
# 	Diff:	 0.0017236967943065062
# 	T-test:	 6.248364245614255e-14
#
#
# Feat: authorship_pos[T.middle_position]
#
# Before matching:
#
# 	Female:	 0.6580847813396594
# 	Male:	 0.6402958472152468
# 	Diff:	 0.017788934124412625
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.6580847813396594
# 	Male:	 0.6613505893458199
# 	Diff:	 -0.0032658080061604977
# 	T-test:	 1.1390925041909596e-23
#
#
# Feat: authorship_pos[T.solo_author]
#
# Before matching:
#
# 	Female:	 0.013133282823891795
# 	Male:	 0.016717581713019302
# 	Diff:	 -0.0035842988891275074
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.013133282823891795
# 	Male:	 0.013181722206351769
# 	Diff:	 -4.843938245997423e-05
# 	T-test:	 0.5414911717758715
#
#
# Feat: affiliation_cate[T.international]
#
# Before matching:
#
# 	Female:	 0.650354601120316
# 	Male:	 0.6530828090562306
# 	Diff:	 -0.0027282079359146616
# 	T-test:	 2.4062679946893132e-20
#
# After matching:
#
# 	Female:	 0.650354601120316
# 	Male:	 0.6519404319799287
# 	Diff:	 -0.0015858308596127246
# 	T-test:	 1.136250592648589e-06
#
#
# Feat: pub_year[T.2014]
#
# Before matching:
#
# 	Female:	 0.14788270217232
# 	Male:	 0.14987067062699716
# 	Diff:	 -0.0019879684546771637
# 	T-test:	 2.1730750520364815e-19
#
# After matching:
#
# 	Female:	 0.14788270217232
# 	Male:	 0.1483121980301318
# 	Diff:	 -0.0004294958578117958
# 	T-test:	 0.0754948906907164
#
#
# Feat: pub_year[T.2015]
#
# Before matching:
#
# 	Female:	 0.17185721560493336
# 	Male:	 0.1679662009832451
# 	Diff:	 0.0038910146216882546
# 	T-test:	 6.648496794265946e-63
#
# After matching:
#
# 	Female:	 0.17185721560493336
# 	Male:	 0.17221864792021163
# 	Diff:	 -0.0003614323152782706
# 	T-test:	 0.15873176583049387
#
#
# Feat: pub_year[T.2016]
#
# Before matching:
#
# 	Female:	 0.18450958230347894
# 	Male:	 0.17919735746432489
# 	Diff:	 0.005312224839154056
# 	T-test:	 9.030368977533984e-110
#
# After matching:
#
# 	Female:	 0.18450958230347894
# 	Male:	 0.18395687652925616
# 	Diff:	 0.0005527057742227837
# 	T-test:	 0.036280444092521937
#
#
# Feat: pub_year[T.2017]
#
# Before matching:
#
# 	Female:	 0.1898771626942233
# 	Male:	 0.18427190398396331
# 	Diff:	 0.0056052587102599916
# 	T-test:	 2.1296198888138154e-119
#
# After matching:
#
# 	Female:	 0.1898771626942233
# 	Male:	 0.18999540446884355
# 	Diff:	 -0.00011824177462024799
# 	T-test:	 0.6570640700158412
#
#
# Feat: pub_year[T.2018]
#
# Before matching:
#
# 	Female:	 0.17721610174754387
# 	Male:	 0.18533416034671613
# 	Diff:	 -0.008118058599172251
# 	T-test:	 3.7926501873229636e-252
#
# After matching:
#
# 	Female:	 0.17721610174754387
# 	Male:	 0.17591022567784084
# 	Diff:	 0.0013058760697030325
# 	T-test:	 7.815588342342786e-07
#
#
# Feat: author_pub_count_cate
#
# Before matching:
#
# 	Female:	 4.083574081204278
# 	Male:	 5.408816076619209
# 	Diff:	 -1.325241995414931
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 4.083574081204278
# 	Male:	 4.038385105510911
# 	Diff:	 0.04518897569336655
# 	T-test:	 0.0
#
#
# Feat: affiliation_rank_cate
#
# Before matching:
#
# 	Female:	 4.351107771415796
# 	Male:	 4.278362448382888
# 	Diff:	 0.07274532303290826
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 4.351107771415796
# 	Male:	 4.383269782519593
# 	Diff:	 -0.03216201110379746
# 	T-test:	 3.9140290492653784e-61
#
#
# Feat: num_authors
#
# Before matching:
#
# 	Female:	 30.234357432961136
# 	Male:	 59.75761670371676
# 	Diff:	 -29.52325927075562
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 30.234357432961136
# 	Male:	 27.18848459255027
# 	Diff:	 3.0458728404108655
# 	T-test:	 1.069658756483827e-142
#
#
# Feat: journal_impact
#
# Before matching:
#
# 	Female:	 5.2335768996311165
# 	Male:	 5.587131912433172
# 	Diff:	 -0.3535550128020555
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 5.233576899631116
# 	Male:	 5.248401342888726
# 	Diff:	 -0.01482444325761012
# 	T-test:	 0.0005011415081046972
#
#
# Feat: author_citation_log
#
# Before matching:
#
# 	Female:	 5.925967647807714
# 	Male:	 7.8381556507593055
# 	Diff:	 -1.9121880029515914
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 5.925967647807719
# 	Male:	 5.847736420095895
# 	Diff:	 0.07823122771182334
# 	T-test:	 0.0
#
#
# Feat: Social_Sciences
#
# Before matching:
#
# 	Female:	 0.08525554879336256
# 	Male:	 0.0625295919117657
# 	Diff:	 0.022725956881596857
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.08525554879336256
# 	Male:	 0.08183523157750922
# 	Diff:	 0.0034203172158533413
# 	T-test:	 2.678471781724054e-77
#
#
# Feat: Materials_Science
#
# Before matching:
#
# 	Female:	 0.027651683579049346
# 	Male:	 0.04093146452185847
# 	Diff:	 -0.01327978094280912
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.027651683579049346
# 	Male:	 0.02912672487672798
# 	Diff:	 -0.001475041297678635
# 	T-test:	 2.394734814192785e-39
#
#
# Feat: Engineering
#
# Before matching:
#
# 	Female:	 0.02683293381193099
# 	Male:	 0.04685283150334916
# 	Diff:	 -0.020019897691418168
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.02683293381193099
# 	Male:	 0.028284624843193024
# 	Diff:	 -0.0014516910312620326
# 	T-test:	 6.2731811413942515e-40
#
#
# Feat: Chemistry
#
# Before matching:
#
# 	Female:	 0.04568107013774173
# 	Male:	 0.05754512690232749
# 	Diff:	 -0.01186405676458576
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.04568107013774173
# 	Male:	 0.0475185373790568
# 	Diff:	 -0.0018374672413150675
# 	T-test:	 8.12823833797459e-38
#
#
# Feat: Biochemistry__Genetics_and_Molecular_Biology
#
# Before matching:
#
# 	Female:	 0.24596027970638282
# 	Male:	 0.21738092893030106
# 	Diff:	 0.028579350776081758
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.24596027970638282
# 	Male:	 0.24961335436513357
# 	Diff:	 -0.0036530746587507545
# 	T-test:	 1.3287809017220994e-36
#
#
# Feat: Medicine
#
# Before matching:
#
# 	Female:	 0.4565071479140015
# 	Male:	 0.3973910549603031
# 	Diff:	 0.05911609295369841
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.4565071479140015
# 	Male:	 0.45207631065790616
# 	Diff:	 0.004430837256095332
# 	T-test:	 7.680189580211876e-41
#
#
# Feat: Nursing
#
# Before matching:
#
# 	Female:	 0.029067852396507398
# 	Male:	 0.013703378409361314
# 	Diff:	 0.015364473987146084
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.029067852396507398
# 	Male:	 0.02639648255561214
# 	Diff:	 0.0026713698408952595
# 	T-test:	 7.142905712552254e-147
#
#
# Feat: Agricultural_and_Biological_Sciences
#
# Before matching:
#
# 	Female:	 0.11412815321749283
# 	Male:	 0.11102763196059422
# 	Diff:	 0.0031005212568986085
# 	T-test:	 1.267687674299663e-56
#
# After matching:
#
# 	Female:	 0.11412815321749283
# 	Male:	 0.11779017053146697
# 	Diff:	 -0.003662017313974142
# 	T-test:	 2.2594548373618223e-67
#
#
# Feat: Pharmacology__Toxicology_and_Pharmaceutics
#
# Before matching:
#
# 	Female:	 0.04006135655111597
# 	Male:	 0.03308216329118767
# 	Diff:	 0.006979193259928303
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.04006135655111597
# 	Male:	 0.039648752375392796
# 	Diff:	 0.00041260417572317604
# 	T-test:	 0.0020346345356642126
#
#
# Feat: Neuroscience
#
# Before matching:
#
# 	Female:	 0.05414703215629774
# 	Male:	 0.04820676745485275
# 	Diff:	 0.005940264701444993
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.05414703215629774
# 	Male:	 0.05359134549700048
# 	Diff:	 0.0005556866592972623
# 	T-test:	 0.00034103361272138684
#
#
# Feat: Business__Management_and_Accounting
#
# Before matching:
#
# 	Female:	 0.008794604598015227
# 	Male:	 0.010140003489301871
# 	Diff:	 -0.0013453988912866446
# 	T-test:	 4.26479537425425e-109
#
# After matching:
#
# 	Female:	 0.008794604598015227
# 	Male:	 0.009050712307329251
# 	Diff:	 -0.0002561077093140244
# 	T-test:	 9.694015822676427e-05
#
#
# Feat: Economics__Econometrics_and_Finance
#
# Before matching:
#
# 	Female:	 0.0057940953634816736
# 	Male:	 0.008899212085248583
# 	Diff:	 -0.003105116721766909
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.0057940953634816736
# 	Male:	 0.005884515544073628
# 	Diff:	 -9.04201805919545e-05
# 	T-test:	 0.08894132420293582
#
#
# Feat: Chemical_Engineering
#
# Before matching:
#
# 	Female:	 0.017548470433346168
# 	Male:	 0.022919910754185736
# 	Diff:	 -0.005371440320839568
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.017548470433346168
# 	Male:	 0.01851055109112814
# 	Diff:	 -0.0009620806577819718
# 	T-test:	 2.0375951452984157e-26
#
#
# Feat: Physics_and_Astronomy
#
# Before matching:
#
# 	Female:	 0.03856768472172196
# 	Male:	 0.08781400664378271
# 	Diff:	 -0.04924632192206075
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.03856768472172196
# 	Male:	 0.03884018729894551
# 	Diff:	 -0.00027250257722355453
# 	T-test:	 0.01585651470021931
#
#
# Feat: Computer_Science
#
# Before matching:
# 	Female:	 0.014188267733161104
# 	Male:	 0.026809966813646047
# 	Diff:	 -0.012621699080484943
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.014188267733161104
# 	Male:	 0.015094456795796952
# 	Diff:	 -0.0009061890626358479
# 	T-test:	 7.081347405790692e-29
#
#
# Feat: Decision_Sciences
#
# Before matching:
#
# 	Female:	 0.002887732415883149
# 	Male:	 0.004968320883363166
# 	Diff:	 -0.0020805884674800165
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.002887732415883149
# 	Male:	 0.0030330505632630753
# 	Diff:	 -0.00014531814737992615
# 	T-test:	 0.00012205663626571385
#
#
# Feat: Health_Professions
#
# Before matching:
#
# 	Female:	 0.01080868927999205
# 	Male:	 0.01029045589112727
# 	Diff:	 0.0005182333888647805
# 	T-test:	 2.1376736710195383e-16
#
# After matching:
#
# 	Female:	 0.01080868927999205
# 	Male:	 0.01072075317029548
# 	Diff:	 8.79361096965698e-05
# 	T-test:	 0.2181137076569987
#
#
# Feat: Psychology
#
# Before matching:
#
# 	Female:	 0.039713835032851835
# 	Male:	 0.02157696366160718
# 	Diff:	 0.018136871371244655
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.039713835032851835
# 	Male:	 0.03651907145429931
# 	Diff:	 0.0031947635785525286
# 	T-test:	 4.467027864096212e-143
#
#
# Feat: Immunology_and_Microbiology
#
# Before matching:
#
# 	Female:	 0.0558217927539652
# 	Male:	 0.04621249305734746
# 	Diff:	 0.009609299696617737
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.0558217927539652
# 	Male:	 0.05516202352415138
# 	Diff:	 0.0006597692298138183
# 	T-test:	 2.4654541418494593e-05
#
#
# Feat: Dentistry
#
# Before matching:
#
# 	Female:	 0.003810316346428527
# 	Male:	 0.004295287190436383
# 	Diff:	 -0.0004849708440078557
# 	T-test:	 2.7167914326577253e-34
#
# After matching:
#
# 	Female:	 0.003810316346428527
# 	Male:	 0.0038917938717971013
# 	Diff:	 -8.14775253685741e-05
# 	T-test:	 0.055948039327069016
#
#
# Feat: Earth_and_Planetary_Sciences
#
# Before matching:
#
# 	Female:	 0.021717983431247128
# 	Male:	 0.037316265600448886
# 	Diff:	 -0.015598282169201758
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.021717983431247128
# 	Male:	 0.022360115757703726
# 	Diff:	 -0.000642132326456598
# 	T-test:	 1.3875538078773445e-10
#
#
# Feat: Environmental_Science
#
# Before matching:
#
# 	Female:	 0.04421919441580863
# 	Male:	 0.04921611449685542
# 	Diff:	 -0.004996920081046796
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.04421919441580863
# 	Male:	 0.04525728764298933
# 	Diff:	 -0.0010380932271807017
# 	T-test:	 3.119568176512098e-13
#
#
# Feat: Mathematics
#
# Before matching:
#
# 	Female:	 0.009694831890502156
# 	Male:	 0.020392744531279042
# 	Diff:	 -0.010697912640776887
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.009694831890502156
# 	Male:	 0.010277098108380013
# 	Diff:	 -0.0005822662178778578
# 	T-test:	 3.545576801085217e-18
#
#
# Feat: Arts_and_Humanities
#
# Before matching:
#
# 	Female:	 0.004273595568417523
# 	Male:	 0.003705958756234821
# 	Diff:	 0.000567636812182702
# 	T-test:	 8.245266369292056e-49
#
# After matching:
#
# 	Female:	 0.004273595568417523
# 	Male:	 0.004275086010954753
# 	Diff:	 -1.490442537229776e-06
# 	T-test:	 0.9738464931411612
#
#
# Feat: Energy
#
# Before matching:
#
# 	Female:	 0.006330654676884478
# 	Male:	 0.011370077364280131
# 	Diff:	 -0.005039422687395653
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.006330654676884478
# 	Male:	 0.0066588004421646195
# 	Diff:	 -0.0003281457652801415
# 	T-test:	 2.1043432384168286e-09
#
#
# Feat: Veterinary
#
# Before matching:
#
# 	Female:	 0.009884863313998982
# 	Male:	 0.00788267480222089
# 	Diff:	 0.0020021885117780924
# 	T-test:	 1.5968424301255844e-268
#
# After matching:
#
# 	Female:	 0.009884863313998982
# 	Male:	 0.00972836684758983
# 	Diff:	 0.00015649646640915164
# 	T-test:	 0.02082097836081467
#
#
# Feat: General
#
# Before matching:
#
# 	Female:	 0.01378311577012408
# 	Male:	 0.017548665043571506
# 	Diff:	 -0.003765549273447426
# 	T-test:	 0.0
#
# After matching:
#
# 	Female:	 0.01378311577012408
# 	Male:	 0.014432451902177288
# 	Diff:	 -0.000649336132053209
# 	T-test:	 1.1256369831876874e-16

# %%
for feat in co_feats:
    f_avg = np.mean(X.loc[X['gender']=='Female', feat])
    m_avg = np.mean(X.loc[X['gender']=='Male', feat])
    f_avg_ = np.mean(X.loc[pairs.keys(), feat])
    m_avg_ = np.mean(X.loc[pairs.values(), feat])
    print(feat, ' & ', '{:6.2f}'.format(f_avg), ' & ', '{:6.2f}'.format(m_avg), ' & ', '{:6.2f}'.format(f_avg_), ' & ', '{:6.2f}'.format(m_avg_), ' \\\\ \hline')
# Out:
# authorship_pos[T.last_position]  &    0.14  &    0.19  &    0.14  &    0.13  \\ \hline
# authorship_pos[T.middle_position]  &    0.66  &    0.64  &    0.66  &    0.66  \\ \hline
# authorship_pos[T.solo_author]  &    0.01  &    0.02  &    0.01  &    0.01  \\ \hline
# affiliation_cate[T.international]  &    0.65  &    0.65  &    0.65  &    0.65  \\ \hline
# pub_year[T.2014]  &    0.15  &    0.15  &    0.15  &    0.15  \\ \hline
# pub_year[T.2015]  &    0.17  &    0.17  &    0.17  &    0.17  \\ \hline
# pub_year[T.2016]  &    0.18  &    0.18  &    0.18  &    0.18  \\ \hline
# pub_year[T.2017]  &    0.19  &    0.18  &    0.19  &    0.19  \\ \hline
# pub_year[T.2018]  &    0.18  &    0.19  &    0.18  &    0.18  \\ \hline
# author_pub_count_cate  &    4.08  &    5.41  &    4.08  &    4.04  \\ \hline
# affiliation_rank_cate  &    4.35  &    4.28  &    4.35  &    4.38  \\ \hline
# num_authors  &   30.23  &   59.76  &   30.23  &   27.19  \\ \hline
# journal_impact  &    5.23  &    5.59  &    5.23  &    5.25  \\ \hline
# author_citation_log  &    5.93  &    7.84  &    5.93  &    5.85  \\ \hline
# Social_Sciences  &    0.09  &    0.06  &    0.09  &    0.08  \\ \hline
# Materials_Science  &    0.03  &    0.04  &    0.03  &    0.03  \\ \hline
# Engineering  &    0.03  &    0.05  &    0.03  &    0.03  \\ \hline
# Chemistry  &    0.05  &    0.06  &    0.05  &    0.05  \\ \hline
# Biochemistry__Genetics_and_Molecular_Biology  &    0.25  &    0.22  &    0.25  &    0.25  \\ \hline
# Medicine  &    0.46  &    0.40  &    0.46  &    0.45  \\ \hline
# Nursing  &    0.03  &    0.01  &    0.03  &    0.03  \\ \hline
# Agricultural_and_Biological_Sciences  &    0.11  &    0.11  &    0.11  &    0.12  \\ \hline
# Pharmacology__Toxicology_and_Pharmaceutics  &    0.04  &    0.03  &    0.04  &    0.04  \\ \hline
# Neuroscience  &    0.05  &    0.05  &    0.05  &    0.05  \\ \hline
# Business__Management_and_Accounting  &    0.01  &    0.01  &    0.01  &    0.01  \\ \hline
# Economics__Econometrics_and_Finance  &    0.01  &    0.01  &    0.01  &    0.01  \\ \hline
# Chemical_Engineering  &    0.02  &    0.02  &    0.02  &    0.02  \\ \hline
# Physics_and_Astronomy  &    0.04  &    0.09  &    0.04  &    0.04  \\ \hline
# Computer_Science  &    0.01  &    0.03  &    0.01  &    0.02  \\ \hline
# Decision_Sciences  &    0.00  &    0.00  &    0.00  &    0.00  \\ \hline
# Health_Professions  &    0.01  &    0.01  &    0.01  &    0.01  \\ \hline
# Psychology  &    0.04  &    0.02  &    0.04  &    0.04  \\ \hline
# Immunology_and_Microbiology  &    0.06  &    0.05  &    0.06  &    0.06  \\ \hline
# Dentistry  &    0.00  &    0.00  &    0.00  &    0.00  \\ \hline
# Earth_and_Planetary_Sciences  &    0.02  &    0.04  &    0.02  &    0.02  \\ \hline
# Environmental_Science  &    0.04  &    0.05  &    0.04  &    0.05  \\ \hline
# Mathematics  &    0.01  &    0.02  &    0.01  &    0.01  \\ \hline
# Arts_and_Humanities  &    0.00  &    0.00  &    0.00  &    0.00  \\ \hline
# Energy  &    0.01  &    0.01  &    0.01  &    0.01  \\ \hline
# Veterinary  &    0.01  &    0.01  &    0.01  &    0.01  \\ \hline
# General  &    0.01  &    0.02  &    0.01  &    0.01  \\ \hline

# %% [markdown]
# Avg treatment effect

# %%
# female avg
np.mean(X.loc[pairs.keys(), 'self_promotion'])
# Out:
# 0.03473749580813036

# %%
# male avg
np.mean(X.loc[pairs.values(), 'self_promotion'])
# Out:
# 0.045598598984015005

# %%
ttest_rel(X.loc[pairs.keys(), 'self_promotion'].apply(lambda x: 1 if x == True else 0), \
          X.loc[pairs.values(), 'self_promotion'].apply(lambda x: 1 if x == True else 0))
# Out:
# Ttest_relResult(statistic=-78.66416929505928, pvalue=0.0)

# %% [markdown]
# Avg treatment effect: `estimate via logit with covariates to control for the slight remaining imbalance`

# %%
reg_data['self_promotion'] = reg_data['self_promotion'].astype('int32')

# %%
eq = "self_promotion ~ C(gender, Treatment(reference='Male')) + authorship_pos + author_pub_count_cate + \
    affiliation_rank_cate + affiliation_cate + num_authors + journal_impact + author_citation_log + pub_year + \
        Social_Sciences + Materials_Science + Engineering + Chemistry + \
        Biochemistry__Genetics_and_Molecular_Biology + Medicine + Nursing + Agricultural_and_Biological_Sciences + \
        Pharmacology__Toxicology_and_Pharmaceutics + Neuroscience + Business__Management_and_Accounting + \
        Economics__Econometrics_and_Finance + Chemical_Engineering + Physics_and_Astronomy + Computer_Science + \
        Decision_Sciences + Health_Professions + Psychology + Immunology_and_Microbiology + Dentistry + \
        Earth_and_Planetary_Sciences + Environmental_Science + Mathematics + Arts_and_Humanities + Energy + \
        Veterinary + General"
model = smf.logit(formula = eq, data = reg_data.loc[list(pairs.keys()) + list(pairs.values())].sample(frac=1)).fit()

# for count DV.
# smf.glm(formula = eq, data=reg_data, family=sm.families.NegativeBinomial()).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         self_promotion   No. Observations:              8051300
# Model:                          Logit   Df Residuals:                  8051257
# Method:                           MLE   Df Model:                           42
# Date:                Sun, 20 Nov 2022   Pseudo R-squ.:                 0.09350
# Time:                        16:36:40   Log-Likelihood:            -1.2296e+06
# converged:                       True   LL-Null:                   -1.3565e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           -3.5594      0.010   -355.722      0.000      -3.579      -3.540
# C(gender, Treatment(reference='Male'))[T.Female]    -0.3021      0.004    -81.613      0.000      -0.309      -0.295
# authorship_pos[T.last_position]                     -0.3803      0.006    -66.384      0.000      -0.392      -0.369
# authorship_pos[T.middle_position]                   -0.9775      0.004   -222.808      0.000      -0.986      -0.969
# authorship_pos[T.solo_author]                        0.4408      0.010     42.393      0.000       0.420       0.461
# affiliation_cate[T.international]                    0.1096      0.004     26.561      0.000       0.101       0.118
# pub_year[T.2014]                                     0.3232      0.010     32.021      0.000       0.303       0.343
# pub_year[T.2015]                                     0.6528      0.009     69.630      0.000       0.634       0.671
# pub_year[T.2016]                                     0.8914      0.009     98.639      0.000       0.874       0.909
# pub_year[T.2017]                                     1.2516      0.009    143.129      0.000       1.234       1.269
# pub_year[T.2018]                                     1.6208      0.009    188.904      0.000       1.604       1.638
# author_pub_count_cate                                0.0814      0.002     46.522      0.000       0.078       0.085
# affiliation_rank_cate                               -0.0555      0.001    -78.812      0.000      -0.057      -0.054
# num_authors                                         -0.0008   2.51e-05    -30.811      0.000      -0.001      -0.001
# journal_impact                                       0.0352      0.000    150.641      0.000       0.035       0.036
# author_citation_log                                 -0.0170      0.001    -16.118      0.000      -0.019      -0.015
# Social_Sciences                                      0.8527      0.008    112.957      0.000       0.838       0.867
# Materials_Science                                   -0.3331      0.018    -18.911      0.000      -0.368      -0.299
# Engineering                                         -0.4449      0.015    -29.539      0.000      -0.474      -0.415
# Chemistry                                           -0.6085      0.013    -47.162      0.000      -0.634      -0.583
# Biochemistry__Genetics_and_Molecular_Biology        -0.2238      0.005    -43.397      0.000      -0.234      -0.214
# Medicine                                            -0.3209      0.004    -76.017      0.000      -0.329      -0.313
# Nursing                                              0.1953      0.010     18.635      0.000       0.175       0.216
# Agricultural_and_Biological_Sciences                 0.5262      0.006     88.769      0.000       0.515       0.538
# Pharmacology__Toxicology_and_Pharmaceutics          -0.6657      0.014    -47.529      0.000      -0.693      -0.638
# Neuroscience                                        -0.1361      0.009    -15.242      0.000      -0.154      -0.119
# Business__Management_and_Accounting                 -0.2197      0.016    -13.603      0.000      -0.251      -0.188
# Economics__Econometrics_and_Finance                 -0.4521      0.019    -23.452      0.000      -0.490      -0.414
# Chemical_Engineering                                 0.0559      0.018      3.045      0.002       0.020       0.092
# Physics_and_Astronomy                               -0.8550      0.017    -49.707      0.000      -0.889      -0.821
# Computer_Science                                     0.1120      0.015      7.632      0.000       0.083       0.141
# Decision_Sciences                                   -0.8185      0.033    -24.625      0.000      -0.884      -0.753
# Health_Professions                                   0.8642      0.013     66.096      0.000       0.839       0.890
# Psychology                                          -0.5992      0.011    -55.447      0.000      -0.620      -0.578
# Immunology_and_Microbiology                         -0.1886      0.010    -19.605      0.000      -0.207      -0.170
# Dentistry                                           -1.4253      0.062    -22.966      0.000      -1.547      -1.304
# Earth_and_Planetary_Sciences                        -0.0741      0.012     -6.057      0.000      -0.098      -0.050
# Environmental_Science                                0.1515      0.008     18.893      0.000       0.136       0.167
# Mathematics                                         -0.2762      0.021    -13.071      0.000      -0.318      -0.235
# Arts_and_Humanities                                 -0.2164      0.020    -10.816      0.000      -0.256      -0.177
# Energy                                              -0.4123      0.026    -16.019      0.000      -0.463      -0.362
# Veterinary                                          -0.8509      0.029    -29.717      0.000      -0.907      -0.795
# General                                              0.3437      0.012     28.883      0.000       0.320       0.367
# ====================================================================================================================
# """

# %%
print(model.summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                                    & self\_promotion  & \textbf{  No. Observations:  } &   8051300    \\
# \textbf{Model:}                                            &      Logit       & \textbf{  Df Residuals:      } &   8051257    \\
# \textbf{Method:}                                           &       MLE        & \textbf{  Df Model:          } &        42    \\
# \textbf{Date:}                                             & Mon, 21 Nov 2022 & \textbf{  Pseudo R-squ.:     } &   0.09350    \\
# \textbf{Time:}                                             &     09:00:05     & \textbf{  Log-Likelihood:    } & -1.2296e+06  \\
# \textbf{converged:}                                        &       True       & \textbf{  LL-Null:           } & -1.3565e+06  \\
# \textbf{Covariance Type:}                                  &    nonrobust     & \textbf{  LLR p-value:       } &     0.000    \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                                            & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                                         &      -3.5594  &        0.010     &  -355.722  &         0.000        &       -3.579    &       -3.540     \\
# \textbf{C(gender, Treatment(reference='Male'))[T.Female]}  &      -0.3021  &        0.004     &   -81.613  &         0.000        &       -0.309    &       -0.295     \\
# \textbf{authorship\_pos[T.last\_position]}                 &      -0.3803  &        0.006     &   -66.384  &         0.000        &       -0.392    &       -0.369     \\
# \textbf{authorship\_pos[T.middle\_position]}               &      -0.9775  &        0.004     &  -222.808  &         0.000        &       -0.986    &       -0.969     \\
# \textbf{authorship\_pos[T.solo\_author]}                   &       0.4408  &        0.010     &    42.393  &         0.000        &        0.420    &        0.461     \\
# \textbf{affiliation\_cate[T.international]}                &       0.1096  &        0.004     &    26.561  &         0.000        &        0.101    &        0.118     \\
# \textbf{pub\_year[T.2014]}                                 &       0.3232  &        0.010     &    32.021  &         0.000        &        0.303    &        0.343     \\
# \textbf{pub\_year[T.2015]}                                 &       0.6528  &        0.009     &    69.630  &         0.000        &        0.634    &        0.671     \\
# \textbf{pub\_year[T.2016]}                                 &       0.8914  &        0.009     &    98.639  &         0.000        &        0.874    &        0.909     \\
# \textbf{pub\_year[T.2017]}                                 &       1.2516  &        0.009     &   143.129  &         0.000        &        1.234    &        1.269     \\
# \textbf{pub\_year[T.2018]}                                 &       1.6208  &        0.009     &   188.904  &         0.000        &        1.604    &        1.638     \\
# \textbf{author\_pub\_count\_cate}                          &       0.0814  &        0.002     &    46.522  &         0.000        &        0.078    &        0.085     \\
# \textbf{affiliation\_rank\_cate}                           &      -0.0555  &        0.001     &   -78.812  &         0.000        &       -0.057    &       -0.054     \\
# \textbf{num\_authors}                                      &      -0.0008  &     2.51e-05     &   -30.811  &         0.000        &       -0.001    &       -0.001     \\
# \textbf{journal\_impact}                                   &       0.0352  &        0.000     &   150.641  &         0.000        &        0.035    &        0.036     \\
# \textbf{author\_citation\_log}                             &      -0.0170  &        0.001     &   -16.118  &         0.000        &       -0.019    &       -0.015     \\
# \textbf{Social\_Sciences}                                  &       0.8527  &        0.008     &   112.957  &         0.000        &        0.838    &        0.867     \\
# \textbf{Materials\_Science}                                &      -0.3331  &        0.018     &   -18.911  &         0.000        &       -0.368    &       -0.299     \\
# \textbf{Engineering}                                       &      -0.4449  &        0.015     &   -29.539  &         0.000        &       -0.474    &       -0.415     \\
# \textbf{Chemistry}                                         &      -0.6085  &        0.013     &   -47.162  &         0.000        &       -0.634    &       -0.583     \\
# \textbf{Biochemistry\_\_Genetics\_and\_Molecular\_Biology} &      -0.2238  &        0.005     &   -43.397  &         0.000        &       -0.234    &       -0.214     \\
# \textbf{Medicine}                                          &      -0.3209  &        0.004     &   -76.017  &         0.000        &       -0.329    &       -0.313     \\
# \textbf{Nursing}                                           &       0.1953  &        0.010     &    18.635  &         0.000        &        0.175    &        0.216     \\
# \textbf{Agricultural\_and\_Biological\_Sciences}           &       0.5262  &        0.006     &    88.769  &         0.000        &        0.515    &        0.538     \\
# \textbf{Pharmacology\_\_Toxicology\_and\_Pharmaceutics}    &      -0.6657  &        0.014     &   -47.529  &         0.000        &       -0.693    &       -0.638     \\
# \textbf{Neuroscience}                                      &      -0.1361  &        0.009     &   -15.242  &         0.000        &       -0.154    &       -0.119     \\
# \textbf{Business\_\_Management\_and\_Accounting}           &      -0.2197  &        0.016     &   -13.603  &         0.000        &       -0.251    &       -0.188     \\
# \textbf{Economics\_\_Econometrics\_and\_Finance}           &      -0.4521  &        0.019     &   -23.452  &         0.000        &       -0.490    &       -0.414     \\
# \textbf{Chemical\_Engineering}                             &       0.0559  &        0.018     &     3.045  &         0.002        &        0.020    &        0.092     \\
# \textbf{Physics\_and\_Astronomy}                           &      -0.8550  &        0.017     &   -49.707  &         0.000        &       -0.889    &       -0.821     \\
# \textbf{Computer\_Science}                                 &       0.1120  &        0.015     &     7.632  &         0.000        &        0.083    &        0.141     \\
# \textbf{Decision\_Sciences}                                &      -0.8185  &        0.033     &   -24.625  &         0.000        &       -0.884    &       -0.753     \\
# \textbf{Health\_Professions}                               &       0.8642  &        0.013     &    66.096  &         0.000        &        0.839    &        0.890     \\
# \textbf{Psychology}                                        &      -0.5992  &        0.011     &   -55.447  &         0.000        &       -0.620    &       -0.578     \\
# \textbf{Immunology\_and\_Microbiology}                     &      -0.1886  &        0.010     &   -19.605  &         0.000        &       -0.207    &       -0.170     \\
# \textbf{Dentistry}                                         &      -1.4253  &        0.062     &   -22.966  &         0.000        &       -1.547    &       -1.304     \\
# \textbf{Earth\_and\_Planetary\_Sciences}                   &      -0.0741  &        0.012     &    -6.057  &         0.000        &       -0.098    &       -0.050     \\
# \textbf{Environmental\_Science}                            &       0.1515  &        0.008     &    18.893  &         0.000        &        0.136    &        0.167     \\
# \textbf{Mathematics}                                       &      -0.2762  &        0.021     &   -13.071  &         0.000        &       -0.318    &       -0.235     \\
# \textbf{Arts\_and\_Humanities}                             &      -0.2164  &        0.020     &   -10.816  &         0.000        &       -0.256    &       -0.177     \\
# \textbf{Energy}                                            &      -0.4123  &        0.026     &   -16.019  &         0.000        &       -0.463    &       -0.362     \\
# \textbf{Veterinary}                                        &      -0.8509  &        0.029     &   -29.717  &         0.000        &       -0.907    &       -0.795     \\
# \textbf{General}                                           &       0.3437  &        0.012     &    28.883  &         0.000        &        0.320    &        0.367     \\
# \bottomrule
# \end{tabular}
# %\caption{Logit Regression Results}
# \end{center}

# %%
eq = "self_promotion ~ C(gender, Treatment(reference='Male'))"
model = smf.logit(formula = eq, data = reg_data.loc[list(pairs.keys()) + list(pairs.values())].sample(frac=1)).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.168094
#          Iterations 7

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         self_promotion   No. Observations:              8051300
# Model:                          Logit   Df Residuals:                  8051298
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 20 Nov 2022   Pseudo R-squ.:                0.002277
# Time:                        16:38:45   Log-Likelihood:            -1.3534e+06
# converged:                       True   LL-Null:                   -1.3565e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ====================================================================================================================
#                                                        coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           -3.0412      0.002  -1272.932      0.000      -3.046      -3.037
# C(gender, Treatment(reference='Male'))[T.Female]    -0.2834      0.004    -78.245      0.000      -0.290      -0.276
# ====================================================================================================================
# """

# %%
print(model.summary().as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}                                   & self\_promotion  & \textbf{  No. Observations:  } &   8051300    \\
# \textbf{Model:}                                           &      Logit       & \textbf{  Df Residuals:      } &   8051298    \\
# \textbf{Method:}                                          &       MLE        & \textbf{  Df Model:          } &         1    \\
# \textbf{Date:}                                            & Sun, 20 Nov 2022 & \textbf{  Pseudo R-squ.:     } &   0.002277   \\
# \textbf{Time:}                                            &     16:43:45     & \textbf{  Log-Likelihood:    } & -1.3534e+06  \\
# \textbf{converged:}                                       &       True       & \textbf{  LL-Null:           } & -1.3565e+06  \\
# \textbf{Covariance Type:}                                 &    nonrobust     & \textbf{  LLR p-value:       } &     0.000    \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                                                           & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{Intercept}                                        &      -3.0412  &        0.002     & -1272.932  &         0.000        &       -3.046    &       -3.037     \\
# \textbf{C(gender, Treatment(reference='Male'))[T.Female]} &      -0.2834  &        0.004     &   -78.245  &         0.000        &       -0.290    &       -0.276     \\
# \bottomrule
# \end{tabular}
# %\caption{Logit Regression Results}
# \end{center}
